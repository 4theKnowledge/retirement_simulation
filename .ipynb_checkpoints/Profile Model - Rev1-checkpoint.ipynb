# %% [markdown]
# ## Object oriented profile design for use in personal financial forecasting simulation tool

# %%
import datetime
from dateutil.relativedelta import relativedelta
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt

# %% [raw]
# class Simulation():
#     """
#     Simulation class. Used for simulation functions and data capture.
#     """
#
#     def __init__(self):
#         self.dateHistory = []

# %%
class Expenses():
    """
    Model for general expenses.
    """
    
    def __init__(self, expenses):
        # Everything is on a monthly basis in the model...
        self.expenses = expenses

# %%
class Income():
    """
    Model for income (earned, passive, portfolio).
    """
    
    def __init__(self, income):
        # Everything is on a monthly basis in the model...
        self.income = income
        self.remainingIncome = self.income    # init
        self.dateHistory = []
        self.incomeHistory = []
        
    def incomeAfterCosts(self, loanPaymentSum):
        """
        Aggregated Monthly.
        """
        costs = loanPaymentSum
        self.remainingIncome = self.income - costs
        
    def getIncomeHistory(self, date, incomeInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.incomeHistory.append(incomeInfo)

# %%
class Loan():
    """
    Model for user profile loans.
    """
    
    def __init__(self, loanID, principal, interestRate, annualPayments, duration, startDate):
        self.principal = principal
        self.interestRate = interestRate
        self.annualPayments = annualPayments
        self.duration = duration
        self.startDate = datetime.datetime.strptime(startDate, '%d-%m-%Y').date()
        self.loanID = loanID
        self.period = 1
        self.endDate = (self.startDate + relativedelta(years=self.duration))
        self.beginBalance = self.principal
        self.endBalance = self.principal
        self.loanPaidOff = False
        self.loanPaidOffDate = 'Not paid off - Active'
        self.loanActive = False
        
        # First loan payment amount
        self.loanPayment = -round(np.pmt(self.interestRate/self.annualPayments, self.duration*self.annualPayments, self.principal), 2)      
    
        # For data capture
        self.dateHistory = []
        self.loanHistory = []
    
    def initDesc(self):
        return f'''Loan {self.loanID} has principal of ${self.principal} over duration {self.duration} years with expected finish date of {self.endDate} - remaining balance: ${self.endBalance}'''
    
    # Main Functions
    def makePayment(self):
        """
        Make a payment against the principal.
        """
        self.loanActive = True
        self.interest = round(((self.interestRate/self.annualPayments) * self.beginBalance), 2)
        self.loanPayment = min(self.loanPayment, self.beginBalance + self.interest)
        self.endBalance = self.beginBalance - (self.loanPayment - self.interest)
        self.period += 1
        self.beginBalance = self.endBalance
        
    def paymentSummary(self):
        try:
            print(f'Period: {self.period} BeginBalance: {self.beginBalance:0.2f} Principal: {self.principal:0.2f} Interest: {self.interest:0.2f} Payment: {self.loanPayment:0.2f}')
        except:
            print('Not enough information. Loan has likely not become active.')

    def loanFinished(self, date):
        """
        Used when a loan is finished.
        """
        #TODO: Add date for when loan finishes... as this may not be constant...
        self.loanPaidOff = True
        self.loanActive = False
        self.loanPaidOffDate = date
    
    # Misc Functions
    def increasePrincipal(self, increaseAmt):
        """
        Increase the amount of loan principal via month begin balance.
        """
        self.beginBalance += increaseAmt
        
    def increasePrincipalRandomly(self):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """
        if (0.99 < np.random.uniform(0,1)) and self.loanActive:
            if self.loanPaidOff == False:
                increaseAmt = np.random.randint(0,10)*1000
                self.beginBalance += increaseAmt
                print(f'Increased {self.loanID} balance by ${increaseAmt}')       
        
    # Data Capture Functions
    def getLoanHistory(self, date, loanInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.loanHistory.append(loanInfo)

# %%
class Profile(Income):
    """
    Profile for user. Contains their general information and meta data for financial modeling.
    """
    
    # Initializer / Instance Attributes
    def __init__(self, name, age, retireAge, incomePA, expensesPM):
        self.name = name
        self.age = age
        self.retireAge = retireAge
        # Loans
        self.hasLoan = False
        self.loanDict = {}
        self.noLoans = 0
        self.loanPaymentSum = 0
        # Income
        self.hasIncome = False
        self.income = incomePA / 12
        self.hasIncome = True
        # Expenses
        self.expenses = expensesPM
        
        # Inherit Loan init.. by inheriting this class, we can access it's attributes and methods...
        super().__init__(self.income)  # pass attribute to class
        
        
    # Profile
    def ageStep(self, year):
        """
        Used to age the users profile and step through time.
        """
        self.age += year
    
    def summary(self):
        print(f'{self.name} is {self.age} years old and has income of ${self.income:0.2f} per month.')
    
    # Loan
    def getLoan(self, principal, interestRate, annualPayments, duration, startDate):
        """
        Allocates a loan to the profile.
        """
        self.hasLoan = True
        self.noLoans += 1
        print(f'Number of loans: {self.noLoans}')
        loanID = str(self.noLoans)
        self.loanDict[loanID] = Loan(loanID, principal, interestRate, annualPayments, duration, startDate)
        
    def removeLoan(self, loanID):
        """
        Removes a loan from the profile. TODO: update to remove once paid off.
        """
        try:
            del self.loanDict[loanID]
        except:
            print('Loan doesnt exist')
            
    def loanDesc(self):
        """
        Summary of active loans.
        """
        self.currentLoans = len(self.loanDict)
        try:
            return f'Current active loans for {self.name}: {self.currentLoans}'
        except:
            return f'{self.name} has no loan'
        
    def loanInfo(self):
        """
        Detailed description of loan dict. For debugging purposes.
        """
        for loanID, loanDetails in self.loanDict.items():
            print(f'{loanDetails.initDesc()}')

# %% [markdown]
# # Get basic profile information and Initiate Profile

# %%
def init_profile():
    myProfile = Profile('Tyler', 26, 65, 52000, 500)
    
    myProfile.summary()


    # Loan 1 - mortgage
    myProfile.getLoan(350000, 0.04, 12, 25, '1-1-2021')
    # Loan 2 - car
    myProfile.getLoan(50000, 0.12, 12, 5, '01-01-2025')
    # Loan 3 - car 2
    myProfile.getLoan(75000, 0.08, 12, 10, '01-06-2027')
    myProfile.loanDesc()
    myProfile.loanInfo()
    
    return myProfile

# %%
myProfile = init_profile()
# Out:
# Tyler is 26 years old and has income of $4333.33 per month.
# Number of loans: 1
# Number of loans: 2
# Number of loans: 3
# Loan 1 has principal of $350000 over duration 25 years with expected finish date of 2046-01-01 - remaining balance: $350000
# Loan 2 has principal of $50000 over duration 5 years with expected finish date of 2030-01-01 - remaining balance: $50000
# Loan 3 has principal of $75000 over duration 10 years with expected finish date of 2037-06-01 - remaining balance: $75000

# %%
myProfile.loanDict['1'].paymentSummary()
# Out:
# Not enough information. Loan has likely not become active.

# %%
myProfile.loanDict['1'].loanActive
# Out:
# False

# %%
myProfile.expenses
# Out:
# 500

# %% [markdown]
# ## Simulate

# %% [raw]
# simulate = Simulation()

# %% [raw]
# simulate.dateHistory

# %% [markdown]
# ### Simulation Iterations

# %%
# Duration of simulation (phase 1)
dateStart = datetime.date(2020,1,1)
dateStartTemp = dateStart



# Iterate over life with month level grainularity
while myProfile.age < myProfile.retireAge:
    # Current datetime of step
    print(f'\n {dateStartTemp}')
    print(f'Monthly Income: ${myProfile.income:0.2f}')
    
    tempLoanCost = 0
    
    # Pay debts
    for loanID, loanInfo in myProfile.loanDict.items():
        if myProfile.loanDict[loanID].startDate <= dateStartTemp:
            
            # Random change of principal injection
            myProfile.loanDict[loanID].increasePrincipalRandomly()

            # If balance remains on loans - make payment
            if 0 < myProfile.loanDict[loanID].beginBalance:
                # Raise payment against loan
                myProfile.loanDict[loanID].makePayment()
                myProfile.loanDict[loanID].paymentSummary()
                
                # Compute remaining income (income - loan payments)
#                 myProfile.incomeAfterCosts(myProfile.loanDict[loanID].loanPayment)
    
                # Capture loan history information for future use
                myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, myProfile.loanDict[loanID].beginBalance)

                # Actuate attribute when loan is paid off.
                if myProfile.loanDict[loanID].beginBalance == 0:
                    print(f'LOAN {loanID} PAID OFF!')
                    # Setting finished to True
                    myProfile.loanDict[loanID].loanFinished(dateStartTemp)
            
                else:
                    # Capture loanPayment for totalcost agg
                    print(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
                    tempLoanCost += myProfile.loanDict[loanID].loanPayment
            
            else:
                # No principal. Either loan hasn't begun or it's finished
                myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)


    
        else:
            myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
            print('too early - no loan active')
            pass
                
    myProfile.incomeAfterCosts(tempLoanCost + myProfile.expenses)
    print(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
    myProfile.getIncomeHistory(dateStartTemp, myProfile.remainingIncome)
    
    
    # Steps through time month-by-month
    dateStartTemp += relativedelta(months=1)
    
    # Adds year to age during simulation
    if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
        #print(f'Year: {dateStartTemp.year - dateStart.year}')
        myProfile.ageStep(1)
# Out:
#  2020-01-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-02-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-03-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-04-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-05-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-06-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-07-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-08-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-09-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-10-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-11-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2020-12-01
# Monthly Income: $4333.33
# too early - no loan active
# too early - no loan active
# too early - no loan active
# Income Remaining: $3833.33
#
#  2021-01-01
# Monthly Income: $4333.33
# Period: 2 BeginBalance: 349319.24 Principal: 350000.00 Interest: 1166.67 Payment: 1847.43
# Loan 1 - Begin Balance: $349319.24 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-02-01
# Monthly Income: $4333.33
# Period: 3 BeginBalance: 348636.21 Principal: 350000.00 Interest: 1164.40 Payment: 1847.43
# Loan 1 - Begin Balance: $348636.21 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-03-01
# Monthly Income: $4333.33
# Period: 4 BeginBalance: 347950.90 Principal: 350000.00 Interest: 1162.12 Payment: 1847.43
# Loan 1 - Begin Balance: $347950.90 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-04-01
# Monthly Income: $4333.33
# Period: 5 BeginBalance: 347263.31 Principal: 350000.00 Interest: 1159.84 Payment: 1847.43
# Loan 1 - Begin Balance: $347263.31 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-05-01
# Monthly Income: $4333.33
# Period: 6 BeginBalance: 346573.42 Principal: 350000.00 Interest: 1157.54 Payment: 1847.43
# Loan 1 - Begin Balance: $346573.42 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-06-01
# Monthly Income: $4333.33
# Period: 7 BeginBalance: 345881.23 Principal: 350000.00 Interest: 1155.24 Payment: 1847.43
# Loan 1 - Begin Balance: $345881.23 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-07-01
# Monthly Income: $4333.33
# Period: 8 BeginBalance: 345186.74 Principal: 350000.00 Interest: 1152.94 Payment: 1847.43
# Loan 1 - Begin Balance: $345186.74 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-08-01
# Monthly Income: $4333.33
# Period: 9 BeginBalance: 344489.93 Principal: 350000.00 Interest: 1150.62 Payment: 1847.43
# Loan 1 - Begin Balance: $344489.93 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-09-01
# Monthly Income: $4333.33
# Period: 10 BeginBalance: 343790.80 Principal: 350000.00 Interest: 1148.30 Payment: 1847.43
# Loan 1 - Begin Balance: $343790.80 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-10-01
# Monthly Income: $4333.33
# Period: 11 BeginBalance: 343089.34 Principal: 350000.00 Interest: 1145.97 Payment: 1847.43
# Loan 1 - Begin Balance: $343089.34 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-11-01
# Monthly Income: $4333.33
# Period: 12 BeginBalance: 342385.54 Principal: 350000.00 Interest: 1143.63 Payment: 1847.43
# Loan 1 - Begin Balance: $342385.54 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2021-12-01
# Monthly Income: $4333.33
# Period: 13 BeginBalance: 341679.40 Principal: 350000.00 Interest: 1141.29 Payment: 1847.43
# Loan 1 - Begin Balance: $341679.40 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-01-01
# Monthly Income: $4333.33
# Period: 14 BeginBalance: 340970.90 Principal: 350000.00 Interest: 1138.93 Payment: 1847.43
# Loan 1 - Begin Balance: $340970.90 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-02-01
# Monthly Income: $4333.33
# Period: 15 BeginBalance: 340260.04 Principal: 350000.00 Interest: 1136.57 Payment: 1847.43
# Loan 1 - Begin Balance: $340260.04 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-03-01
# Monthly Income: $4333.33
# Period: 16 BeginBalance: 339546.81 Principal: 350000.00 Interest: 1134.20 Payment: 1847.43
# Loan 1 - Begin Balance: $339546.81 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-04-01
# Monthly Income: $4333.33
# Period: 17 BeginBalance: 338831.20 Principal: 350000.00 Interest: 1131.82 Payment: 1847.43
# Loan 1 - Begin Balance: $338831.20 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-05-01
# Monthly Income: $4333.33
# Period: 18 BeginBalance: 338113.21 Principal: 350000.00 Interest: 1129.44 Payment: 1847.43
# Loan 1 - Begin Balance: $338113.21 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-06-01
# Monthly Income: $4333.33
# Period: 19 BeginBalance: 337392.82 Principal: 350000.00 Interest: 1127.04 Payment: 1847.43
# Loan 1 - Begin Balance: $337392.82 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-07-01
# Monthly Income: $4333.33
# Period: 20 BeginBalance: 336670.03 Principal: 350000.00 Interest: 1124.64 Payment: 1847.43
# Loan 1 - Begin Balance: $336670.03 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-08-01
# Monthly Income: $4333.33
# Period: 21 BeginBalance: 335944.83 Principal: 350000.00 Interest: 1122.23 Payment: 1847.43
# Loan 1 - Begin Balance: $335944.83 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-09-01
# Monthly Income: $4333.33
# Period: 22 BeginBalance: 335217.22 Principal: 350000.00 Interest: 1119.82 Payment: 1847.43
# Loan 1 - Begin Balance: $335217.22 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-10-01
# Monthly Income: $4333.33
# Period: 23 BeginBalance: 334487.18 Principal: 350000.00 Interest: 1117.39 Payment: 1847.43
# Loan 1 - Begin Balance: $334487.18 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-11-01
# Monthly Income: $4333.33
# Period: 24 BeginBalance: 333754.71 Principal: 350000.00 Interest: 1114.96 Payment: 1847.43
# Loan 1 - Begin Balance: $333754.71 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2022-12-01
# Monthly Income: $4333.33
# Period: 25 BeginBalance: 333019.80 Principal: 350000.00 Interest: 1112.52 Payment: 1847.43
# Loan 1 - Begin Balance: $333019.80 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-01-01
# Monthly Income: $4333.33
# Period: 26 BeginBalance: 332282.44 Principal: 350000.00 Interest: 1110.07 Payment: 1847.43
# Loan 1 - Begin Balance: $332282.44 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-02-01
# Monthly Income: $4333.33
# Period: 27 BeginBalance: 331542.62 Principal: 350000.00 Interest: 1107.61 Payment: 1847.43
# Loan 1 - Begin Balance: $331542.62 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-03-01
# Monthly Income: $4333.33
# Period: 28 BeginBalance: 330800.33 Principal: 350000.00 Interest: 1105.14 Payment: 1847.43
# Loan 1 - Begin Balance: $330800.33 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-04-01
# Monthly Income: $4333.33
# Period: 29 BeginBalance: 330055.57 Principal: 350000.00 Interest: 1102.67 Payment: 1847.43
# Loan 1 - Begin Balance: $330055.57 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-05-01
# Monthly Income: $4333.33
# Period: 30 BeginBalance: 329308.33 Principal: 350000.00 Interest: 1100.19 Payment: 1847.43
# Loan 1 - Begin Balance: $329308.33 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-06-01
# Monthly Income: $4333.33
# Period: 31 BeginBalance: 328558.59 Principal: 350000.00 Interest: 1097.69 Payment: 1847.43
# Loan 1 - Begin Balance: $328558.59 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-07-01
# Monthly Income: $4333.33
# Period: 32 BeginBalance: 327806.36 Principal: 350000.00 Interest: 1095.20 Payment: 1847.43
# Loan 1 - Begin Balance: $327806.36 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-08-01
# Monthly Income: $4333.33
# Period: 33 BeginBalance: 327051.62 Principal: 350000.00 Interest: 1092.69 Payment: 1847.43
# Loan 1 - Begin Balance: $327051.62 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-09-01
# Monthly Income: $4333.33
# Period: 34 BeginBalance: 326294.36 Principal: 350000.00 Interest: 1090.17 Payment: 1847.43
# Loan 1 - Begin Balance: $326294.36 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-10-01
# Monthly Income: $4333.33
# Period: 35 BeginBalance: 325534.58 Principal: 350000.00 Interest: 1087.65 Payment: 1847.43
# Loan 1 - Begin Balance: $325534.58 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-11-01
# Monthly Income: $4333.33
# Period: 36 BeginBalance: 324772.27 Principal: 350000.00 Interest: 1085.12 Payment: 1847.43
# Loan 1 - Begin Balance: $324772.27 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2023-12-01
# Monthly Income: $4333.33
# Period: 37 BeginBalance: 324007.41 Principal: 350000.00 Interest: 1082.57 Payment: 1847.43
# Loan 1 - Begin Balance: $324007.41 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-01-01
# Monthly Income: $4333.33
# Period: 38 BeginBalance: 323240.00 Principal: 350000.00 Interest: 1080.02 Payment: 1847.43
# Loan 1 - Begin Balance: $323240.00 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-02-01
# Monthly Income: $4333.33
# Period: 39 BeginBalance: 322470.04 Principal: 350000.00 Interest: 1077.47 Payment: 1847.43
# Loan 1 - Begin Balance: $322470.04 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-03-01
# Monthly Income: $4333.33
# Increased 1 balance by $0
# Period: 40 BeginBalance: 321697.51 Principal: 350000.00 Interest: 1074.90 Payment: 1847.43
# Loan 1 - Begin Balance: $321697.51 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-04-01
# Monthly Income: $4333.33
# Period: 41 BeginBalance: 320922.41 Principal: 350000.00 Interest: 1072.33 Payment: 1847.43
# Loan 1 - Begin Balance: $320922.41 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-05-01
# Monthly Income: $4333.33
# Period: 42 BeginBalance: 320144.72 Principal: 350000.00 Interest: 1069.74 Payment: 1847.43
# Loan 1 - Begin Balance: $320144.72 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-06-01
# Monthly Income: $4333.33
# Period: 43 BeginBalance: 319364.44 Principal: 350000.00 Interest: 1067.15 Payment: 1847.43
# Loan 1 - Begin Balance: $319364.44 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-07-01
# Monthly Income: $4333.33
# Period: 44 BeginBalance: 318581.56 Principal: 350000.00 Interest: 1064.55 Payment: 1847.43
# Loan 1 - Begin Balance: $318581.56 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-08-01
# Monthly Income: $4333.33
# Period: 45 BeginBalance: 317796.07 Principal: 350000.00 Interest: 1061.94 Payment: 1847.43
# Loan 1 - Begin Balance: $317796.07 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-09-01
# Monthly Income: $4333.33
# Period: 46 BeginBalance: 317007.96 Principal: 350000.00 Interest: 1059.32 Payment: 1847.43
# Loan 1 - Begin Balance: $317007.96 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-10-01
# Monthly Income: $4333.33
# Period: 47 BeginBalance: 316217.22 Principal: 350000.00 Interest: 1056.69 Payment: 1847.43
# Loan 1 - Begin Balance: $316217.22 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-11-01
# Monthly Income: $4333.33
# Period: 48 BeginBalance: 315423.85 Principal: 350000.00 Interest: 1054.06 Payment: 1847.43
# Loan 1 - Begin Balance: $315423.85 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2024-12-01
# Monthly Income: $4333.33
# Period: 49 BeginBalance: 314627.83 Principal: 350000.00 Interest: 1051.41 Payment: 1847.43
# Loan 1 - Begin Balance: $314627.83 Payment: 1847.43
# too early - no loan active
# too early - no loan active
# Income Remaining: $1985.90
#
#  2025-01-01
# Monthly Income: $4333.33
# Period: 50 BeginBalance: 313829.16 Principal: 350000.00 Interest: 1048.76 Payment: 1847.43
# Loan 1 - Begin Balance: $313829.16 Payment: 1847.43
# Period: 2 BeginBalance: 49387.78 Principal: 50000.00 Interest: 500.00 Payment: 1112.22
# Loan 2 - Begin Balance: $49387.78 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-02-01
# Monthly Income: $4333.33
# Period: 51 BeginBalance: 313027.83 Principal: 350000.00 Interest: 1046.10 Payment: 1847.43
# Loan 1 - Begin Balance: $313027.83 Payment: 1847.43
# Period: 3 BeginBalance: 48769.44 Principal: 50000.00 Interest: 493.88 Payment: 1112.22
# Loan 2 - Begin Balance: $48769.44 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-03-01
# Monthly Income: $4333.33
# Period: 52 BeginBalance: 312223.83 Principal: 350000.00 Interest: 1043.43 Payment: 1847.43
# Loan 1 - Begin Balance: $312223.83 Payment: 1847.43
# Period: 4 BeginBalance: 48144.91 Principal: 50000.00 Interest: 487.69 Payment: 1112.22
# Loan 2 - Begin Balance: $48144.91 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-04-01
# Monthly Income: $4333.33
# Period: 53 BeginBalance: 311417.15 Principal: 350000.00 Interest: 1040.75 Payment: 1847.43
# Loan 1 - Begin Balance: $311417.15 Payment: 1847.43
# Period: 5 BeginBalance: 47514.14 Principal: 50000.00 Interest: 481.45 Payment: 1112.22
# Loan 2 - Begin Balance: $47514.14 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-05-01
# Monthly Income: $4333.33
# Period: 54 BeginBalance: 310607.78 Principal: 350000.00 Interest: 1038.06 Payment: 1847.43
# Loan 1 - Begin Balance: $310607.78 Payment: 1847.43
# Period: 6 BeginBalance: 46877.06 Principal: 50000.00 Interest: 475.14 Payment: 1112.22
# Loan 2 - Begin Balance: $46877.06 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-06-01
# Monthly Income: $4333.33
# Period: 55 BeginBalance: 309795.71 Principal: 350000.00 Interest: 1035.36 Payment: 1847.43
# Loan 1 - Begin Balance: $309795.71 Payment: 1847.43
# Period: 7 BeginBalance: 46233.61 Principal: 50000.00 Interest: 468.77 Payment: 1112.22
# Loan 2 - Begin Balance: $46233.61 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-07-01
# Monthly Income: $4333.33
# Period: 56 BeginBalance: 308980.93 Principal: 350000.00 Interest: 1032.65 Payment: 1847.43
# Loan 1 - Begin Balance: $308980.93 Payment: 1847.43
# Period: 8 BeginBalance: 45583.73 Principal: 50000.00 Interest: 462.34 Payment: 1112.22
# Loan 2 - Begin Balance: $45583.73 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-08-01
# Monthly Income: $4333.33
# Period: 57 BeginBalance: 308163.44 Principal: 350000.00 Interest: 1029.94 Payment: 1847.43
# Loan 1 - Begin Balance: $308163.44 Payment: 1847.43
# Period: 9 BeginBalance: 44927.35 Principal: 50000.00 Interest: 455.84 Payment: 1112.22
# Loan 2 - Begin Balance: $44927.35 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-09-01
# Monthly Income: $4333.33
# Period: 58 BeginBalance: 307343.22 Principal: 350000.00 Interest: 1027.21 Payment: 1847.43
# Loan 1 - Begin Balance: $307343.22 Payment: 1847.43
# Period: 10 BeginBalance: 44264.40 Principal: 50000.00 Interest: 449.27 Payment: 1112.22
# Loan 2 - Begin Balance: $44264.40 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-10-01
# Monthly Income: $4333.33
# Period: 59 BeginBalance: 306520.27 Principal: 350000.00 Interest: 1024.48 Payment: 1847.43
# Loan 1 - Begin Balance: $306520.27 Payment: 1847.43
# Period: 11 BeginBalance: 43594.82 Principal: 50000.00 Interest: 442.64 Payment: 1112.22
# Loan 2 - Begin Balance: $43594.82 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-11-01
# Monthly Income: $4333.33
# Period: 60 BeginBalance: 305694.57 Principal: 350000.00 Interest: 1021.73 Payment: 1847.43
# Loan 1 - Begin Balance: $305694.57 Payment: 1847.43
# Period: 12 BeginBalance: 42918.55 Principal: 50000.00 Interest: 435.95 Payment: 1112.22
# Loan 2 - Begin Balance: $42918.55 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2025-12-01
# Monthly Income: $4333.33
# Period: 61 BeginBalance: 304866.12 Principal: 350000.00 Interest: 1018.98 Payment: 1847.43
# Loan 1 - Begin Balance: $304866.12 Payment: 1847.43
# Period: 13 BeginBalance: 42235.52 Principal: 50000.00 Interest: 429.19 Payment: 1112.22
# Loan 2 - Begin Balance: $42235.52 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-01-01
# Monthly Income: $4333.33
# Period: 62 BeginBalance: 304034.91 Principal: 350000.00 Interest: 1016.22 Payment: 1847.43
# Loan 1 - Begin Balance: $304034.91 Payment: 1847.43
# Period: 14 BeginBalance: 41545.66 Principal: 50000.00 Interest: 422.36 Payment: 1112.22
# Loan 2 - Begin Balance: $41545.66 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-02-01
# Monthly Income: $4333.33
# Period: 63 BeginBalance: 303200.93 Principal: 350000.00 Interest: 1013.45 Payment: 1847.43
# Loan 1 - Begin Balance: $303200.93 Payment: 1847.43
# Period: 15 BeginBalance: 40848.90 Principal: 50000.00 Interest: 415.46 Payment: 1112.22
# Loan 2 - Begin Balance: $40848.90 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-03-01
# Monthly Income: $4333.33
# Period: 64 BeginBalance: 302364.17 Principal: 350000.00 Interest: 1010.67 Payment: 1847.43
# Loan 1 - Begin Balance: $302364.17 Payment: 1847.43
# Period: 16 BeginBalance: 40145.17 Principal: 50000.00 Interest: 408.49 Payment: 1112.22
# Loan 2 - Begin Balance: $40145.17 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-04-01
# Monthly Income: $4333.33
# Period: 65 BeginBalance: 301524.62 Principal: 350000.00 Interest: 1007.88 Payment: 1847.43
# Loan 1 - Begin Balance: $301524.62 Payment: 1847.43
# Period: 17 BeginBalance: 39434.40 Principal: 50000.00 Interest: 401.45 Payment: 1112.22
# Loan 2 - Begin Balance: $39434.40 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-05-01
# Monthly Income: $4333.33
# Period: 66 BeginBalance: 300682.27 Principal: 350000.00 Interest: 1005.08 Payment: 1847.43
# Loan 1 - Begin Balance: $300682.27 Payment: 1847.43
# Period: 18 BeginBalance: 38716.52 Principal: 50000.00 Interest: 394.34 Payment: 1112.22
# Loan 2 - Begin Balance: $38716.52 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-06-01
# Monthly Income: $4333.33
# Period: 67 BeginBalance: 299837.11 Principal: 350000.00 Interest: 1002.27 Payment: 1847.43
# Loan 1 - Begin Balance: $299837.11 Payment: 1847.43
# Period: 19 BeginBalance: 37991.47 Principal: 50000.00 Interest: 387.17 Payment: 1112.22
# Loan 2 - Begin Balance: $37991.47 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-07-01
# Monthly Income: $4333.33
# Period: 68 BeginBalance: 298989.14 Principal: 350000.00 Interest: 999.46 Payment: 1847.43
# Loan 1 - Begin Balance: $298989.14 Payment: 1847.43
# Period: 20 BeginBalance: 37259.16 Principal: 50000.00 Interest: 379.91 Payment: 1112.22
# Loan 2 - Begin Balance: $37259.16 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-08-01
# Monthly Income: $4333.33
# Period: 69 BeginBalance: 298138.34 Principal: 350000.00 Interest: 996.63 Payment: 1847.43
# Loan 1 - Begin Balance: $298138.34 Payment: 1847.43
# Period: 21 BeginBalance: 36519.53 Principal: 50000.00 Interest: 372.59 Payment: 1112.22
# Loan 2 - Begin Balance: $36519.53 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-09-01
# Monthly Income: $4333.33
# Period: 70 BeginBalance: 297284.70 Principal: 350000.00 Interest: 993.79 Payment: 1847.43
# Loan 1 - Begin Balance: $297284.70 Payment: 1847.43
# Period: 22 BeginBalance: 35772.51 Principal: 50000.00 Interest: 365.20 Payment: 1112.22
# Loan 2 - Begin Balance: $35772.51 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-10-01
# Monthly Income: $4333.33
# Period: 71 BeginBalance: 296428.22 Principal: 350000.00 Interest: 990.95 Payment: 1847.43
# Loan 1 - Begin Balance: $296428.22 Payment: 1847.43
# Period: 23 BeginBalance: 35018.02 Principal: 50000.00 Interest: 357.73 Payment: 1112.22
# Loan 2 - Begin Balance: $35018.02 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-11-01
# Monthly Income: $4333.33
# Period: 72 BeginBalance: 295568.88 Principal: 350000.00 Interest: 988.09 Payment: 1847.43
# Loan 1 - Begin Balance: $295568.88 Payment: 1847.43
# Period: 24 BeginBalance: 34255.98 Principal: 50000.00 Interest: 350.18 Payment: 1112.22
# Loan 2 - Begin Balance: $34255.98 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2026-12-01
# Monthly Income: $4333.33
# Period: 73 BeginBalance: 294706.68 Principal: 350000.00 Interest: 985.23 Payment: 1847.43
# Loan 1 - Begin Balance: $294706.68 Payment: 1847.43
# Period: 25 BeginBalance: 33486.32 Principal: 50000.00 Interest: 342.56 Payment: 1112.22
# Loan 2 - Begin Balance: $33486.32 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2027-01-01
# Monthly Income: $4333.33
# Period: 74 BeginBalance: 293841.61 Principal: 350000.00 Interest: 982.36 Payment: 1847.43
# Loan 1 - Begin Balance: $293841.61 Payment: 1847.43
# Period: 26 BeginBalance: 32708.96 Principal: 50000.00 Interest: 334.86 Payment: 1112.22
# Loan 2 - Begin Balance: $32708.96 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2027-02-01
# Monthly Income: $4333.33
# Period: 75 BeginBalance: 292973.65 Principal: 350000.00 Interest: 979.47 Payment: 1847.43
# Loan 1 - Begin Balance: $292973.65 Payment: 1847.43
# Period: 27 BeginBalance: 31923.83 Principal: 50000.00 Interest: 327.09 Payment: 1112.22
# Loan 2 - Begin Balance: $31923.83 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2027-03-01
# Monthly Income: $4333.33
# Period: 76 BeginBalance: 292102.80 Principal: 350000.00 Interest: 976.58 Payment: 1847.43
# Loan 1 - Begin Balance: $292102.80 Payment: 1847.43
# Period: 28 BeginBalance: 31130.85 Principal: 50000.00 Interest: 319.24 Payment: 1112.22
# Loan 2 - Begin Balance: $31130.85 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2027-04-01
# Monthly Income: $4333.33
# Period: 77 BeginBalance: 291229.05 Principal: 350000.00 Interest: 973.68 Payment: 1847.43
# Loan 1 - Begin Balance: $291229.05 Payment: 1847.43
# Period: 29 BeginBalance: 30329.94 Principal: 50000.00 Interest: 311.31 Payment: 1112.22
# Loan 2 - Begin Balance: $30329.94 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2027-05-01
# Monthly Income: $4333.33
# Period: 78 BeginBalance: 290352.38 Principal: 350000.00 Interest: 970.76 Payment: 1847.43
# Loan 1 - Begin Balance: $290352.38 Payment: 1847.43
# Period: 30 BeginBalance: 29521.02 Principal: 50000.00 Interest: 303.30 Payment: 1112.22
# Loan 2 - Begin Balance: $29521.02 Payment: 1112.22
# too early - no loan active
# Income Remaining: $873.68
#
#  2027-06-01
# Monthly Income: $4333.33
# Period: 79 BeginBalance: 289472.79 Principal: 350000.00 Interest: 967.84 Payment: 1847.43
# Loan 1 - Begin Balance: $289472.79 Payment: 1847.43
# Period: 31 BeginBalance: 28704.01 Principal: 50000.00 Interest: 295.21 Payment: 1112.22
# Loan 2 - Begin Balance: $28704.01 Payment: 1112.22
# Period: 2 BeginBalance: 74590.04 Principal: 75000.00 Interest: 500.00 Payment: 909.96
# Loan 3 - Begin Balance: $74590.04 Payment: 909.96
# Income Remaining: $-36.28
#
#  2027-07-01
# Monthly Income: $4333.33
# Period: 80 BeginBalance: 288590.27 Principal: 350000.00 Interest: 964.91 Payment: 1847.43
# Loan 1 - Begin Balance: $288590.27 Payment: 1847.43
# Period: 32 BeginBalance: 27878.83 Principal: 50000.00 Interest: 287.04 Payment: 1112.22
# Loan 2 - Begin Balance: $27878.83 Payment: 1112.22
# Period: 3 BeginBalance: 74177.35 Principal: 75000.00 Interest: 497.27 Payment: 909.96
# Loan 3 - Begin Balance: $74177.35 Payment: 909.96
# Income Remaining: $-36.28
#
#  2027-08-01
# Monthly Income: $4333.33
# Period: 81 BeginBalance: 287704.81 Principal: 350000.00 Interest: 961.97 Payment: 1847.43
# Loan 1 - Begin Balance: $287704.81 Payment: 1847.43
# Period: 33 BeginBalance: 27045.40 Principal: 50000.00 Interest: 278.79 Payment: 1112.22
# Loan 2 - Begin Balance: $27045.40 Payment: 1112.22
# Period: 4 BeginBalance: 73761.91 Principal: 75000.00 Interest: 494.52 Payment: 909.96
# Loan 3 - Begin Balance: $73761.91 Payment: 909.96
# Income Remaining: $-36.28
#
#  2027-09-01
# Monthly Income: $4333.33
# Period: 82 BeginBalance: 286816.40 Principal: 350000.00 Interest: 959.02 Payment: 1847.43
# Loan 1 - Begin Balance: $286816.40 Payment: 1847.43
# Period: 34 BeginBalance: 26203.63 Principal: 50000.00 Interest: 270.45 Payment: 1112.22
# Loan 2 - Begin Balance: $26203.63 Payment: 1112.22
# Period: 5 BeginBalance: 73343.70 Principal: 75000.00 Interest: 491.75 Payment: 909.96
# Loan 3 - Begin Balance: $73343.70 Payment: 909.96
# Income Remaining: $-36.28
#
#  2027-10-01
# Monthly Income: $4333.33
# Period: 83 BeginBalance: 285925.02 Principal: 350000.00 Interest: 956.05 Payment: 1847.43
# Loan 1 - Begin Balance: $285925.02 Payment: 1847.43
# Period: 35 BeginBalance: 25353.45 Principal: 50000.00 Interest: 262.04 Payment: 1112.22
# Loan 2 - Begin Balance: $25353.45 Payment: 1112.22
# Period: 6 BeginBalance: 72922.70 Principal: 75000.00 Interest: 488.96 Payment: 909.96
# Loan 3 - Begin Balance: $72922.70 Payment: 909.96
# Income Remaining: $-36.28
#
#  2027-11-01
# Monthly Income: $4333.33
# Period: 84 BeginBalance: 285030.67 Principal: 350000.00 Interest: 953.08 Payment: 1847.43
# Loan 1 - Begin Balance: $285030.67 Payment: 1847.43
# Period: 36 BeginBalance: 24494.76 Principal: 50000.00 Interest: 253.53 Payment: 1112.22
# Loan 2 - Begin Balance: $24494.76 Payment: 1112.22
# Period: 7 BeginBalance: 72498.89 Principal: 75000.00 Interest: 486.15 Payment: 909.96
# Loan 3 - Begin Balance: $72498.89 Payment: 909.96
# Income Remaining: $-36.28
#
#  2027-12-01
# Monthly Income: $4333.33
# Period: 85 BeginBalance: 284133.34 Principal: 350000.00 Interest: 950.10 Payment: 1847.43
# Loan 1 - Begin Balance: $284133.34 Payment: 1847.43
# Period: 37 BeginBalance: 23627.49 Principal: 50000.00 Interest: 244.95 Payment: 1112.22
# Loan 2 - Begin Balance: $23627.49 Payment: 1112.22
# Period: 8 BeginBalance: 72072.26 Principal: 75000.00 Interest: 483.33 Payment: 909.96
# Loan 3 - Begin Balance: $72072.26 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-01-01
# Monthly Income: $4333.33
# Period: 86 BeginBalance: 283233.02 Principal: 350000.00 Interest: 947.11 Payment: 1847.43
# Loan 1 - Begin Balance: $283233.02 Payment: 1847.43
# Period: 38 BeginBalance: 22751.54 Principal: 50000.00 Interest: 236.27 Payment: 1112.22
# Loan 2 - Begin Balance: $22751.54 Payment: 1112.22
# Period: 9 BeginBalance: 71642.78 Principal: 75000.00 Interest: 480.48 Payment: 909.96
# Loan 3 - Begin Balance: $71642.78 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-02-01
# Monthly Income: $4333.33
# Period: 87 BeginBalance: 282329.70 Principal: 350000.00 Interest: 944.11 Payment: 1847.43
# Loan 1 - Begin Balance: $282329.70 Payment: 1847.43
# Period: 39 BeginBalance: 21866.84 Principal: 50000.00 Interest: 227.52 Payment: 1112.22
# Loan 2 - Begin Balance: $21866.84 Payment: 1112.22
# Period: 10 BeginBalance: 71210.44 Principal: 75000.00 Interest: 477.62 Payment: 909.96
# Loan 3 - Begin Balance: $71210.44 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-03-01
# Monthly Income: $4333.33
# Period: 88 BeginBalance: 281423.37 Principal: 350000.00 Interest: 941.10 Payment: 1847.43
# Loan 1 - Begin Balance: $281423.37 Payment: 1847.43
# Period: 40 BeginBalance: 20973.29 Principal: 50000.00 Interest: 218.67 Payment: 1112.22
# Loan 2 - Begin Balance: $20973.29 Payment: 1112.22
# Period: 11 BeginBalance: 70775.22 Principal: 75000.00 Interest: 474.74 Payment: 909.96
# Loan 3 - Begin Balance: $70775.22 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-04-01
# Monthly Income: $4333.33
# Period: 89 BeginBalance: 280514.02 Principal: 350000.00 Interest: 938.08 Payment: 1847.43
# Loan 1 - Begin Balance: $280514.02 Payment: 1847.43
# Period: 41 BeginBalance: 20070.80 Principal: 50000.00 Interest: 209.73 Payment: 1112.22
# Loan 2 - Begin Balance: $20070.80 Payment: 1112.22
# Period: 12 BeginBalance: 70337.09 Principal: 75000.00 Interest: 471.83 Payment: 909.96
# Loan 3 - Begin Balance: $70337.09 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-05-01
# Monthly Income: $4333.33
# Period: 90 BeginBalance: 279601.64 Principal: 350000.00 Interest: 935.05 Payment: 1847.43
# Loan 1 - Begin Balance: $279601.64 Payment: 1847.43
# Period: 42 BeginBalance: 19159.29 Principal: 50000.00 Interest: 200.71 Payment: 1112.22
# Loan 2 - Begin Balance: $19159.29 Payment: 1112.22
# Period: 13 BeginBalance: 69896.04 Principal: 75000.00 Interest: 468.91 Payment: 909.96
# Loan 3 - Begin Balance: $69896.04 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-06-01
# Monthly Income: $4333.33
# Period: 91 BeginBalance: 278686.22 Principal: 350000.00 Interest: 932.01 Payment: 1847.43
# Loan 1 - Begin Balance: $278686.22 Payment: 1847.43
# Period: 43 BeginBalance: 18238.66 Principal: 50000.00 Interest: 191.59 Payment: 1112.22
# Loan 2 - Begin Balance: $18238.66 Payment: 1112.22
# Period: 14 BeginBalance: 69452.05 Principal: 75000.00 Interest: 465.97 Payment: 909.96
# Loan 3 - Begin Balance: $69452.05 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-07-01
# Monthly Income: $4333.33
# Period: 92 BeginBalance: 277767.74 Principal: 350000.00 Interest: 928.95 Payment: 1847.43
# Loan 1 - Begin Balance: $277767.74 Payment: 1847.43
# Period: 44 BeginBalance: 17308.83 Principal: 50000.00 Interest: 182.39 Payment: 1112.22
# Loan 2 - Begin Balance: $17308.83 Payment: 1112.22
# Period: 15 BeginBalance: 69005.10 Principal: 75000.00 Interest: 463.01 Payment: 909.96
# Loan 3 - Begin Balance: $69005.10 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-08-01
# Monthly Income: $4333.33
# Period: 93 BeginBalance: 276846.20 Principal: 350000.00 Interest: 925.89 Payment: 1847.43
# Loan 1 - Begin Balance: $276846.20 Payment: 1847.43
# Period: 45 BeginBalance: 16369.70 Principal: 50000.00 Interest: 173.09 Payment: 1112.22
# Loan 2 - Begin Balance: $16369.70 Payment: 1112.22
# Period: 16 BeginBalance: 68555.17 Principal: 75000.00 Interest: 460.03 Payment: 909.96
# Loan 3 - Begin Balance: $68555.17 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-09-01
# Monthly Income: $4333.33
# Period: 94 BeginBalance: 275921.59 Principal: 350000.00 Interest: 922.82 Payment: 1847.43
# Loan 1 - Begin Balance: $275921.59 Payment: 1847.43
# Period: 46 BeginBalance: 15421.18 Principal: 50000.00 Interest: 163.70 Payment: 1112.22
# Loan 2 - Begin Balance: $15421.18 Payment: 1112.22
# Period: 17 BeginBalance: 68102.24 Principal: 75000.00 Interest: 457.03 Payment: 909.96
# Loan 3 - Begin Balance: $68102.24 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-10-01
# Monthly Income: $4333.33
# Period: 95 BeginBalance: 274993.90 Principal: 350000.00 Interest: 919.74 Payment: 1847.43
# Loan 1 - Begin Balance: $274993.90 Payment: 1847.43
# Period: 47 BeginBalance: 14463.17 Principal: 50000.00 Interest: 154.21 Payment: 1112.22
# Loan 2 - Begin Balance: $14463.17 Payment: 1112.22
# Period: 18 BeginBalance: 67646.29 Principal: 75000.00 Interest: 454.01 Payment: 909.96
# Loan 3 - Begin Balance: $67646.29 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-11-01
# Monthly Income: $4333.33
# Period: 96 BeginBalance: 274063.12 Principal: 350000.00 Interest: 916.65 Payment: 1847.43
# Loan 1 - Begin Balance: $274063.12 Payment: 1847.43
# Period: 48 BeginBalance: 13495.58 Principal: 50000.00 Interest: 144.63 Payment: 1112.22
# Loan 2 - Begin Balance: $13495.58 Payment: 1112.22
# Period: 19 BeginBalance: 67187.31 Principal: 75000.00 Interest: 450.98 Payment: 909.96
# Loan 3 - Begin Balance: $67187.31 Payment: 909.96
# Income Remaining: $-36.28
#
#  2028-12-01
# Monthly Income: $4333.33
# Period: 97 BeginBalance: 273129.23 Principal: 350000.00 Interest: 913.54 Payment: 1847.43
# Loan 1 - Begin Balance: $273129.23 Payment: 1847.43
# Period: 49 BeginBalance: 12518.32 Principal: 50000.00 Interest: 134.96 Payment: 1112.22
# Loan 2 - Begin Balance: $12518.32 Payment: 1112.22
# Period: 20 BeginBalance: 66725.27 Principal: 75000.00 Interest: 447.92 Payment: 909.96
# Loan 3 - Begin Balance: $66725.27 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-01-01
# Monthly Income: $4333.33
# Period: 98 BeginBalance: 272192.23 Principal: 350000.00 Interest: 910.43 Payment: 1847.43
# Loan 1 - Begin Balance: $272192.23 Payment: 1847.43
# Period: 50 BeginBalance: 11531.28 Principal: 50000.00 Interest: 125.18 Payment: 1112.22
# Loan 2 - Begin Balance: $11531.28 Payment: 1112.22
# Period: 21 BeginBalance: 66260.15 Principal: 75000.00 Interest: 444.84 Payment: 909.96
# Loan 3 - Begin Balance: $66260.15 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-02-01
# Monthly Income: $4333.33
# Period: 99 BeginBalance: 271252.11 Principal: 350000.00 Interest: 907.31 Payment: 1847.43
# Loan 1 - Begin Balance: $271252.11 Payment: 1847.43
# Period: 51 BeginBalance: 10534.37 Principal: 50000.00 Interest: 115.31 Payment: 1112.22
# Loan 2 - Begin Balance: $10534.37 Payment: 1112.22
# Period: 22 BeginBalance: 65791.92 Principal: 75000.00 Interest: 441.73 Payment: 909.96
# Loan 3 - Begin Balance: $65791.92 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-03-01
# Monthly Income: $4333.33
# Period: 100 BeginBalance: 270308.85 Principal: 350000.00 Interest: 904.17 Payment: 1847.43
# Loan 1 - Begin Balance: $270308.85 Payment: 1847.43
# Period: 52 BeginBalance: 9527.49 Principal: 50000.00 Interest: 105.34 Payment: 1112.22
# Loan 2 - Begin Balance: $9527.49 Payment: 1112.22
# Period: 23 BeginBalance: 65320.57 Principal: 75000.00 Interest: 438.61 Payment: 909.96
# Loan 3 - Begin Balance: $65320.57 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-04-01
# Monthly Income: $4333.33
# Increased 1 balance by $2000
# Period: 101 BeginBalance: 271369.12 Principal: 350000.00 Interest: 907.70 Payment: 1847.43
# Loan 1 - Begin Balance: $271369.12 Payment: 1847.43
# Period: 53 BeginBalance: 8510.54 Principal: 50000.00 Interest: 95.27 Payment: 1112.22
# Loan 2 - Begin Balance: $8510.54 Payment: 1112.22
# Period: 24 BeginBalance: 64846.08 Principal: 75000.00 Interest: 435.47 Payment: 909.96
# Loan 3 - Begin Balance: $64846.08 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-05-01
# Monthly Income: $4333.33
# Period: 102 BeginBalance: 270426.25 Principal: 350000.00 Interest: 904.56 Payment: 1847.43
# Loan 1 - Begin Balance: $270426.25 Payment: 1847.43
# Period: 54 BeginBalance: 7483.43 Principal: 50000.00 Interest: 85.11 Payment: 1112.22
# Loan 2 - Begin Balance: $7483.43 Payment: 1112.22
# Period: 25 BeginBalance: 64368.43 Principal: 75000.00 Interest: 432.31 Payment: 909.96
# Loan 3 - Begin Balance: $64368.43 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-06-01
# Monthly Income: $4333.33
# Period: 103 BeginBalance: 269480.24 Principal: 350000.00 Interest: 901.42 Payment: 1847.43
# Loan 1 - Begin Balance: $269480.24 Payment: 1847.43
# Period: 55 BeginBalance: 6446.04 Principal: 50000.00 Interest: 74.83 Payment: 1112.22
# Loan 2 - Begin Balance: $6446.04 Payment: 1112.22
# Period: 26 BeginBalance: 63887.59 Principal: 75000.00 Interest: 429.12 Payment: 909.96
# Loan 3 - Begin Balance: $63887.59 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-07-01
# Monthly Income: $4333.33
# Period: 104 BeginBalance: 268531.08 Principal: 350000.00 Interest: 898.27 Payment: 1847.43
# Loan 1 - Begin Balance: $268531.08 Payment: 1847.43
# Period: 56 BeginBalance: 5398.28 Principal: 50000.00 Interest: 64.46 Payment: 1112.22
# Loan 2 - Begin Balance: $5398.28 Payment: 1112.22
# Period: 27 BeginBalance: 63403.55 Principal: 75000.00 Interest: 425.92 Payment: 909.96
# Loan 3 - Begin Balance: $63403.55 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-08-01
# Monthly Income: $4333.33
# Period: 105 BeginBalance: 267578.75 Principal: 350000.00 Interest: 895.10 Payment: 1847.43
# Loan 1 - Begin Balance: $267578.75 Payment: 1847.43
# Period: 57 BeginBalance: 4340.04 Principal: 50000.00 Interest: 53.98 Payment: 1112.22
# Loan 2 - Begin Balance: $4340.04 Payment: 1112.22
# Period: 28 BeginBalance: 62916.28 Principal: 75000.00 Interest: 422.69 Payment: 909.96
# Loan 3 - Begin Balance: $62916.28 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-09-01
# Monthly Income: $4333.33
# Period: 106 BeginBalance: 266623.25 Principal: 350000.00 Interest: 891.93 Payment: 1847.43
# Loan 1 - Begin Balance: $266623.25 Payment: 1847.43
# Period: 58 BeginBalance: 3271.22 Principal: 50000.00 Interest: 43.40 Payment: 1112.22
# Loan 2 - Begin Balance: $3271.22 Payment: 1112.22
# Period: 29 BeginBalance: 62425.76 Principal: 75000.00 Interest: 419.44 Payment: 909.96
# Loan 3 - Begin Balance: $62425.76 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-10-01
# Monthly Income: $4333.33
# Period: 107 BeginBalance: 265664.56 Principal: 350000.00 Interest: 888.74 Payment: 1847.43
# Loan 1 - Begin Balance: $265664.56 Payment: 1847.43
# Period: 59 BeginBalance: 2191.71 Principal: 50000.00 Interest: 32.71 Payment: 1112.22
# Loan 2 - Begin Balance: $2191.71 Payment: 1112.22
# Period: 30 BeginBalance: 61931.97 Principal: 75000.00 Interest: 416.17 Payment: 909.96
# Loan 3 - Begin Balance: $61931.97 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-11-01
# Monthly Income: $4333.33
# Increased 1 balance by $3000
# Period: 108 BeginBalance: 267712.68 Principal: 350000.00 Interest: 895.55 Payment: 1847.43
# Loan 1 - Begin Balance: $267712.68 Payment: 1847.43
# Period: 60 BeginBalance: 1101.41 Principal: 50000.00 Interest: 21.92 Payment: 1112.22
# Loan 2 - Begin Balance: $1101.41 Payment: 1112.22
# Period: 31 BeginBalance: 61434.89 Principal: 75000.00 Interest: 412.88 Payment: 909.96
# Loan 3 - Begin Balance: $61434.89 Payment: 909.96
# Income Remaining: $-36.28
#
#  2029-12-01
# Monthly Income: $4333.33
# Period: 109 BeginBalance: 266757.63 Principal: 350000.00 Interest: 892.38 Payment: 1847.43
# Loan 1 - Begin Balance: $266757.63 Payment: 1847.43
# Period: 61 BeginBalance: 0.20 Principal: 50000.00 Interest: 11.01 Payment: 1112.22
# Loan 2 - Begin Balance: $0.20 Payment: 1112.22
# Period: 32 BeginBalance: 60934.50 Principal: 75000.00 Interest: 409.57 Payment: 909.96
# Loan 3 - Begin Balance: $60934.50 Payment: 909.96
# Income Remaining: $-36.28
#
#  2030-01-01
# Monthly Income: $4333.33
# Period: 110 BeginBalance: 265799.39 Principal: 350000.00 Interest: 889.19 Payment: 1847.43
# Loan 1 - Begin Balance: $265799.39 Payment: 1847.43
# Period: 62 BeginBalance: 0.00 Principal: 50000.00 Interest: 0.00 Payment: 0.20
# LOAN 2 PAID OFF!
# Period: 33 BeginBalance: 60430.77 Principal: 75000.00 Interest: 406.23 Payment: 909.96
# Loan 3 - Begin Balance: $60430.77 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-02-01
# Monthly Income: $4333.33
# Period: 111 BeginBalance: 264837.96 Principal: 350000.00 Interest: 886.00 Payment: 1847.43
# Loan 1 - Begin Balance: $264837.96 Payment: 1847.43
# Period: 34 BeginBalance: 59923.68 Principal: 75000.00 Interest: 402.87 Payment: 909.96
# Loan 3 - Begin Balance: $59923.68 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-03-01
# Monthly Income: $4333.33
# Period: 112 BeginBalance: 263873.32 Principal: 350000.00 Interest: 882.79 Payment: 1847.43
# Loan 1 - Begin Balance: $263873.32 Payment: 1847.43
# Period: 35 BeginBalance: 59413.21 Principal: 75000.00 Interest: 399.49 Payment: 909.96
# Loan 3 - Begin Balance: $59413.21 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-04-01
# Monthly Income: $4333.33
# Period: 113 BeginBalance: 262905.47 Principal: 350000.00 Interest: 879.58 Payment: 1847.43
# Loan 1 - Begin Balance: $262905.47 Payment: 1847.43
# Period: 36 BeginBalance: 58899.34 Principal: 75000.00 Interest: 396.09 Payment: 909.96
# Loan 3 - Begin Balance: $58899.34 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-05-01
# Monthly Income: $4333.33
# Period: 114 BeginBalance: 261934.39 Principal: 350000.00 Interest: 876.35 Payment: 1847.43
# Loan 1 - Begin Balance: $261934.39 Payment: 1847.43
# Period: 37 BeginBalance: 58382.04 Principal: 75000.00 Interest: 392.66 Payment: 909.96
# Loan 3 - Begin Balance: $58382.04 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-06-01
# Monthly Income: $4333.33
# Period: 115 BeginBalance: 260960.07 Principal: 350000.00 Interest: 873.11 Payment: 1847.43
# Loan 1 - Begin Balance: $260960.07 Payment: 1847.43
# Period: 38 BeginBalance: 57861.29 Principal: 75000.00 Interest: 389.21 Payment: 909.96
# Loan 3 - Begin Balance: $57861.29 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-07-01
# Monthly Income: $4333.33
# Period: 116 BeginBalance: 259982.51 Principal: 350000.00 Interest: 869.87 Payment: 1847.43
# Loan 1 - Begin Balance: $259982.51 Payment: 1847.43
# Period: 39 BeginBalance: 57337.07 Principal: 75000.00 Interest: 385.74 Payment: 909.96
# Loan 3 - Begin Balance: $57337.07 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-08-01
# Monthly Income: $4333.33
# Period: 117 BeginBalance: 259001.69 Principal: 350000.00 Interest: 866.61 Payment: 1847.43
# Loan 1 - Begin Balance: $259001.69 Payment: 1847.43
# Period: 40 BeginBalance: 56809.36 Principal: 75000.00 Interest: 382.25 Payment: 909.96
# Loan 3 - Begin Balance: $56809.36 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-09-01
# Monthly Income: $4333.33
# Period: 118 BeginBalance: 258017.60 Principal: 350000.00 Interest: 863.34 Payment: 1847.43
# Loan 1 - Begin Balance: $258017.60 Payment: 1847.43
# Period: 41 BeginBalance: 56278.13 Principal: 75000.00 Interest: 378.73 Payment: 909.96
# Loan 3 - Begin Balance: $56278.13 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-10-01
# Monthly Income: $4333.33
# Period: 119 BeginBalance: 257030.23 Principal: 350000.00 Interest: 860.06 Payment: 1847.43
# Loan 1 - Begin Balance: $257030.23 Payment: 1847.43
# Period: 42 BeginBalance: 55743.36 Principal: 75000.00 Interest: 375.19 Payment: 909.96
# Loan 3 - Begin Balance: $55743.36 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-11-01
# Monthly Income: $4333.33
# Period: 120 BeginBalance: 256039.57 Principal: 350000.00 Interest: 856.77 Payment: 1847.43
# Loan 1 - Begin Balance: $256039.57 Payment: 1847.43
# Period: 43 BeginBalance: 55205.02 Principal: 75000.00 Interest: 371.62 Payment: 909.96
# Loan 3 - Begin Balance: $55205.02 Payment: 909.96
# Income Remaining: $1075.94
#
#  2030-12-01
# Monthly Income: $4333.33
# Period: 121 BeginBalance: 255045.61 Principal: 350000.00 Interest: 853.47 Payment: 1847.43
# Loan 1 - Begin Balance: $255045.61 Payment: 1847.43
# Period: 44 BeginBalance: 54663.09 Principal: 75000.00 Interest: 368.03 Payment: 909.96
# Loan 3 - Begin Balance: $54663.09 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-01-01
# Monthly Income: $4333.33
# Period: 122 BeginBalance: 254048.33 Principal: 350000.00 Interest: 850.15 Payment: 1847.43
# Loan 1 - Begin Balance: $254048.33 Payment: 1847.43
# Period: 45 BeginBalance: 54117.55 Principal: 75000.00 Interest: 364.42 Payment: 909.96
# Loan 3 - Begin Balance: $54117.55 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-02-01
# Monthly Income: $4333.33
# Period: 123 BeginBalance: 253047.73 Principal: 350000.00 Interest: 846.83 Payment: 1847.43
# Loan 1 - Begin Balance: $253047.73 Payment: 1847.43
# Period: 46 BeginBalance: 53568.37 Principal: 75000.00 Interest: 360.78 Payment: 909.96
# Loan 3 - Begin Balance: $53568.37 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-03-01
# Monthly Income: $4333.33
# Period: 124 BeginBalance: 252043.79 Principal: 350000.00 Interest: 843.49 Payment: 1847.43
# Loan 1 - Begin Balance: $252043.79 Payment: 1847.43
# Period: 47 BeginBalance: 53015.53 Principal: 75000.00 Interest: 357.12 Payment: 909.96
# Loan 3 - Begin Balance: $53015.53 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-04-01
# Monthly Income: $4333.33
# Period: 125 BeginBalance: 251036.51 Principal: 350000.00 Interest: 840.15 Payment: 1847.43
# Loan 1 - Begin Balance: $251036.51 Payment: 1847.43
# Period: 48 BeginBalance: 52459.01 Principal: 75000.00 Interest: 353.44 Payment: 909.96
# Loan 3 - Begin Balance: $52459.01 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-05-01
# Monthly Income: $4333.33
# Period: 126 BeginBalance: 250025.87 Principal: 350000.00 Interest: 836.79 Payment: 1847.43
# Loan 1 - Begin Balance: $250025.87 Payment: 1847.43
# Period: 49 BeginBalance: 51898.78 Principal: 75000.00 Interest: 349.73 Payment: 909.96
# Loan 3 - Begin Balance: $51898.78 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-06-01
# Monthly Income: $4333.33
# Period: 127 BeginBalance: 249011.86 Principal: 350000.00 Interest: 833.42 Payment: 1847.43
# Loan 1 - Begin Balance: $249011.86 Payment: 1847.43
# Period: 50 BeginBalance: 51334.81 Principal: 75000.00 Interest: 345.99 Payment: 909.96
# Loan 3 - Begin Balance: $51334.81 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-07-01
# Monthly Income: $4333.33
# Period: 128 BeginBalance: 247994.47 Principal: 350000.00 Interest: 830.04 Payment: 1847.43
# Loan 1 - Begin Balance: $247994.47 Payment: 1847.43
# Period: 51 BeginBalance: 50767.08 Principal: 75000.00 Interest: 342.23 Payment: 909.96
# Loan 3 - Begin Balance: $50767.08 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-08-01
# Monthly Income: $4333.33
# Period: 129 BeginBalance: 246973.69 Principal: 350000.00 Interest: 826.65 Payment: 1847.43
# Loan 1 - Begin Balance: $246973.69 Payment: 1847.43
# Period: 52 BeginBalance: 50195.57 Principal: 75000.00 Interest: 338.45 Payment: 909.96
# Loan 3 - Begin Balance: $50195.57 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-09-01
# Monthly Income: $4333.33
# Period: 130 BeginBalance: 245949.51 Principal: 350000.00 Interest: 823.25 Payment: 1847.43
# Loan 1 - Begin Balance: $245949.51 Payment: 1847.43
# Period: 53 BeginBalance: 49620.25 Principal: 75000.00 Interest: 334.64 Payment: 909.96
# Loan 3 - Begin Balance: $49620.25 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-10-01
# Monthly Income: $4333.33
# Period: 131 BeginBalance: 244921.91 Principal: 350000.00 Interest: 819.83 Payment: 1847.43
# Loan 1 - Begin Balance: $244921.91 Payment: 1847.43
# Period: 54 BeginBalance: 49041.09 Principal: 75000.00 Interest: 330.80 Payment: 909.96
# Loan 3 - Begin Balance: $49041.09 Payment: 909.96
# Income Remaining: $1075.94
#
#  2031-11-01
# Monthly Income: $4333.33
# Period: 132 BeginBalance: 243890.89 Principal: 350000.00 Interest: 816.41 Payment: 1847.43
# Loan 1 - Begin Balance: $243890.89 Payment: 1847.43
# ...
# Income Remaining: $1985.90
#
#  2044-02-01
# Monthly Income: $4333.33
# Period: 279 BeginBalance: 51419.91 Principal: 350000.00 Interest: 176.97 Payment: 1847.43
# Loan 1 - Begin Balance: $51419.91 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-03-01
# Monthly Income: $4333.33
# Period: 280 BeginBalance: 49743.88 Principal: 350000.00 Interest: 171.40 Payment: 1847.43
# Loan 1 - Begin Balance: $49743.88 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-04-01
# Monthly Income: $4333.33
# Period: 281 BeginBalance: 48062.26 Principal: 350000.00 Interest: 165.81 Payment: 1847.43
# Loan 1 - Begin Balance: $48062.26 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-05-01
# Monthly Income: $4333.33
# Period: 282 BeginBalance: 46375.04 Principal: 350000.00 Interest: 160.21 Payment: 1847.43
# Loan 1 - Begin Balance: $46375.04 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-06-01
# Monthly Income: $4333.33
# Period: 283 BeginBalance: 44682.19 Principal: 350000.00 Interest: 154.58 Payment: 1847.43
# Loan 1 - Begin Balance: $44682.19 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-07-01
# Monthly Income: $4333.33
# Period: 284 BeginBalance: 42983.70 Principal: 350000.00 Interest: 148.94 Payment: 1847.43
# Loan 1 - Begin Balance: $42983.70 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-08-01
# Monthly Income: $4333.33
# Period: 285 BeginBalance: 41279.55 Principal: 350000.00 Interest: 143.28 Payment: 1847.43
# Loan 1 - Begin Balance: $41279.55 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-09-01
# Monthly Income: $4333.33
# Period: 286 BeginBalance: 39569.72 Principal: 350000.00 Interest: 137.60 Payment: 1847.43
# Loan 1 - Begin Balance: $39569.72 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-10-01
# Monthly Income: $4333.33
# Period: 287 BeginBalance: 37854.19 Principal: 350000.00 Interest: 131.90 Payment: 1847.43
# Loan 1 - Begin Balance: $37854.19 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-11-01
# Monthly Income: $4333.33
# Period: 288 BeginBalance: 36132.94 Principal: 350000.00 Interest: 126.18 Payment: 1847.43
# Loan 1 - Begin Balance: $36132.94 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2044-12-01
# Monthly Income: $4333.33
# Period: 289 BeginBalance: 34405.95 Principal: 350000.00 Interest: 120.44 Payment: 1847.43
# Loan 1 - Begin Balance: $34405.95 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-01-01
# Monthly Income: $4333.33
# Period: 290 BeginBalance: 32673.21 Principal: 350000.00 Interest: 114.69 Payment: 1847.43
# Loan 1 - Begin Balance: $32673.21 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-02-01
# Monthly Income: $4333.33
# Period: 291 BeginBalance: 30934.69 Principal: 350000.00 Interest: 108.91 Payment: 1847.43
# Loan 1 - Begin Balance: $30934.69 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-03-01
# Monthly Income: $4333.33
# Period: 292 BeginBalance: 29190.38 Principal: 350000.00 Interest: 103.12 Payment: 1847.43
# Loan 1 - Begin Balance: $29190.38 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-04-01
# Monthly Income: $4333.33
# Period: 293 BeginBalance: 27440.25 Principal: 350000.00 Interest: 97.30 Payment: 1847.43
# Loan 1 - Begin Balance: $27440.25 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-05-01
# Monthly Income: $4333.33
# Period: 294 BeginBalance: 25684.29 Principal: 350000.00 Interest: 91.47 Payment: 1847.43
# Loan 1 - Begin Balance: $25684.29 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-06-01
# Monthly Income: $4333.33
# Period: 295 BeginBalance: 23922.47 Principal: 350000.00 Interest: 85.61 Payment: 1847.43
# Loan 1 - Begin Balance: $23922.47 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-07-01
# Monthly Income: $4333.33
# Period: 296 BeginBalance: 22154.78 Principal: 350000.00 Interest: 79.74 Payment: 1847.43
# Loan 1 - Begin Balance: $22154.78 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-08-01
# Monthly Income: $4333.33
# Period: 297 BeginBalance: 20381.20 Principal: 350000.00 Interest: 73.85 Payment: 1847.43
# Loan 1 - Begin Balance: $20381.20 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-09-01
# Monthly Income: $4333.33
# Period: 298 BeginBalance: 18601.71 Principal: 350000.00 Interest: 67.94 Payment: 1847.43
# Loan 1 - Begin Balance: $18601.71 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-10-01
# Monthly Income: $4333.33
# Period: 299 BeginBalance: 16816.29 Principal: 350000.00 Interest: 62.01 Payment: 1847.43
# Loan 1 - Begin Balance: $16816.29 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-11-01
# Monthly Income: $4333.33
# Period: 300 BeginBalance: 15024.91 Principal: 350000.00 Interest: 56.05 Payment: 1847.43
# Loan 1 - Begin Balance: $15024.91 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2045-12-01
# Monthly Income: $4333.33
# Period: 301 BeginBalance: 13227.56 Principal: 350000.00 Interest: 50.08 Payment: 1847.43
# Loan 1 - Begin Balance: $13227.56 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-01-01
# Monthly Income: $4333.33
# Period: 302 BeginBalance: 11424.22 Principal: 350000.00 Interest: 44.09 Payment: 1847.43
# Loan 1 - Begin Balance: $11424.22 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-02-01
# Monthly Income: $4333.33
# Period: 303 BeginBalance: 9614.87 Principal: 350000.00 Interest: 38.08 Payment: 1847.43
# Loan 1 - Begin Balance: $9614.87 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-03-01
# Monthly Income: $4333.33
# Period: 304 BeginBalance: 7799.49 Principal: 350000.00 Interest: 32.05 Payment: 1847.43
# Loan 1 - Begin Balance: $7799.49 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-04-01
# Monthly Income: $4333.33
# Period: 305 BeginBalance: 5978.06 Principal: 350000.00 Interest: 26.00 Payment: 1847.43
# Loan 1 - Begin Balance: $5978.06 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-05-01
# Monthly Income: $4333.33
# Period: 306 BeginBalance: 4150.56 Principal: 350000.00 Interest: 19.93 Payment: 1847.43
# Loan 1 - Begin Balance: $4150.56 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-06-01
# Monthly Income: $4333.33
# Period: 307 BeginBalance: 2316.97 Principal: 350000.00 Interest: 13.84 Payment: 1847.43
# Loan 1 - Begin Balance: $2316.97 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-07-01
# Monthly Income: $4333.33
# Period: 308 BeginBalance: 477.26 Principal: 350000.00 Interest: 7.72 Payment: 1847.43
# Loan 1 - Begin Balance: $477.26 Payment: 1847.43
# Income Remaining: $1985.90
#
#  2046-08-01
# Monthly Income: $4333.33
# Period: 309 BeginBalance: 0.00 Principal: 350000.00 Interest: 1.59 Payment: 478.85
# LOAN 1 PAID OFF!
# Income Remaining: $3833.33
#
#  2046-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2046-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2046-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2046-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2047-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2048-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2049-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2050-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2051-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2052-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2053-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2054-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2055-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2056-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#  2057-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2057-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-01-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-02-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-03-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-04-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-05-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-06-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-07-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-08-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-09-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-10-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-11-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33
#
#  2058-12-01
# Monthly Income: $4333.33
# Income Remaining: $3833.33

# %%
myProfile.summary()
# Out:
# Tyler is 65 years old and has income of $4333.33 per month.

# %%
myProfile.loanInfo()
# Out:
# Loan 1 has principal of $350000 over duration 25 years with expected finish date of 2046-01-01 - remaining balance: $0.0
# Loan 2 has principal of $50000 over duration 5 years with expected finish date of 2030-01-01 - remaining balance: $0.0
# Loan 3 has principal of $75000 over duration 10 years with expected finish date of 2037-06-01 - remaining balance: $0.0

# %%
for loanID, _ in myProfile.loanDict.items():
    
    plt.plot(myProfile.loanDict[loanID].dateHistory, myProfile.loanDict[loanID].loanHistory)

# %%
myProfile.loanDict['2'].loanPaidOff
# Out:
# True

# %%
print('Loan 1')
print('Start Date:', myProfile.loanDict['1'].startDate)
print('Expected End Date:', myProfile.loanDict['1'].endDate)
print('Finish Date:', myProfile.loanDict['1'].loanPaidOffDate)
# Out:
# Loan 1
# Start Date: 2021-01-01
# Expected End Date: 2046-01-01
# Finish Date: 2046-08-01

# %%
print('Loan 2')
print('Start Date:', myProfile.loanDict['2'].startDate)
print('Expected End Date:', myProfile.loanDict['2'].endDate)
print('Finish Date:', myProfile.loanDict['2'].loanPaidOffDate)
# Out:
# Loan 2
# Start Date: 2025-01-01
# Expected End Date: 2030-01-01
# Finish Date: 2030-01-01

# %%
print('Loan 3')
print('Start Date:', myProfile.loanDict['3'].startDate)
print('Expected End Date:', myProfile.loanDict['3'].endDate)
print('Finish Date:', myProfile.loanDict['3'].loanPaidOffDate)
# Out:
# Loan 3
# Start Date: 2027-06-01
# Expected End Date: 2037-06-01
# Finish Date: 2037-07-01

# %%
plt.plot(myProfile.dateHistory, myProfile.incomeHistory)
plt.title('Remaining Income')
plt.xlabel('Year')
plt.ylabel('$ Amount')
# Out:
# Text(0, 0.5, '$ Amount')
