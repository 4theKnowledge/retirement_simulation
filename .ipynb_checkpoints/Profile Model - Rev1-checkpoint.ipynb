# %% [markdown]
# ## Object oriented profile design for use in personal financial forecasting simulation tool

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import datetime
from dateutil.relativedelta import relativedelta
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [raw]
# class Simulation():
#     """
#     Simulation class. Used for simulation functions and data capture.
#     """
#
#     def __init__(self):
#         self.dateHistory = []

# %%
class Superannuation():
    """
    Note: Assumes superannuation is run via an institution and is not self managed.
    
    """
    
    def __init__(self, contribRate):
        self.superContrib = 0
        self.superInitialBal = 1000   # initial super balance
        self.superReturnRate = 0.06 / 12
        
        self.contribRate = contribRate   # Employer contribution rate
        
        # Cumulative Sum of Super Balance and Value
        self.superBalCumSum = 0
        self.superValCumSum = 0
        
    def superFees(self, phase):
        if phase == 1:
            # phase 1 - before retirement
            self.contribFee = 1/12
        if phase == 2:
            # phase 2 - retirement
            self.contribFee = 0
        self.adminFee = 100
        self.investmentFee = 1/12
        self.insurancePrem = 1/12
        self.indirectCosts = 0.2/12
        self.superFeesTotal = 0
        
        self.superFeesTotal = self.adminFee + self.investmentFee * self.superContrib + \
                            self.contribFee * self.superContrib + self.insurancePrem * self.superContrib + \
                            self.indirectCosts * self.superContrib
        print(f'Super Fees: ${self.superFeesTotal:0.2f}')
        
    def superValue(self, phase):
        
        if self.superBalCumSum == 0:
            print('adding initial value to superVal')
            self.superValCumSum += self.superContrib + self.superInitialBal
        elif phase == 1:
#             print(f'{self.superValCumSum}-{self.superContrib}-{self.superFeesTotal}-{1 + self.superReturnRate}')
            
            self.superValCumSum = (self.superValCumSum + self.superContrib - self.superFeesTotal) * (1 + self.superReturnRate)
        elif phase == 2:
            self.superValCumSum = (self.superValCumSum - self.drawdownAmt - self.superFeesTotal) * (1 + self.superReturnRate)
        
        print(f'Super Value: ${self.superValCumSum:0.2f}')
        
        
    def superBalance(self):
        
        if self.superBalCumSum == 0:
            print('adding initial value to superBal')
            self.superBalCumSum += self.superContrib + self.superInitialBal
        else:
            self.superBalCumSum += self.superContrib - self.superFeesTotal
        
        print(f'Super Balance: ${self.superBalCumSum:0.2f}')
        
    def superContribution(self, phase, income):
        # Monthly income...
        self.superContrib = self.contribRate * income
        print(f'Super Contribution: ${self.superContrib:0.2f}')
        
        self.superFees(phase)
        self.superValue(phase)
        self.superBalance()
        
        
    def superDrawDown(self):
        # Drawdown once retirement starts and contributions cease
        retirementIncome = 25000
        self.drawdownAmt = retirementIncome / 12
        
        self.superContribution(2, 0)   # no income within phase 2

# %%
class Tax():
    """
    Model for taxing income.
    Calculates tax on gross annual income.
    Note: Tax rates are current as of 2019-2020 and sourced from the ATO.
    """
    
    def __init__(self):
        self.tax_table_income = {1: [0, 18200],
                    2: [18201, 37000],
                    3: [37001, 90000],
                    4: [90001, 180000],
                    5: [180001, 1000000000]}   # ridiculous upper limit

        self.tax_table_paymt = {1: [0, 0],
                        2: [0.19, 0],
                        3: [0.325, 3572],
                        4: [0.37, 20797],
                        5: [0.45, 54097]}
    
    def getTaxAmount(self, income):
        
        income = income * 12 # input is per month...
        
        for key, value in self.tax_table_income.items():
            if value[0] <= income <= value[1]:
                tax_to_pay = self.tax_table_paymt[key][1] + self.tax_table_paymt[key][0] * \
                (income - self.tax_table_income[key][0])
                
        monthlyIncomeTax = tax_to_pay / 12
        
        return monthlyIncomeTax

# %%
class Savings():
    """
    Model for savings.
    """
    
    def __init__(self, proportionSaved):
        self.proportionSaved = proportionSaved
        
        
        # data capture
        self.dataHistory = []
        self.savingHistory = []
        
    def getSavedAmount(self, remainingIncome):
        """
        Gets amount saved from remainingIncome
        """
        if remainingIncome > 0:
            return remainingIncome*self.proportionSaved
        else: 
            return 0
        
    # Data Capture Functions
    def getSavingHistory(self, date, savingInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.savingHistory.append(savingInfo)

# %%
class Expenses():
    """
    Model for general expenses.
    """
    
    def __init__(self, expenses):
        # Everything is on a monthly basis in the model...
        self.expenses = expenses
        
    def increaseExpenseRandomly(self, phase):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """

        expensesTemp = 0
        if (0.5 < np.random.uniform(0,1)):
            if phase == 2:
                increaseAmt = np.random.uniform(0.8, 1.2)*(self.expenses / 2)
            else:
                increaseAmt = np.random.uniform(0.8, 1.2)*(self.expenses / 2)
            
            print(f'Expense balance: ${increaseAmt:0.2f}')
            return increaseAmt
        else:
            print('Expense remains unchanged from', self.expenses)
            return self.expenses

# %%
class Income():
    """
    Model for income (earned, passive, portfolio).
    """
    
    def __init__(self, income):
        # Everything is on a monthly basis in the model...
        self.income = income
        self.remainingIncome = self.income    # init
        self.dateHistory = []
        self.incomeHistory = []

        
    def incomeAfterCosts(self, loanPaymentSum):
        """
        Aggregated Monthly.
        """
        costs = loanPaymentSum
        self.remainingIncome = self.income - costs
        
    def getIncomeHistory(self, date, incomeInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.incomeHistory.append(incomeInfo)

# %%
class Loan():
    """
    Model for user profile loans.
    """
    
    def __init__(self, loanID, principal, interestRate, annualPayments, duration, startDate):
        self.principal = principal
        self.interestRate = interestRate
        self.annualPayments = annualPayments
        self.duration = duration
        self.startDate = datetime.datetime.strptime(startDate, '%d-%m-%Y').date()
        self.loanID = loanID
        self.period = 1
        self.endDate = (self.startDate + relativedelta(years=self.duration))
        self.beginBalance = self.principal
        self.endBalance = self.principal
        self.loanPaidOff = False
        self.loanPaidOffDate = 'Not paid off - Active'
        self.loanActive = False
        
        # First loan payment amount
        self.loanPayment = -round(np.pmt(self.interestRate/self.annualPayments, self.duration*self.annualPayments, self.principal), 2)      
    
        # For data capture
        self.dateHistory = []
        self.loanHistory = []
    
    def initDesc(self):
        return f'''Loan {self.loanID} has principal of ${self.principal} over duration {self.duration} years with expected finish date of {self.endDate} - remaining balance: ${self.endBalance}'''
    
    # Main Functions
    def makePayment(self):
        """
        Make a payment against the principal.
        """
        self.loanActive = True
        self.interest = round(((self.interestRate/self.annualPayments) * self.beginBalance), 2)
        self.loanPayment = min(self.loanPayment, self.beginBalance + self.interest)
        self.endBalance = self.beginBalance - (self.loanPayment - self.interest)
        self.period += 1
        self.beginBalance = self.endBalance
        
    def paymentSummary(self):
        try:
            print(f'Period: {self.period} BeginBalance: {self.beginBalance:0.2f} Principal: {self.principal:0.2f} Interest: {self.interest:0.2f} Payment: {self.loanPayment:0.2f}')
        except:
            print('Not enough information. Loan has likely not become active.')

    def loanFinished(self, date):
        """
        Used when a loan is finished.
        """
        #TODO: Add date for when loan finishes... as this may not be constant...
        self.loanPaidOff = True
        self.loanActive = False
        self.loanPaidOffDate = date
    
    # Misc Functions
    def increasePrincipal(self, increaseAmt):
        """
        Increase the amount of loan principal via month begin balance.
        """
        self.beginBalance += increaseAmt
        
    def increasePrincipalRandomly(self):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """
        if (0.99 < np.random.uniform(0,1)) and self.loanActive:
            if self.loanPaidOff == False:
                increaseAmt = np.random.randint(0,10)*1000
                self.beginBalance += increaseAmt
                print(f'Increased {self.loanID} balance by ${increaseAmt}')       
        
    # Data Capture Functions
    def getLoanHistory(self, date, loanInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.loanHistory.append(loanInfo)

# %%
class Profile(Income, Expenses, Savings, Tax, Superannuation):
    """
    Profile for user. Contains their general information and meta data for financial modeling.
    """
    
    # Initializer / Instance Attributes
    def __init__(self, name, age, retireAge, deadAge, incomePA, expensesPM, proportionSaved):
        self.name = name
        self.age = age
        self.retireAge = retireAge
        self.deadAge = deadAge
        # Loans
        self.hasLoan = False
        self.loanDict = {}
        self.noLoans = 0
        self.loanPaymentSum = 0
        # Income
        self.hasIncome = False
        self.income = incomePA / 12
        self.hasIncome = True
        # Expenses
        self.expenses = expensesPM    # Expenses per month
        # Savings
        self.proportionSaved = proportionSaved

        
        # Inherit Loan init.. by inheriting this class, we can access it's attributes and methods...
        Income.__init__(self, self.income)  # pass attribute to class
        
        # Init Expenses
        Expenses.__init__(self, self.expenses)
        
        
        # Init Savings
        Savings.__init__(self, self.proportionSaved)
        
        # Init Tax
        Tax.__init__(self)
        
        # init super
        Superannuation.__init__(self, 0.095)
        
        
    # Profile
    def ageStep(self, year):
        """
        Used to age the users profile and step through time.
        """
        self.age += year
    
    def summary(self):
        print(f'{self.name} is {self.age} years old and has income of ${self.income:0.2f} per month.')
    
    # Loan
    def getLoan(self, principal, interestRate, annualPayments, duration, startDate):
        """
        Allocates a loan to the profile.
        """
        self.hasLoan = True
        self.noLoans += 1
        print(f'Number of loans: {self.noLoans}')
        loanID = str(self.noLoans)
        self.loanDict[loanID] = Loan(loanID, principal, interestRate, annualPayments, duration, startDate)
        
    def removeLoan(self, loanID):
        """
        Removes a loan from the profile. TODO: update to remove once paid off.
        """
        try:
            del self.loanDict[loanID]
        except:
            print('Loan doesnt exist')
            
    def loanDesc(self):
        """
        Summary of active loans.
        """
        self.currentLoans = len(self.loanDict)
        try:
            return f'Current active loans for {self.name}: {self.currentLoans}'
        except:
            return f'{self.name} has no loan'
        
    def loanInfo(self):
        """
        Detailed description of loan dict. For debugging purposes.
        """
        for loanID, loanDetails in self.loanDict.items():
            print(f'{loanDetails.initDesc()}')

# %% [markdown]
# # Get basic profile information and Initiate Profile

# %%
def init_profile():
    myProfile = Profile('Tyler', 26, 65, 80, 52000, 500, 0.25)
    
    myProfile.summary()

    # Loan 1 - mortgage
    myProfile.getLoan(300000, 0.04, 12, 25, '1-1-2021')
    # Loan 2 - car
    myProfile.getLoan(50000, 0.12, 12, 5, '01-01-2025')
    # Loan 3 - car 2
    myProfile.getLoan(7000, 0.08, 12, 10, '01-06-2027')
    myProfile.loanDesc()
    myProfile.loanInfo()
    
    return myProfile

# %% [raw]
# # Very good function...
# print(help(Profile))

# %%
myProfile = init_profile()
# Out:
# Tyler is 26 years old and has income of $4333.33 per month.
# Number of loans: 1
# Number of loans: 2
# Number of loans: 3
# Loan 1 has principal of $300000 over duration 25 years with expected finish date of 2046-01-01 - remaining balance: $300000
# Loan 2 has principal of $50000 over duration 5 years with expected finish date of 2030-01-01 - remaining balance: $50000
# Loan 3 has principal of $7000 over duration 10 years with expected finish date of 2037-06-01 - remaining balance: $7000

# %% [markdown]
# ## Simulate

# %% [markdown]
# ### Simulation Iterations

# %%
def simulate():
    # Duration of simulation (phase 1)
    dateStart = datetime.date(2020,1,1)
    dateStartTemp = dateStart
    
    
    # Iterate over life with month level grainularity
    print('\n----- ENTERING PHASE ONE -----\n')
    while myProfile.age < myProfile.retireAge:
        # Current datetime of step
        print(f'\n {dateStartTemp}')
        print(f'Monthly Income: ${myProfile.income:0.2f}')

        # Tax
        tax = myProfile.getTaxAmount(myProfile.income)
        print(f'Tax: ${tax:0.2f}')

        # Super
        myProfile.superContribution(1, myProfile.income)

        tempLoanCost = 0

        # Pay debts
        for loanID, loanInfo in myProfile.loanDict.items():
            if myProfile.loanDict[loanID].startDate <= dateStartTemp:

                # Random change of principal injection
                myProfile.loanDict[loanID].increasePrincipalRandomly()

                # If balance remains on loans - make payment
                if 0 < myProfile.loanDict[loanID].beginBalance:
                    # Raise payment against loan
                    myProfile.loanDict[loanID].makePayment()
                    myProfile.loanDict[loanID].paymentSummary()

                    # Capture loan history information for future use
                    myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, myProfile.loanDict[loanID].beginBalance)

                    # Actuate attribute when loan is paid off.
                    if myProfile.loanDict[loanID].beginBalance == 0:
                        print(f'LOAN {loanID} PAID OFF!')
                        # Setting finished to True
                        myProfile.loanDict[loanID].loanFinished(dateStartTemp)

                    else:
                        # Capture loanPayment for totalcost agg
                        print(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
                        tempLoanCost += myProfile.loanDict[loanID].loanPayment

                else:
                    # No principal - either loan hasnt begun or its finished
                    myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)

            else:
                # Too early - no loans are active
                myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
                pass


        expenses =  myProfile.increaseExpenseRandomly(1)

        myProfile.incomeAfterCosts(tax + tempLoanCost + expenses)
        print(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
        myProfile.getIncomeHistory(dateStartTemp, myProfile.remainingIncome)

        savedAmt = myProfile.getSavedAmount(myProfile.remainingIncome)
        print(f'Amount saved this month: ${savedAmt:0.2f}')


        yield OrderedDict([('Date', dateStartTemp),
                          ('Income', myProfile.income),
                          ('Tax', myProfile.getTaxAmount(myProfile.income)),
                          ('SuperContrib', myProfile.superContrib),
                           ('SuperBalance', myProfile.superBalCumSum),
                           ('SuperValue', myProfile.superValCumSum),
                          ('LoanDebt', tempLoanCost),
                          ('Expenses', expenses),
                          ('RemainingIncome', myProfile.remainingIncome),
                          ('SavedAmt', savedAmt)])


        # Steps through time month-by-month
        dateStartTemp += relativedelta(months=1)

        # Adds year to age during simulation
        if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
            #print(f'Year: {dateStartTemp.year - dateStart.year}')
            myProfile.ageStep(1)
            
    # Iterate over life with month level granularity
    print('\n----- ENTERING PHASE TWO -----\n')
    while myProfile.age < myProfile.deadAge:
        print(f'\n {dateStartTemp}')
        
        # Super drawdown
        myProfile.superDrawDown()
        
        expenses =  myProfile.increaseExpenseRandomly(2)
        
        yield OrderedDict([('Date', dateStartTemp),
                          ('Income', 0),
                          ('Tax', 0),
                          ('SuperContrib', 0),
                           ('SuperBalance', myProfile.superBalCumSum),
                           ('SuperValue', myProfile.superValCumSum),
                          ('LoanDebt', 0),
                          ('Expenses', 0),
                          ('RemainingIncome', 0),
                          ('SavedAmt', 0)])
        
        
        
        dateStartTemp += relativedelta(months=1)
        # Adds year to age during simulation
        if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
            print(f'Year: {dateStartTemp.year - dateStart.year}')
            myProfile.ageStep(1)

# %%
df = pd.DataFrame(simulate())
# Out:
# ----- ENTERING PHASE ONE -----
#
#
#  2020-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# adding initial value to superVal
# Super Value: $1411.67
# adding initial value to superBal
# Super Balance: $1411.67
# Expense balance: $253.88
# Income Remaining: $3375.57
# Amount saved this month: $843.89
#
#  2020-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $1621.62
# Super Balance: $1613.56
# Expense balance: $205.60
# Income Remaining: $3423.84
# Amount saved this month: $855.96
#
#  2020-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $1832.63
# Super Balance: $1815.44
# Expense balance: $231.58
# Income Remaining: $3397.87
# Amount saved this month: $849.47
#
#  2020-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2044.69
# Super Balance: $2017.33
# Expense balance: $284.13
# Income Remaining: $3345.31
# Amount saved this month: $836.33
#
#  2020-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2257.81
# Super Balance: $2219.22
# Expense balance: $278.61
# Income Remaining: $3350.83
# Amount saved this month: $837.71
#
#  2020-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2472.00
# Super Balance: $2421.11
# Expense balance: $236.65
# Income Remaining: $3392.79
# Amount saved this month: $848.20
#
#  2020-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2687.26
# Super Balance: $2623.00
# Expense remains unchanged from 500
# Income Remaining: $3129.44
# Amount saved this month: $782.36
#
#  2020-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2903.59
# Super Balance: $2824.89
# Expense balance: $225.14
# Income Remaining: $3404.31
# Amount saved this month: $851.08
#
#  2020-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3121.01
# Super Balance: $3026.78
# Expense balance: $235.59
# Income Remaining: $3393.85
# Amount saved this month: $848.46
#
#  2020-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3339.51
# Super Balance: $3228.67
# Expense balance: $231.97
# Income Remaining: $3397.47
# Amount saved this month: $849.37
#
#  2020-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3559.11
# Super Balance: $3430.56
# Expense remains unchanged from 500
# Income Remaining: $3129.44
# Amount saved this month: $782.36
#
#  2020-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3779.80
# Super Balance: $3632.44
# Expense balance: $292.24
# Income Remaining: $3337.20
# Amount saved this month: $834.30
#
#  2021-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4001.60
# Super Balance: $3834.33
# Period: 2 BeginBalance: 299416.49 Principal: 300000.00 Interest: 1000.00 Payment: 1583.51
# Loan 1 - Begin Balance: $299416.49 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4224.51
# Super Balance: $4036.22
# Increased 1 balance by $1000
# Period: 3 BeginBalance: 299834.37 Principal: 300000.00 Interest: 1001.39 Payment: 1583.51
# Loan 1 - Begin Balance: $299834.37 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4448.53
# Super Balance: $4238.11
# Period: 4 BeginBalance: 299250.31 Principal: 300000.00 Interest: 999.45 Payment: 1583.51
# Loan 1 - Begin Balance: $299250.31 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4673.67
# Super Balance: $4440.00
# Period: 5 BeginBalance: 298664.30 Principal: 300000.00 Interest: 997.50 Payment: 1583.51
# Loan 1 - Begin Balance: $298664.30 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4899.94
# Super Balance: $4641.89
# Period: 6 BeginBalance: 298076.34 Principal: 300000.00 Interest: 995.55 Payment: 1583.51
# Loan 1 - Begin Balance: $298076.34 Payment: 1583.51
# Expense balance: $268.83
# Income Remaining: $1777.10
# Amount saved this month: $444.28
#
#  2021-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5127.33
# Super Balance: $4843.78
# Period: 7 BeginBalance: 297486.42 Principal: 300000.00 Interest: 993.59 Payment: 1583.51
# Loan 1 - Begin Balance: $297486.42 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5355.87
# Super Balance: $5045.67
# Period: 8 BeginBalance: 296894.53 Principal: 300000.00 Interest: 991.62 Payment: 1583.51
# Loan 1 - Begin Balance: $296894.53 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5585.55
# Super Balance: $5247.56
# Period: 9 BeginBalance: 296300.67 Principal: 300000.00 Interest: 989.65 Payment: 1583.51
# Loan 1 - Begin Balance: $296300.67 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5816.37
# Super Balance: $5449.44
# Period: 10 BeginBalance: 295704.83 Principal: 300000.00 Interest: 987.67 Payment: 1583.51
# Loan 1 - Begin Balance: $295704.83 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6048.35
# Super Balance: $5651.33
# Period: 11 BeginBalance: 295107.00 Principal: 300000.00 Interest: 985.68 Payment: 1583.51
# Loan 1 - Begin Balance: $295107.00 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2021-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6281.49
# Super Balance: $5853.22
# Period: 12 BeginBalance: 294507.18 Principal: 300000.00 Interest: 983.69 Payment: 1583.51
# Loan 1 - Begin Balance: $294507.18 Payment: 1583.51
# Expense balance: $285.09
# Income Remaining: $1760.85
# Amount saved this month: $440.21
#
#  2021-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6515.80
# Super Balance: $6055.11
# Period: 13 BeginBalance: 293905.36 Principal: 300000.00 Interest: 981.69 Payment: 1583.51
# Loan 1 - Begin Balance: $293905.36 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6751.28
# Super Balance: $6257.00
# Period: 14 BeginBalance: 293301.53 Principal: 300000.00 Interest: 979.68 Payment: 1583.51
# Loan 1 - Begin Balance: $293301.53 Payment: 1583.51
# Expense balance: $208.31
# Income Remaining: $1837.62
# Amount saved this month: $459.40
#
#  2022-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6987.93
# Super Balance: $6458.89
# Period: 15 BeginBalance: 292695.69 Principal: 300000.00 Interest: 977.67 Payment: 1583.51
# Loan 1 - Begin Balance: $292695.69 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7225.77
# Super Balance: $6660.78
# Period: 16 BeginBalance: 292087.83 Principal: 300000.00 Interest: 975.65 Payment: 1583.51
# Loan 1 - Begin Balance: $292087.83 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7464.80
# Super Balance: $6862.67
# Period: 17 BeginBalance: 291477.95 Principal: 300000.00 Interest: 973.63 Payment: 1583.51
# Loan 1 - Begin Balance: $291477.95 Payment: 1583.51
# Expense balance: $260.64
# Income Remaining: $1785.29
# Amount saved this month: $446.32
#
#  2022-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7705.02
# Super Balance: $7064.56
# Period: 18 BeginBalance: 290866.03 Principal: 300000.00 Interest: 971.59 Payment: 1583.51
# Loan 1 - Begin Balance: $290866.03 Payment: 1583.51
# Expense balance: $274.27
# Income Remaining: $1771.66
# Amount saved this month: $442.92
#
#  2022-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7946.44
# Super Balance: $7266.44
# Period: 19 BeginBalance: 290252.07 Principal: 300000.00 Interest: 969.55 Payment: 1583.51
# Loan 1 - Begin Balance: $290252.07 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8189.07
# Super Balance: $7468.33
# Period: 20 BeginBalance: 289636.07 Principal: 300000.00 Interest: 967.51 Payment: 1583.51
# Loan 1 - Begin Balance: $289636.07 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8432.92
# Super Balance: $7670.22
# Period: 21 BeginBalance: 289018.01 Principal: 300000.00 Interest: 965.45 Payment: 1583.51
# Loan 1 - Begin Balance: $289018.01 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8677.98
# Super Balance: $7872.11
# Period: 22 BeginBalance: 288397.89 Principal: 300000.00 Interest: 963.39 Payment: 1583.51
# Loan 1 - Begin Balance: $288397.89 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2022-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8924.27
# Super Balance: $8074.00
# Period: 23 BeginBalance: 287775.71 Principal: 300000.00 Interest: 961.33 Payment: 1583.51
# Loan 1 - Begin Balance: $287775.71 Payment: 1583.51
# Expense balance: $246.05
# Income Remaining: $1799.88
# Amount saved this month: $449.97
#
#  2022-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9171.79
# Super Balance: $8275.89
# Period: 24 BeginBalance: 287151.45 Principal: 300000.00 Interest: 959.25 Payment: 1583.51
# Loan 1 - Begin Balance: $287151.45 Payment: 1583.51
# Expense balance: $225.33
# Income Remaining: $1820.61
# Amount saved this month: $455.15
#
#  2022-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9420.54
# Super Balance: $8477.78
# Period: 25 BeginBalance: 286525.11 Principal: 300000.00 Interest: 957.17 Payment: 1583.51
# Loan 1 - Begin Balance: $286525.11 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2023-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9670.54
# Super Balance: $8679.67
# Period: 26 BeginBalance: 285896.68 Principal: 300000.00 Interest: 955.08 Payment: 1583.51
# Loan 1 - Begin Balance: $285896.68 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2023-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9921.80
# Super Balance: $8881.56
# Period: 27 BeginBalance: 285266.16 Principal: 300000.00 Interest: 952.99 Payment: 1583.51
# Loan 1 - Begin Balance: $285266.16 Payment: 1583.51
# Expense balance: $290.88
# Income Remaining: $1755.06
# Amount saved this month: $438.76
#
#  2023-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10174.30
# Super Balance: $9083.44
# Period: 28 BeginBalance: 284633.54 Principal: 300000.00 Interest: 950.89 Payment: 1583.51
# Loan 1 - Begin Balance: $284633.54 Payment: 1583.51
# Expense balance: $280.47
# Income Remaining: $1765.46
# Amount saved this month: $441.37
#
#  2023-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10428.07
# Super Balance: $9285.33
# Period: 29 BeginBalance: 283998.81 Principal: 300000.00 Interest: 948.78 Payment: 1583.51
# Loan 1 - Begin Balance: $283998.81 Payment: 1583.51
# Expense balance: $229.88
# Income Remaining: $1816.05
# Amount saved this month: $454.01
#
#  2023-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10683.11
# Super Balance: $9487.22
# Period: 30 BeginBalance: 283361.96 Principal: 300000.00 Interest: 946.66 Payment: 1583.51
# Loan 1 - Begin Balance: $283361.96 Payment: 1583.51
# Expense balance: $217.87
# Income Remaining: $1828.06
# Amount saved this month: $457.02
#
#  2023-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10939.42
# Super Balance: $9689.11
# Period: 31 BeginBalance: 282722.99 Principal: 300000.00 Interest: 944.54 Payment: 1583.51
# Loan 1 - Begin Balance: $282722.99 Payment: 1583.51
# Expense balance: $245.53
# Income Remaining: $1800.41
# Amount saved this month: $450.10
#
#  2023-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11197.02
# Super Balance: $9891.00
# Period: 32 BeginBalance: 282081.89 Principal: 300000.00 Interest: 942.41 Payment: 1583.51
# Loan 1 - Begin Balance: $282081.89 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2023-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11455.90
# Super Balance: $10092.89
# Period: 33 BeginBalance: 281438.65 Principal: 300000.00 Interest: 940.27 Payment: 1583.51
# Loan 1 - Begin Balance: $281438.65 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2023-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11716.08
# Super Balance: $10294.78
# Period: 34 BeginBalance: 280793.27 Principal: 300000.00 Interest: 938.13 Payment: 1583.51
# Loan 1 - Begin Balance: $280793.27 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2023-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11977.56
# Super Balance: $10496.67
# Period: 35 BeginBalance: 280145.74 Principal: 300000.00 Interest: 935.98 Payment: 1583.51
# Loan 1 - Begin Balance: $280145.74 Payment: 1583.51
# Expense balance: $274.51
# Income Remaining: $1771.43
# Amount saved this month: $442.86
#
#  2023-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $12240.35
# Super Balance: $10698.56
# Period: 36 BeginBalance: 279496.05 Principal: 300000.00 Interest: 933.82 Payment: 1583.51
# Loan 1 - Begin Balance: $279496.05 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2023-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $12504.45
# Super Balance: $10900.44
# Period: 37 BeginBalance: 278844.19 Principal: 300000.00 Interest: 931.65 Payment: 1583.51
# Loan 1 - Begin Balance: $278844.19 Payment: 1583.51
# Expense balance: $242.36
# Income Remaining: $1803.57
# Amount saved this month: $450.89
#
#  2024-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $12769.87
# Super Balance: $11102.33
# Period: 38 BeginBalance: 278190.16 Principal: 300000.00 Interest: 929.48 Payment: 1583.51
# Loan 1 - Begin Balance: $278190.16 Payment: 1583.51
# Expense balance: $261.87
# Income Remaining: $1784.06
# Amount saved this month: $446.02
#
#  2024-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13036.61
# Super Balance: $11304.22
# Period: 39 BeginBalance: 277533.95 Principal: 300000.00 Interest: 927.30 Payment: 1583.51
# Loan 1 - Begin Balance: $277533.95 Payment: 1583.51
# Expense balance: $219.60
# Income Remaining: $1826.33
# Amount saved this month: $456.58
#
#  2024-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13304.70
# Super Balance: $11506.11
# Increased 1 balance by $5000
# Period: 40 BeginBalance: 281892.22 Principal: 300000.00 Interest: 941.78 Payment: 1583.51
# Loan 1 - Begin Balance: $281892.22 Payment: 1583.51
# Expense balance: $208.30
# Income Remaining: $1837.63
# Amount saved this month: $459.41
#
#  2024-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13574.12
# Super Balance: $11708.00
# Period: 41 BeginBalance: 281248.35 Principal: 300000.00 Interest: 939.64 Payment: 1583.51
# Loan 1 - Begin Balance: $281248.35 Payment: 1583.51
# Expense balance: $237.26
# Income Remaining: $1808.67
# Amount saved this month: $452.17
#
#  2024-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13844.89
# Super Balance: $11909.89
# Period: 42 BeginBalance: 280602.33 Principal: 300000.00 Interest: 937.49 Payment: 1583.51
# Loan 1 - Begin Balance: $280602.33 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2024-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14117.01
# Super Balance: $12111.78
# Period: 43 BeginBalance: 279954.16 Principal: 300000.00 Interest: 935.34 Payment: 1583.51
# Loan 1 - Begin Balance: $279954.16 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2024-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14390.49
# Super Balance: $12313.67
# Period: 44 BeginBalance: 279303.83 Principal: 300000.00 Interest: 933.18 Payment: 1583.51
# Loan 1 - Begin Balance: $279303.83 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2024-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14665.34
# Super Balance: $12515.56
# Period: 45 BeginBalance: 278651.33 Principal: 300000.00 Interest: 931.01 Payment: 1583.51
# Loan 1 - Begin Balance: $278651.33 Payment: 1583.51
# Expense balance: $202.86
# Income Remaining: $1843.07
# Amount saved this month: $460.77
#
#  2024-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14941.57
# Super Balance: $12717.44
# Period: 46 BeginBalance: 277996.66 Principal: 300000.00 Interest: 928.84 Payment: 1583.51
# Loan 1 - Begin Balance: $277996.66 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2024-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $15219.18
# Super Balance: $12919.33
# Period: 47 BeginBalance: 277339.81 Principal: 300000.00 Interest: 926.66 Payment: 1583.51
# Loan 1 - Begin Balance: $277339.81 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2024-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $15498.17
# Super Balance: $13121.22
# Period: 48 BeginBalance: 276680.77 Principal: 300000.00 Interest: 924.47 Payment: 1583.51
# Loan 1 - Begin Balance: $276680.77 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2024-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $15778.56
# Super Balance: $13323.11
# Period: 49 BeginBalance: 276019.53 Principal: 300000.00 Interest: 922.27 Payment: 1583.51
# Loan 1 - Begin Balance: $276019.53 Payment: 1583.51
# Expense remains unchanged from 500
# Income Remaining: $1545.93
# Amount saved this month: $386.48
#
#  2025-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16060.35
# Super Balance: $13525.00
# Period: 50 BeginBalance: 275356.09 Principal: 300000.00 Interest: 920.07 Payment: 1583.51
# Loan 1 - Begin Balance: $275356.09 Payment: 1583.51
# Period: 2 BeginBalance: 49387.78 Principal: 50000.00 Interest: 500.00 Payment: 1112.22
# Loan 2 - Begin Balance: $49387.78 Payment: 1112.22
# Expense balance: $278.84
# Income Remaining: $654.88
# Amount saved this month: $163.72
#
#  2025-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16343.55
# Super Balance: $13726.89
# Period: 51 BeginBalance: 274690.43 Principal: 300000.00 Interest: 917.85 Payment: 1583.51
# Loan 1 - Begin Balance: $274690.43 Payment: 1583.51
# Period: 3 BeginBalance: 48769.44 Principal: 50000.00 Interest: 493.88 Payment: 1112.22
# Loan 2 - Begin Balance: $48769.44 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16628.17
# Super Balance: $13928.78
# Increased 1 balance by $0
# Period: 52 BeginBalance: 274022.55 Principal: 300000.00 Interest: 915.63 Payment: 1583.51
# Loan 1 - Begin Balance: $274022.55 Payment: 1583.51
# Period: 4 BeginBalance: 48144.91 Principal: 50000.00 Interest: 487.69 Payment: 1112.22
# Loan 2 - Begin Balance: $48144.91 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16914.21
# Super Balance: $14130.67
# Period: 53 BeginBalance: 273352.45 Principal: 300000.00 Interest: 913.41 Payment: 1583.51
# Loan 1 - Begin Balance: $273352.45 Payment: 1583.51
# Period: 5 BeginBalance: 47514.14 Principal: 50000.00 Interest: 481.45 Payment: 1112.22
# Loan 2 - Begin Balance: $47514.14 Payment: 1112.22
# Expense balance: $218.82
# Income Remaining: $714.90
# Amount saved this month: $178.72
#
#  2025-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $17201.67
# Super Balance: $14332.56
# Period: 54 BeginBalance: 272680.11 Principal: 300000.00 Interest: 911.17 Payment: 1583.51
# Loan 1 - Begin Balance: $272680.11 Payment: 1583.51
# Period: 6 BeginBalance: 46877.06 Principal: 50000.00 Interest: 475.14 Payment: 1112.22
# Loan 2 - Begin Balance: $46877.06 Payment: 1112.22
# Expense balance: $209.81
# Income Remaining: $723.90
# Amount saved this month: $180.98
#
#  2025-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $17490.58
# Super Balance: $14534.44
# Period: 55 BeginBalance: 272005.53 Principal: 300000.00 Interest: 908.93 Payment: 1583.51
# Loan 1 - Begin Balance: $272005.53 Payment: 1583.51
# Period: 7 BeginBalance: 46233.61 Principal: 50000.00 Interest: 468.77 Payment: 1112.22
# Loan 2 - Begin Balance: $46233.61 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $17780.93
# Super Balance: $14736.33
# Period: 56 BeginBalance: 271328.71 Principal: 300000.00 Interest: 906.69 Payment: 1583.51
# Loan 1 - Begin Balance: $271328.71 Payment: 1583.51
# Period: 8 BeginBalance: 45583.73 Principal: 50000.00 Interest: 462.34 Payment: 1112.22
# Loan 2 - Begin Balance: $45583.73 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18072.74
# Super Balance: $14938.22
# Period: 57 BeginBalance: 270649.63 Principal: 300000.00 Interest: 904.43 Payment: 1583.51
# Loan 1 - Begin Balance: $270649.63 Payment: 1583.51
# Period: 9 BeginBalance: 44927.35 Principal: 50000.00 Interest: 455.84 Payment: 1112.22
# Loan 2 - Begin Balance: $44927.35 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18366.00
# Super Balance: $15140.11
# Period: 58 BeginBalance: 269968.29 Principal: 300000.00 Interest: 902.17 Payment: 1583.51
# Loan 1 - Begin Balance: $269968.29 Payment: 1583.51
# Period: 10 BeginBalance: 44264.40 Principal: 50000.00 Interest: 449.27 Payment: 1112.22
# Loan 2 - Begin Balance: $44264.40 Payment: 1112.22
# Expense balance: $268.46
# Income Remaining: $665.25
# Amount saved this month: $166.31
#
#  2025-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18660.73
# Super Balance: $15342.00
# Period: 59 BeginBalance: 269284.67 Principal: 300000.00 Interest: 899.89 Payment: 1583.51
# Loan 1 - Begin Balance: $269284.67 Payment: 1583.51
# Period: 11 BeginBalance: 43594.82 Principal: 50000.00 Interest: 442.64 Payment: 1112.22
# Loan 2 - Begin Balance: $43594.82 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18956.93
# Super Balance: $15543.89
# Period: 60 BeginBalance: 268598.78 Principal: 300000.00 Interest: 897.62 Payment: 1583.51
# Loan 1 - Begin Balance: $268598.78 Payment: 1583.51
# Period: 12 BeginBalance: 42918.55 Principal: 50000.00 Interest: 435.95 Payment: 1112.22
# Loan 2 - Begin Balance: $42918.55 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2025-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $19254.61
# Super Balance: $15745.78
# Period: 61 BeginBalance: 267910.60 Principal: 300000.00 Interest: 895.33 Payment: 1583.51
# Loan 1 - Begin Balance: $267910.60 Payment: 1583.51
# Period: 13 BeginBalance: 42235.52 Principal: 50000.00 Interest: 429.19 Payment: 1112.22
# Loan 2 - Begin Balance: $42235.52 Payment: 1112.22
# Expense balance: $244.26
# Income Remaining: $689.45
# Amount saved this month: $172.36
#
#  2026-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $19553.78
# Super Balance: $15947.67
# Period: 62 BeginBalance: 267220.13 Principal: 300000.00 Interest: 893.04 Payment: 1583.51
# Loan 1 - Begin Balance: $267220.13 Payment: 1583.51
# Period: 14 BeginBalance: 41545.66 Principal: 50000.00 Interest: 422.36 Payment: 1112.22
# Loan 2 - Begin Balance: $41545.66 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2026-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $19854.45
# Super Balance: $16149.56
# Period: 63 BeginBalance: 266527.35 Principal: 300000.00 Interest: 890.73 Payment: 1583.51
# Loan 1 - Begin Balance: $266527.35 Payment: 1583.51
# Period: 15 BeginBalance: 40848.90 Principal: 50000.00 Interest: 415.46 Payment: 1112.22
# Loan 2 - Begin Balance: $40848.90 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2026-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $20156.62
# Super Balance: $16351.44
# Period: 64 BeginBalance: 265832.26 Principal: 300000.00 Interest: 888.42 Payment: 1583.51
# Loan 1 - Begin Balance: $265832.26 Payment: 1583.51
# Period: 16 BeginBalance: 40145.17 Principal: 50000.00 Interest: 408.49 Payment: 1112.22
# Loan 2 - Begin Balance: $40145.17 Payment: 1112.22
# Expense balance: $235.28
# Income Remaining: $698.43
# Amount saved this month: $174.61
#
#  2026-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $20460.30
# Super Balance: $16553.33
# Period: 65 BeginBalance: 265134.86 Principal: 300000.00 Interest: 886.11 Payment: 1583.51
# Loan 1 - Begin Balance: $265134.86 Payment: 1583.51
# Period: 17 BeginBalance: 39434.40 Principal: 50000.00 Interest: 401.45 Payment: 1112.22
# Loan 2 - Begin Balance: $39434.40 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2026-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $20765.50
# Super Balance: $16755.22
# Period: 66 BeginBalance: 264435.13 Principal: 300000.00 Interest: 883.78 Payment: 1583.51
# Loan 1 - Begin Balance: $264435.13 Payment: 1583.51
# Period: 18 BeginBalance: 38716.52 Principal: 50000.00 Interest: 394.34 Payment: 1112.22
# Loan 2 - Begin Balance: $38716.52 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2026-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $21072.23
# Super Balance: $16957.11
# Period: 67 BeginBalance: 263733.07 Principal: 300000.00 Interest: 881.45 Payment: 1583.51
# Loan 1 - Begin Balance: $263733.07 Payment: 1583.51
# Period: 19 BeginBalance: 37991.47 Principal: 50000.00 Interest: 387.17 Payment: 1112.22
# Loan 2 - Begin Balance: $37991.47 Payment: 1112.22
# Expense balance: $256.08
# Income Remaining: $677.64
# Amount saved this month: $169.41
#
#  2026-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $21380.49
# Super Balance: $17159.00
# Period: 68 BeginBalance: 263028.67 Principal: 300000.00 Interest: 879.11 Payment: 1583.51
# Loan 1 - Begin Balance: $263028.67 Payment: 1583.51
# Period: 20 BeginBalance: 37259.16 Principal: 50000.00 Interest: 379.91 Payment: 1112.22
# Loan 2 - Begin Balance: $37259.16 Payment: 1112.22
# Expense balance: $257.67
# Income Remaining: $676.04
# Amount saved this month: $169.01
#
#  2026-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $21690.29
# Super Balance: $17360.89
# Period: 69 BeginBalance: 262321.92 Principal: 300000.00 Interest: 876.76 Payment: 1583.51
# Loan 1 - Begin Balance: $262321.92 Payment: 1583.51
# Increased 2 balance by $2000
# Period: 21 BeginBalance: 38539.53 Principal: 50000.00 Interest: 392.59 Payment: 1112.22
# Loan 2 - Begin Balance: $38539.53 Payment: 1112.22
# Expense balance: $284.46
# Income Remaining: $649.25
# Amount saved this month: $162.31
#
#  2026-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22001.64
# Super Balance: $17562.78
# Period: 70 BeginBalance: 261612.82 Principal: 300000.00 Interest: 874.41 Payment: 1583.51
# Loan 1 - Begin Balance: $261612.82 Payment: 1583.51
# Period: 22 BeginBalance: 37812.71 Principal: 50000.00 Interest: 385.40 Payment: 1112.22
# Loan 2 - Begin Balance: $37812.71 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2026-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22314.54
# Super Balance: $17764.67
# Period: 71 BeginBalance: 260901.35 Principal: 300000.00 Interest: 872.04 Payment: 1583.51
# Loan 1 - Begin Balance: $260901.35 Payment: 1583.51
# Period: 23 BeginBalance: 37078.62 Principal: 50000.00 Interest: 378.13 Payment: 1112.22
# Loan 2 - Begin Balance: $37078.62 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2026-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22629.01
# Super Balance: $17966.56
# Period: 72 BeginBalance: 260187.51 Principal: 300000.00 Interest: 869.67 Payment: 1583.51
# Loan 1 - Begin Balance: $260187.51 Payment: 1583.51
# Period: 24 BeginBalance: 36337.19 Principal: 50000.00 Interest: 370.79 Payment: 1112.22
# Loan 2 - Begin Balance: $36337.19 Payment: 1112.22
# Expense balance: $232.54
# Income Remaining: $701.18
# Amount saved this month: $175.29
#
#  2026-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22945.06
# Super Balance: $18168.44
# Period: 73 BeginBalance: 259471.29 Principal: 300000.00 Interest: 867.29 Payment: 1583.51
# Loan 1 - Begin Balance: $259471.29 Payment: 1583.51
# Period: 25 BeginBalance: 35588.34 Principal: 50000.00 Interest: 363.37 Payment: 1112.22
# Loan 2 - Begin Balance: $35588.34 Payment: 1112.22
# Expense balance: $291.20
# Income Remaining: $642.51
# Amount saved this month: $160.63
#
#  2027-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $23262.68
# Super Balance: $18370.33
# Period: 74 BeginBalance: 258752.68 Principal: 300000.00 Interest: 864.90 Payment: 1583.51
# Loan 1 - Begin Balance: $258752.68 Payment: 1583.51
# Period: 26 BeginBalance: 34832.00 Principal: 50000.00 Interest: 355.88 Payment: 1112.22
# Loan 2 - Begin Balance: $34832.00 Payment: 1112.22
# Expense balance: $284.64
# Income Remaining: $649.08
# Amount saved this month: $162.27
#
#  2027-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $23581.89
# Super Balance: $18572.22
# Period: 75 BeginBalance: 258031.68 Principal: 300000.00 Interest: 862.51 Payment: 1583.51
# Loan 1 - Begin Balance: $258031.68 Payment: 1583.51
# Period: 27 BeginBalance: 34068.10 Principal: 50000.00 Interest: 348.32 Payment: 1112.22
# Loan 2 - Begin Balance: $34068.10 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2027-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $23902.70
# Super Balance: $18774.11
# Period: 76 BeginBalance: 257308.28 Principal: 300000.00 Interest: 860.11 Payment: 1583.51
# Loan 1 - Begin Balance: $257308.28 Payment: 1583.51
# Period: 28 BeginBalance: 33296.56 Principal: 50000.00 Interest: 340.68 Payment: 1112.22
# Loan 2 - Begin Balance: $33296.56 Payment: 1112.22
# Expense balance: $249.27
# Income Remaining: $684.44
# Amount saved this month: $171.11
#
#  2027-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $24225.11
# Super Balance: $18976.00
# Period: 77 BeginBalance: 256582.46 Principal: 300000.00 Interest: 857.69 Payment: 1583.51
# Loan 1 - Begin Balance: $256582.46 Payment: 1583.51
# Period: 29 BeginBalance: 32517.31 Principal: 50000.00 Interest: 332.97 Payment: 1112.22
# Loan 2 - Begin Balance: $32517.31 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2027-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $24549.14
# Super Balance: $19177.89
# Period: 78 BeginBalance: 255854.22 Principal: 300000.00 Interest: 855.27 Payment: 1583.51
# Loan 1 - Begin Balance: $255854.22 Payment: 1583.51
# Period: 30 BeginBalance: 31730.26 Principal: 50000.00 Interest: 325.17 Payment: 1112.22
# Loan 2 - Begin Balance: $31730.26 Payment: 1112.22
# Expense remains unchanged from 500
# Income Remaining: $433.71
# Amount saved this month: $108.43
#
#  2027-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $24874.78
# Super Balance: $19379.78
# Period: 79 BeginBalance: 255123.56 Principal: 300000.00 Interest: 852.85 Payment: 1583.51
# Loan 1 - Begin Balance: $255123.56 Payment: 1583.51
# Period: 31 BeginBalance: 30935.34 Principal: 50000.00 Interest: 317.30 Payment: 1112.22
# Loan 2 - Begin Balance: $30935.34 Payment: 1112.22
# Period: 2 BeginBalance: 6961.74 Principal: 7000.00 Interest: 46.67 Payment: 84.93
# Loan 3 - Begin Balance: $6961.74 Payment: 84.93
# Expense remains unchanged from 500
# Income Remaining: $348.78
# Amount saved this month: $87.20
#
#  2027-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $25202.05
# Super Balance: $19581.67
# Period: 80 BeginBalance: 254390.46 Principal: 300000.00 Interest: 850.41 Payment: 1583.51
# Loan 1 - Begin Balance: $254390.46 Payment: 1583.51
# Period: 32 BeginBalance: 30132.47 Principal: 50000.00 Interest: 309.35 Payment: 1112.22
# Loan 2 - Begin Balance: $30132.47 Payment: 1112.22
# Period: 3 BeginBalance: 6923.22 Principal: 7000.00 Interest: 46.41 Payment: 84.93
# Loan 3 - Begin Balance: $6923.22 Payment: 84.93
# Expense balance: $275.47
# Income Remaining: $573.32
# Amount saved this month: $143.33
#
#  2027-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $25530.96
# Super Balance: $19783.56
# Period: 81 BeginBalance: 253654.92 Principal: 300000.00 Interest: 847.97 Payment: 1583.51
# Loan 1 - Begin Balance: $253654.92 Payment: 1583.51
# Period: 33 BeginBalance: 29321.57 Principal: 50000.00 Interest: 301.32 Payment: 1112.22
# Loan 2 - Begin Balance: $29321.57 Payment: 1112.22
# Period: 4 BeginBalance: 6884.44 Principal: 7000.00 Interest: 46.15 Payment: 84.93
# Loan 3 - Begin Balance: $6884.44 Payment: 84.93
# Expense balance: $261.60
# Income Remaining: $587.19
# Amount saved this month: $146.80
#
#  2027-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $25861.51
# Super Balance: $19985.44
# Period: 82 BeginBalance: 252916.93 Principal: 300000.00 Interest: 845.52 Payment: 1583.51
# Loan 1 - Begin Balance: $252916.93 Payment: 1583.51
# Period: 34 BeginBalance: 28502.57 Principal: 50000.00 Interest: 293.22 Payment: 1112.22
# Loan 2 - Begin Balance: $28502.57 Payment: 1112.22
# Period: 5 BeginBalance: 6845.41 Principal: 7000.00 Interest: 45.90 Payment: 84.93
# Loan 3 - Begin Balance: $6845.41 Payment: 84.93
# Expense balance: $222.44
# Income Remaining: $626.34
# Amount saved this month: $156.59
#
#  2027-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $26193.72
# Super Balance: $20187.33
# Period: 83 BeginBalance: 252176.48 Principal: 300000.00 Interest: 843.06 Payment: 1583.51
# Loan 1 - Begin Balance: $252176.48 Payment: 1583.51
# Period: 35 BeginBalance: 27675.38 Principal: 50000.00 Interest: 285.03 Payment: 1112.22
# Loan 2 - Begin Balance: $27675.38 Payment: 1112.22
# Period: 6 BeginBalance: 6806.12 Principal: 7000.00 Interest: 45.64 Payment: 84.93
# Loan 3 - Begin Balance: $6806.12 Payment: 84.93
# Expense balance: $227.85
# Income Remaining: $620.94
# Amount saved this month: $155.23
#
#  2027-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $26527.59
# Super Balance: $20389.22
# Period: 84 BeginBalance: 251433.56 Principal: 300000.00 Interest: 840.59 Payment: 1583.51
# Loan 1 - Begin Balance: $251433.56 Payment: 1583.51
# Period: 36 BeginBalance: 26839.91 Principal: 50000.00 Interest: 276.75 Payment: 1112.22
# Loan 2 - Begin Balance: $26839.91 Payment: 1112.22
# Period: 7 BeginBalance: 6766.56 Principal: 7000.00 Interest: 45.37 Payment: 84.93
# Loan 3 - Begin Balance: $6766.56 Payment: 84.93
# Expense remains unchanged from 500
# Income Remaining: $348.78
# Amount saved this month: $87.20
#
#  2027-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $26863.12
# Super Balance: $20591.11
# Period: 85 BeginBalance: 250688.16 Principal: 300000.00 Interest: 838.11 Payment: 1583.51
# Loan 1 - Begin Balance: $250688.16 Payment: 1583.51
# Period: 37 BeginBalance: 25996.09 Principal: 50000.00 Interest: 268.40 Payment: 1112.22
# Loan 2 - Begin Balance: $25996.09 Payment: 1112.22
# Period: 8 BeginBalance: 6726.74 Principal: 7000.00 Interest: 45.11 Payment: 84.93
# Loan 3 - Begin Balance: $6726.74 Payment: 84.93
# Expense remains unchanged from 500
# Income Remaining: $348.78
# Amount saved this month: $87.20
#
#  2028-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $27200.34
# Super Balance: $20793.00
# Period: 86 BeginBalance: 249940.28 Principal: 300000.00 Interest: 835.63 Payment: 1583.51
# Loan 1 - Begin Balance: $249940.28 Payment: 1583.51
# Period: 38 BeginBalance: 25143.83 Principal: 50000.00 Interest: 259.96 Payment: 1112.22
# Loan 2 - Begin Balance: $25143.83 Payment: 1112.22
# Period: 9 BeginBalance: 6686.65 Principal: 7000.00 Interest: 44.84 Payment: 84.93
# Loan 3 - Begin Balance: $6686.65 Payment: 84.93
# Expense balance: $285.99
# Income Remaining: $562.80
# Amount saved this month: $140.70
#
#  2028-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $27539.24
# Super Balance: $20994.89
# Period: 87 BeginBalance: 249189.90 Principal: 300000.00 Interest: 833.13 Payment: 1583.51
# Loan 1 - Begin Balance: $249189.90 Payment: 1583.51
# Period: 39 BeginBalance: 24283.05 Principal: 50000.00 Interest: 251.44 Payment: 1112.22
# Loan 2 - Begin Balance: $24283.05 Payment: 1112.22
# Period: 10 BeginBalance: 6646.30 Principal: 7000.00 Interest: 44.58 Payment: 84.93
# Loan 3 - Begin Balance: $6646.30 Payment: 84.93
# Expense balance: $283.16
# Income Remaining: $565.62
# Amount saved this month: $141.41
#
#  2028-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $27879.83
# Super Balance: $21196.78
# Period: 88 BeginBalance: 248437.02 Principal: 300000.00 Interest: 830.63 Payment: 1583.51
# Loan 1 - Begin Balance: $248437.02 Payment: 1583.51
# Period: 40 BeginBalance: 23413.66 Principal: 50000.00 Interest: 242.83 Payment: 1112.22
# Loan 2 - Begin Balance: $23413.66 Payment: 1112.22
# Period: 11 BeginBalance: 6605.68 Principal: 7000.00 Interest: 44.31 Payment: 84.93
# Loan 3 - Begin Balance: $6605.68 Payment: 84.93
# Expense balance: $204.85
# Income Remaining: $643.93
# Amount saved this month: $160.98
#
#  2028-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $28222.13
# Super Balance: $21398.67
# Period: 89 BeginBalance: 247681.63 Principal: 300000.00 Interest: 828.12 Payment: 1583.51
# Loan 1 - Begin Balance: $247681.63 Payment: 1583.51
# Period: 41 BeginBalance: 22535.58 Principal: 50000.00 Interest: 234.14 Payment: 1112.22
# Loan 2 - Begin Balance: $22535.58 Payment: 1112.22
# Period: 12 BeginBalance: 6564.79 Principal: 7000.00 Interest: 44.04 Payment: 84.93
# Loan 3 - Begin Balance: $6564.79 Payment: 84.93
# Expense balance: $292.86
# Income Remaining: $555.92
# Amount saved this month: $138.98
#
#  2028-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $28566.14
# Super Balance: $21600.56
# Period: 90 BeginBalance: 246923.73 Principal: 300000.00 Interest: 825.61 Payment: 1583.51
# Loan 1 - Begin Balance: $246923.73 Payment: 1583.51
# Period: 42 BeginBalance: 21648.72 Principal: 50000.00 Interest: 225.36 Payment: 1112.22
# Loan 2 - Begin Balance: $21648.72 Payment: 1112.22
# Period: 13 BeginBalance: 6523.63 Principal: 7000.00 Interest: 43.77 Payment: 84.93
# Loan 3 - Begin Balance: $6523.63 Payment: 84.93
# Expense remains unchanged from 500
# Income Remaining: $348.78
# Amount saved this month: $87.20
#
#  2028-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $28911.87
# Super Balance: $21802.44
# Period: 91 BeginBalance: 246163.30 Principal: 300000.00 Interest: 823.08 Payment: 1583.51
# Loan 1 - Begin Balance: $246163.30 Payment: 1583.51
# Period: 43 BeginBalance: 20752.99 Principal: 50000.00 Interest: 216.49 Payment: 1112.22
# Loan 2 - Begin Balance: $20752.99 Payment: 1112.22
# Increased 3 balance by $3000
# Period: 14 BeginBalance: 9502.19 Principal: 7000.00 Interest: 63.49 Payment: 84.93
# Loan 3 - Begin Balance: $9502.19 Payment: 84.93
# Expense remains unchanged from 500
# Income Remaining: $348.78
# Amount saved this month: $87.20
#
#  2028-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $29259.33
# Super Balance: $22004.33
# Period: 92 BeginBalance: 245400.33 Principal: 300000.00 Interest: 820.54 Payment: 1583.51
# Loan 1 - Begin Balance: $245400.33 Payment: 1583.51
# Period: 44 BeginBalance: 19848.30 Principal: 50000.00 Interest: 207.53 Payment: 1112.22
# Loan 2 - Begin Balance: $19848.30 Payment: 1112.22
# Period: 15 BeginBalance: 9480.61 Principal: 7000.00 Interest: 63.35 Payment: 84.93
# Loan 3 - Begin Balance: $9480.61 Payment: 84.93
# Expense balance: $291.32
# Income Remaining: $557.47
# Amount saved this month: $139.37
#
#  2028-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $29608.52
# Super Balance: $22206.22
# Period: 93 BeginBalance: 244634.82 Principal: 300000.00 Interest: 818.00 Payment: 1583.51
# Loan 1 - Begin Balance: $244634.82 Payment: 1583.51
# Period: 45 BeginBalance: 18934.56 Principal: 50000.00 Interest: 198.48 Payment: 1112.22
# Loan 2 - Begin Balance: $18934.56 Payment: 1112.22
# Period: 16 BeginBalance: 9458.88 Principal: 7000.00 Interest: 63.20 Payment: 84.93
# Loan 3 - Begin Balance: $9458.88 Payment: 84.93
# Expense balance: $208.57
# Income Remaining: $640.21
# Amount saved this month: $160.05
#
#  2028-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $29959.46
# Super Balance: $22408.11
# Period: 94 BeginBalance: 243866.76 Principal: 300000.00 Interest: 815.45 Payment: 1583.51
# Loan 1 - Begin Balance: $243866.76 Payment: 1583.51
# Period: 46 BeginBalance: 18011.69 Principal: 50000.00 Interest: 189.35 Payment: 1112.22
# Loan 2 - Begin Balance: $18011.69 Payment: 1112.22
# Period: 17 BeginBalance: 9437.01 Principal: 7000.00 Interest: 63.06 Payment: 84.93
# Loan 3 - Begin Balance: $9437.01 Payment: 84.93
# Expense remains unchanged from 500
# Income Remaining: $348.78
# Amount saved this month: $87.20
#
#  2028-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $30312.16
# Super Balance: $22610.00
# Period: 95 BeginBalance: 243096.14 Principal: 300000.00 Interest: 812.89 Payment: 1583.51
# Loan 1 - Begin Balance: $243096.14 Payment: 1583.51
# Period: 47 BeginBalance: 17079.59 Principal: 50000.00 Interest: 180.12 Payment: 1112.22
# Loan 2 - Begin Balance: $17079.59 Payment: 1112.22
# Period: 18 BeginBalance: 9414.99 Principal: 7000.00 Interest: 62.91 Payment: 84.93
# Loan 3 - Begin Balance: $9414.99 Payment: 84.93
# Expense balance: $232.37
# Income Remaining: $616.42
# Amount saved this month: $154.10
#
#  2028-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $30666.62
# Super Balance: $22811.89
# Period: 96 BeginBalance: 242322.95 Principal: 300000.00 Interest: 810.32 Payment: 1583.51
# Loan 1 - Begin Balance: $242322.95 Payment: 1583.51
# Period: 48 BeginBalance: 16138.17 Principal: 50000.00 Interest: 170.80 Payment: 1112.22
# Loan 2 - Begin Balance: $16138.17 Payment: 1112.22
# Period: 19 BeginBalance: 9392.83 Principal: 7000.00 Interest: 62.77 Payment: 84.93
# Loan 3 - Begin Balance: $9392.83 Payment: 84.93
# Expense balance: $209.19
# Income Remaining: $639.59
# Amount saved this month: $159.90
#
#  2028-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $31022.85
# Super Balance: $23013.78
# ...
#
#  2064-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $371863.03
# Super Balance: $89093.78
# Expense balance: $267.70
#
#  2064-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $371528.09
# Super Balance: $88993.78
# Expense balance: $224.10
#
#  2064-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $371191.48
# Super Balance: $88893.78
# Expense balance: $279.83
#
#  2064-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $370853.19
# Super Balance: $88793.78
# Expense remains unchanged from 500
#
#  2064-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $370513.21
# Super Balance: $88693.78
# Expense remains unchanged from 500
#
#  2064-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $370171.52
# Super Balance: $88593.78
# Expense balance: $256.90
#
#  2064-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $369828.13
# Super Balance: $88493.78
# Expense remains unchanged from 500
# Year: 45
#
#  2065-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $369483.02
# Super Balance: $88393.78
# Expense remains unchanged from 500
#
#  2065-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $369136.19
# Super Balance: $88293.78
# Expense remains unchanged from 500
#
#  2065-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $368787.62
# Super Balance: $88193.78
# Expense remains unchanged from 500
#
#  2065-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $368437.31
# Super Balance: $88093.78
# Expense remains unchanged from 500
#
#  2065-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $368085.24
# Super Balance: $87993.78
# Expense remains unchanged from 500
#
#  2065-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $367731.42
# Super Balance: $87893.78
# Expense balance: $282.98
#
#  2065-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $367375.83
# Super Balance: $87793.78
# Expense balance: $208.19
#
#  2065-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $367018.45
# Super Balance: $87693.78
# Expense remains unchanged from 500
#
#  2065-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $366659.30
# Super Balance: $87593.78
# Expense remains unchanged from 500
#
#  2065-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $366298.34
# Super Balance: $87493.78
# Expense remains unchanged from 500
#
#  2065-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $365935.59
# Super Balance: $87393.78
# Expense remains unchanged from 500
#
#  2065-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $365571.01
# Super Balance: $87293.78
# Expense remains unchanged from 500
# Year: 46
#
#  2066-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $365204.62
# Super Balance: $87193.78
# Expense remains unchanged from 500
#
#  2066-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $364836.39
# Super Balance: $87093.78
# Expense balance: $290.11
#
#  2066-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $364466.32
# Super Balance: $86993.78
# Expense balance: $206.99
#
#  2066-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $364094.40
# Super Balance: $86893.78
# Expense balance: $211.37
#
#  2066-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $363720.63
# Super Balance: $86793.78
# Expense remains unchanged from 500
#
#  2066-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $363344.98
# Super Balance: $86693.78
# Expense balance: $244.46
#
#  2066-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $362967.46
# Super Balance: $86593.78
# Expense remains unchanged from 500
#
#  2066-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $362588.04
# Super Balance: $86493.78
# Expense balance: $229.99
#
#  2066-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $362206.73
# Super Balance: $86393.78
# Expense remains unchanged from 500
#
#  2066-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $361823.52
# Super Balance: $86293.78
# Expense remains unchanged from 500
#
#  2066-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $361438.38
# Super Balance: $86193.78
# Expense remains unchanged from 500
#
#  2066-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $361051.33
# Super Balance: $86093.78
# Expense remains unchanged from 500
# Year: 47
#
#  2067-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $360662.33
# Super Balance: $85993.78
# Expense balance: $280.62
#
#  2067-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $360271.39
# Super Balance: $85893.78
# Expense balance: $233.10
#
#  2067-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $359878.50
# Super Balance: $85793.78
# Expense balance: $293.29
#
#  2067-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $359483.64
# Super Balance: $85693.78
# Expense balance: $295.79
#
#  2067-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $359086.81
# Super Balance: $85593.78
# Expense remains unchanged from 500
#
#  2067-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $358688.00
# Super Balance: $85493.78
# Expense balance: $245.12
#
#  2067-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $358287.19
# Super Balance: $85393.78
# Expense balance: $219.14
#
#  2067-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $357884.37
# Super Balance: $85293.78
# Expense balance: $200.27
#
#  2067-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $357479.54
# Super Balance: $85193.78
# Expense balance: $275.13
#
#  2067-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $357072.69
# Super Balance: $85093.78
# Expense remains unchanged from 500
#
#  2067-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $356663.80
# Super Balance: $84993.78
# Expense remains unchanged from 500
#
#  2067-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $356252.87
# Super Balance: $84893.78
# Expense balance: $206.07
# Year: 48
#
#  2068-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $355839.89
# Super Balance: $84793.78
# Expense balance: $245.60
#
#  2068-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $355424.84
# Super Balance: $84693.78
# Expense remains unchanged from 500
#
#  2068-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $355007.71
# Super Balance: $84593.78
# Expense remains unchanged from 500
#
#  2068-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $354588.50
# Super Balance: $84493.78
# Expense balance: $252.61
#
#  2068-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $354167.19
# Super Balance: $84393.78
# Expense balance: $268.23
#
#  2068-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $353743.78
# Super Balance: $84293.78
# Expense remains unchanged from 500
#
#  2068-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $353318.25
# Super Balance: $84193.78
# Expense balance: $245.28
#
#  2068-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $352890.59
# Super Balance: $84093.78
# Expense remains unchanged from 500
#
#  2068-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $352460.79
# Super Balance: $83993.78
# Expense balance: $220.95
#
#  2068-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $352028.85
# Super Balance: $83893.78
# Expense remains unchanged from 500
#
#  2068-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $351594.74
# Super Balance: $83793.78
# Expense remains unchanged from 500
#
#  2068-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $351158.46
# Super Balance: $83693.78
# Expense remains unchanged from 500
# Year: 49
#
#  2069-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $350720.01
# Super Balance: $83593.78
# Expense balance: $214.73
#
#  2069-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $350279.36
# Super Balance: $83493.78
# Expense remains unchanged from 500
#
#  2069-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $349836.50
# Super Balance: $83393.78
# Expense remains unchanged from 500
#
#  2069-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $349391.44
# Super Balance: $83293.78
# Expense remains unchanged from 500
#
#  2069-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $348944.14
# Super Balance: $83193.78
# Expense balance: $236.22
#
#  2069-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $348494.61
# Super Balance: $83093.78
# Expense remains unchanged from 500
#
#  2069-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $348042.84
# Super Balance: $82993.78
# Expense remains unchanged from 500
#
#  2069-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $347588.80
# Super Balance: $82893.78
# Expense remains unchanged from 500
#
#  2069-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $347132.49
# Super Balance: $82793.78
# Expense remains unchanged from 500
#
#  2069-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $346673.91
# Super Balance: $82693.78
# Expense balance: $297.72
#
#  2069-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $346213.03
# Super Balance: $82593.78
# Expense balance: $254.36
#
#  2069-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $345749.84
# Super Balance: $82493.78
# Expense balance: $293.80
# Year: 50
#
#  2070-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $345284.34
# Super Balance: $82393.78
# Expense balance: $288.07
#
#  2070-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $344816.51
# Super Balance: $82293.78
# Expense remains unchanged from 500
#
#  2070-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $344346.35
# Super Balance: $82193.78
# Expense balance: $269.51
#
#  2070-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $343873.83
# Super Balance: $82093.78
# Expense balance: $205.11
#
#  2070-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $343398.95
# Super Balance: $81993.78
# Expense remains unchanged from 500
#
#  2070-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $342921.69
# Super Balance: $81893.78
# Expense balance: $298.19
#
#  2070-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $342442.05
# Super Balance: $81793.78
# Expense remains unchanged from 500
#
#  2070-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $341960.01
# Super Balance: $81693.78
# Expense remains unchanged from 500
#
#  2070-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $341475.56
# Super Balance: $81593.78
# Expense remains unchanged from 500
#
#  2070-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $340988.69
# Super Balance: $81493.78
# Expense remains unchanged from 500
#
#  2070-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $340499.38
# Super Balance: $81393.78
# Expense remains unchanged from 500
#
#  2070-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $340007.63
# Super Balance: $81293.78
# Expense balance: $262.39
# Year: 51
#
#  2071-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $339513.42
# Super Balance: $81193.78
# Expense balance: $200.09
#
#  2071-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $339016.73
# Super Balance: $81093.78
# Expense balance: $221.56
#
#  2071-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $338517.57
# Super Balance: $80993.78
# Expense balance: $229.98
#
#  2071-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $338015.90
# Super Balance: $80893.78
# Expense remains unchanged from 500
#
#  2071-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $337511.73
# Super Balance: $80793.78
# Expense remains unchanged from 500
#
#  2071-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $337005.04
# Super Balance: $80693.78
# Expense balance: $273.48
#
#  2071-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $336495.82
# Super Balance: $80593.78
# Expense balance: $242.01
#
#  2071-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $335984.05
# Super Balance: $80493.78
# Expense balance: $272.65
#
#  2071-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $335469.72
# Super Balance: $80393.78
# Expense balance: $245.86
#
#  2071-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $334952.82
# Super Balance: $80293.78
# Expense remains unchanged from 500
#
#  2071-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $334433.33
# Super Balance: $80193.78
# Expense balance: $264.37
#
#  2071-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $333911.25
# Super Balance: $80093.78
# Expense remains unchanged from 500
# Year: 52
#
#  2072-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $333386.55
# Super Balance: $79993.78
# Expense remains unchanged from 500
#
#  2072-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $332859.24
# Super Balance: $79893.78
# Expense remains unchanged from 500
#
#  2072-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $332329.28
# Super Balance: $79793.78
# Expense balance: $226.43
#
#  2072-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $331796.68
# Super Balance: $79693.78
# Expense balance: $214.32
#
#  2072-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $331261.41
# Super Balance: $79593.78
# Expense remains unchanged from 500
#
#  2072-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $330723.47
# Super Balance: $79493.78
# Expense remains unchanged from 500
#
#  2072-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $330182.84
# Super Balance: $79393.78
# Expense balance: $241.60
#
#  2072-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $329639.50
# Super Balance: $79293.78
# Expense balance: $250.80
#
#  2072-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $329093.45
# Super Balance: $79193.78
# Expense balance: $287.43
#
#  2072-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $328544.66
# Super Balance: $79093.78
# Expense remains unchanged from 500
#
#  2072-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $327993.14
# Super Balance: $78993.78
# Expense remains unchanged from 500
#
#  2072-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $327438.85
# Super Balance: $78893.78
# Expense balance: $232.32
# Year: 53
#
#  2073-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $326881.80
# Super Balance: $78793.78
# Expense balance: $272.71
#
#  2073-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $326321.96
# Super Balance: $78693.78
# Expense remains unchanged from 500
#
#  2073-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $325759.32
# Super Balance: $78593.78
# Expense balance: $212.91
#
#  2073-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $325193.86
# Super Balance: $78493.78
# Expense remains unchanged from 500
#
#  2073-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $324625.58
# Super Balance: $78393.78
# Expense remains unchanged from 500
#
#  2073-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $324054.46
# Super Balance: $78293.78
# Expense remains unchanged from 500
#
#  2073-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $323480.48
# Super Balance: $78193.78
# Expense remains unchanged from 500
#
#  2073-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $322903.64
# Super Balance: $78093.78
# Expense balance: $238.93
#
#  2073-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $322323.90
# Super Balance: $77993.78
# Expense balance: $208.51
#
#  2073-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $321741.27
# Super Balance: $77893.78
# Expense balance: $263.98
#
#  2073-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $321155.73
# Super Balance: $77793.78
# Expense remains unchanged from 500
#
#  2073-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $320567.26
# Super Balance: $77693.78
# Expense remains unchanged from 500
# Year: 54

# %%
df
# Out:
#            Date       Income         Tax  SuperContrib  SuperBalance  \
# 0    2020-01-01  4333.333333  703.889583    411.666667   1411.666667
# 1    2020-02-01  4333.333333  703.889583    411.666667   1613.555556
# 2    2020-03-01  4333.333333  703.889583    411.666667   1815.444444
# 3    2020-04-01  4333.333333  703.889583    411.666667   2017.333333
# 4    2020-05-01  4333.333333  703.889583    411.666667   2219.222222
# ..          ...          ...         ...           ...           ...
# 643  2073-08-01     0.000000    0.000000      0.000000  78093.777778
# 644  2073-09-01     0.000000    0.000000      0.000000  77993.777778
# 645  2073-10-01     0.000000    0.000000      0.000000  77893.777778
# 646  2073-11-01     0.000000    0.000000      0.000000  77793.777778
# 647  2073-12-01     0.000000    0.000000      0.000000  77693.777778
#
#         SuperValue  LoanDebt    Expenses  RemainingIncome    SavedAmt
# 0      1411.666667       0.0  253.875699      3375.568051  843.892013
# 1      1621.623333       0.0  205.601075      3423.842675  855.960669
# 2      1832.629783       0.0  231.577076      3397.866674  849.466668
# 3      2044.691266       0.0  284.134061      3345.309689  836.327422
# 4      2257.813055       0.0  278.613848      3350.829902  837.707475
# ..             ...       ...         ...              ...         ...
# 643  322903.635097       0.0    0.000000         0.000000    0.000000
# 644  322323.903273       0.0    0.000000         0.000000    0.000000
# 645  321741.272789       0.0    0.000000         0.000000    0.000000
# 646  321155.729153       0.0    0.000000         0.000000    0.000000
# 647  320567.257799       0.0    0.000000         0.000000    0.000000
#
# [648 rows x 10 columns]

# %%
plt.plot(df['Date'], df['SuperValue'])
plt.plot(df['Date'], df['SuperBalance'])

# %%
plt.plot(df['Date'], df['LoanDebt'])

# %%
myProfile.summary()

# %%
myProfile.loanInfo()

# %%
for loanID, _ in myProfile.loanDict.items():
    
    plt.plot(myProfile.loanDict[loanID].dateHistory, myProfile.loanDict[loanID].loanHistory)

# %%
myProfile.loanDict['2'].loanPaidOff

# %%
print('Loan 1')
print('Start Date:', myProfile.loanDict['1'].startDate)
print('Expected End Date:', myProfile.loanDict['1'].endDate)
print('Finish Date:', myProfile.loanDict['1'].loanPaidOffDate)

# %%
print('Loan 2')
print('Start Date:', myProfile.loanDict['2'].startDate)
print('Expected End Date:', myProfile.loanDict['2'].endDate)
print('Finish Date:', myProfile.loanDict['2'].loanPaidOffDate)

# %%
print('Loan 3')
print('Start Date:', myProfile.loanDict['3'].startDate)
print('Expected End Date:', myProfile.loanDict['3'].endDate)
print('Finish Date:', myProfile.loanDict['3'].loanPaidOffDate)

# %%
plt.plot(myProfile.dateHistory, myProfile.incomeHistory)
plt.title('Remaining Income')
plt.xlabel('Year')
plt.ylabel('$ Amount')
