# %% [markdown]
# # Stochastic Personal Finance Forecasting Simulator
# <b>Author:</b> Tyler Bikaun<br>
# <b>Last Modified:</b> 14.03.2020

# %% [markdown]
# ><b>Purpose:</b> Develop a user simulator based on object oriented design principles for use in stochastic personal financial forecasting.

# %% [markdown]
# <b>Modules Included</b>
# <ol>
#     <li>Asset Value</li>
#     <li>Superannuation</li>
#     <li>Tax</li>
#     <li>Savings</li>
#     <li>Expenses</li>
#     <li>Income</li>
#     <li>Loan</li>
#     <li>Profile</li>
#     <li>Simulation</li>
# </ol>

# %% [markdown]
# ><b>Inheritance:</b> 1:Asset Value to 7:Loan -> 8:Profile -> 9:Simulation

# %% [markdown]
# ### Notebook set-up and importation of libraries

# %%
import datetime
from dateutil.relativedelta import relativedelta
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### Initialisation of Logging

# %%
import logging
logging.basicConfig(filename='simulation.log', level=logging.DEBUG)

# %% [markdown]
# ### Initialisation of Classes

# %% [markdown]
# ><b>Simulation:</b> The simulation class is used for simulating user lifetimes for stochastic modeling and analysis.

# %%
class Simulation():
    """
    Simulation class. Used for simulation functions and data capture.
    """
    
    def __init__(self):
        """
        
        """
        self.dateHistory = []
        
        
    def init_user(self):
        """
        Initialises a user profile for simulation.
        """
        pass
    
        
    def simulate(self):
        """
        Simulates a user lifetime once.
        """
        # Duration of simulation (phase 1)
        dateStart = datetime.date(2020,1,1)
        dateStartTemp = dateStart


        # Iterate over life with month level granularity
        # Phase One - Working life
        print('\n----- ENTERING PHASE ONE -----\n')
        logging.info('ENTERING PHASE ONE')

        while myProfile.age < myProfile.retireAge:
            # Current datetime of step
            print(f'\n {dateStartTemp}')
            logging.debug(f'Current DateTime: {dateStartTemp}')
            print(f'Monthly Income: ${myProfile.income:0.2f}')
            logging.debug(f'Monthly Income: ${myProfile.income:0.2f}')

            # Tax
            # Get taxable amount from income
            tax = myProfile.getTaxAmount(myProfile.income)
            print(f'Tax: ${tax:0.2f}')
            logging.debug(f'Tax: ${tax:0.2f}')

            # Super
            # Contribute to superannuation from income
            myProfile.superContribution(1, myProfile.income)

            tempLoanCost = 0

            # Pay debts
            # An aggregation of loan costs is computed here over all active loans
            for loanID, loanInfo in myProfile.loanDict.items():    # Iterate through loans associated to the profile

                # If the start date of the loan of interest is before the current time stamp, calculate loan payment or make loan inactive if it's finished.
                if myProfile.loanDict[loanID].startDate <= dateStartTemp:

                    # TESTING: This step is currently simulating random increases to loan principal.
                    # This is used to emulate when income goes below zero and loans need to be increased to make up the difference.
                    # This only works if there are active loans, if no loan is active then another method for re-activating or creating a new loan need to be developed.
                    # NEED TO CONFIRM THAT THIS ISNT ATTRIBUTING EXTRA PRINCIPAL TO ALL LOANS... ONE MAY BE ENOUGH.
                    myProfile.loanDict[loanID].increasePrincipalRandomly()

                    # If balance remains on loans - make payment
                    if 0 < myProfile.loanDict[loanID].beginBalance:
                        # Raise payment against loan
                        myProfile.loanDict[loanID].makePayment()
                        # Print payment summary to console
                        myProfile.loanDict[loanID].paymentSummary()

                        # Capture loan history information for future analytics
                        myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, myProfile.loanDict[loanID].beginBalance)

                        # If the loan payment makes the balance zero, make the loan in-active as it's paid off
                        if myProfile.loanDict[loanID].beginBalance == 0:
                            print(f'LOAN {loanID} PAID OFF!')
                            logging.debug(f'LOAN {loanID} PAID OFF!')
                            # Set loanFinished to True
                            myProfile.loanDict[loanID].loanFinished(dateStartTemp)

                        # Loan is not paid off but persists for the next period
                        else:
                            # Capture loanPayment for totalcost aggregation
                            print('ELSE SUMMARY!!!')
                            myProfile.loanDict[loanID].paymentSummary()
    #                         print(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
    #                         logging.debug(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
                            tempLoanCost += myProfile.loanDict[loanID].loanPayment

                    # No principal - either loan hasnt begun or its finished
                    else:
                        myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)

                # Too early - no loans are active
                else:
                    myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
                    pass

            # Expenses
            # Currently randomly increasing expenses to emulate randomness
            # This has logic based on the phase of the user and some other salient information
            expenses =  myProfile.increaseExpenseRandomly(1)

            # Calculate income remaining after costs attributed to tax, expenses, etc.
            myProfile.incomeAfterCosts(tax + tempLoanCost + expenses)
            print(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
            logging.debug(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
            # Capture income history for future analysis
            myProfile.getIncomeHistory(dateStartTemp, myProfile.remainingIncome)

            # Savings
            # Calculate savings based on remaining income (can't save what you don't have)
            savedAmt = myProfile.getSavedAmount(myProfile.remainingIncome)
            print(f'Amount saved this month: ${savedAmt:0.2f}')
            logging.debug(f'Amount saved this month: ${savedAmt:0.2f}')

            # Note: if more draw downs occur on the remaining income, then the savings need to be subtracted explicitly aswell.
            # As this is not the case, it doesn't matter that the savings amount isn't removed from this parameter.


            # Asset value
            # Compute asset value based on compounding period and interest rates 
    #         myProfile.getAssetValue(myProfile, compoundPeriod)

            # Create an ordered dictionary of information
            yield OrderedDict([('Date', dateStartTemp),
                              ('Income', myProfile.income),
                              ('Tax', myProfile.getTaxAmount(myProfile.income)),
                              ('SuperContrib', myProfile.superContrib),
                               ('SuperBalance', myProfile.superBalCumSum),
                               ('SuperValue', myProfile.superValCumSum),
                              ('LoanDebt', tempLoanCost),
                              ('Expenses', expenses),
                              ('RemainingIncome', myProfile.remainingIncome),
                              ('SavedAmt', savedAmt)])

            # Steps through time another month
            dateStartTemp += relativedelta(months=1)

            # if the current month of the year is January and we're not on the first year of the simulation
            # Add another year to the users profile, e.g. age them another year.
            if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
                #print(f'Year: {dateStartTemp.year - dateStart.year}')
                myProfile.ageStep(1)

        # Iterate over life with month level granularity
        # Phase Two - Retirement
        print('\n----- ENTERING PHASE TWO -----\n')
        print(logging.info('ENTERING PHASE TWO'))

        # While the users age is less than the age of death, run the simulation
        while myProfile.age < myProfile.deadAge:
            print(f'\n {dateStartTemp}')
            logging.debug(f'Current DateTime: {dateStartTemp}')

            # Super drawdown
            # Draw down super as this will act as a source of income
            # Need to review how this is used...
            myProfile.superDrawDown()

            # Expenses
            # Expenses in the retirement phase are treated differently to the 
            # working life phase
            expenses =  myProfile.increaseExpenseRandomly(2)

            # Create an ordered dictionary of information
            yield OrderedDict([('Date', dateStartTemp),
                              ('Income', 0),
                              ('Tax', 0),
                              ('SuperContrib', 0),
                              ('SuperBalance', myProfile.superBalCumSum),
                              ('SuperValue', myProfile.superValCumSum),
                              ('LoanDebt', 0),
                              ('Expenses', expenses),
                              ('RemainingIncome', 0),
                              ('SavedAmt', 0)])

            # Steps through time another month
            dateStartTemp += relativedelta(months=1)

            # if the current month of the year is January and we're not on the first year of the simulation
            # Add another year to the users profile, e.g. age them another year.
            if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
                print(f'Year: {dateStartTemp.year - dateStart.year}')
                myProfile.ageStep(1)
                
                
    def monte_carlo_model(self):
        """
        Runs n iterations of the user life simulation and captures results for analysis.
        """
        pass
    
    def statistical_analysis(self):
        """
        Performs a statistical analysis of the monte carlo simulation results. 
        """
        pass

# %% [markdown]
# ><b>Asset Value:</b> The AssetValue class is used for approximating user asset value and wealth. This is initially used for modeling real estate property value. This model currently assumes that the asset value only appreciates at a given rate (asset return rate).<br><br>
# Future model considerations:<ol><li>Integrate stochastic asset return rate... or damages to the market structure?</li></ol>

# %%
class AssetValue():
    """
    Model for approximating asset value and wealth.
    Initially used for property value
    """
    
    def __init__(self, assetReturnRate):
        self.assetReturnRate = assetReturnRate / 12
        
    def getAssetValue(self, assetPrincipal, compoundPeriod):
        # calculates asset value on a periodic compounding per month
        assetValue = assetPrincipal * (1 + self.assetReturnRate)**compoundPeriod
        return assetValue

# %% [markdown]
# ><b>Superunnuation:</b> The Superunnuation class is used for capturing superannuation acquisition over time. Factors that are integrated into this class include: 1. super contributions (monthly freq), 2. initial balance, 3. rate of return, 4. employer contribution rate, 5. fees (administration and investment), 6. insurance premiums, and 7. indireect costs that aren't captured within these buckets.

# %%
class Superannuation():
    """
    Note: Assumes superannuation is run via an institution and is not self managed.
    
    """
    
    def __init__(self, contribRate):
        self.superContrib = 0
        self.superInitialBal = 1000   # initial super balance
        self.superReturnRate = 0.06 / 12
        
        self.contribRate = contribRate   # Employer contribution rate
        
        # Cumulative Sum of Super Balance and Value
        self.superBalCumSum = 0
        self.superValCumSum = 0
        
    def superFees(self, phase):
        if phase == 1:
            # phase 1 - before retirement
            self.contribFee = 1/12
        if phase == 2:
            # phase 2 - retirement
            self.contribFee = 0
        self.adminFee = 100
        self.investmentFee = 1/12
        self.insurancePrem = 1/12
        self.indirectCosts = 0.2/12
        self.superFeesTotal = 0
        
        self.superFeesTotal = self.adminFee + self.investmentFee * self.superContrib + \
                            self.contribFee * self.superContrib + self.insurancePrem * self.superContrib + \
                            self.indirectCosts * self.superContrib
        print(f'Super Fees: ${self.superFeesTotal:0.2f}')
        
    def superValue(self, phase):
        
        if self.superBalCumSum == 0:
            print('adding initial value to superVal')
            self.superValCumSum += self.superContrib + self.superInitialBal
        elif phase == 1:
#             print(f'{self.superValCumSum}-{self.superContrib}-{self.superFeesTotal}-{1 + self.superReturnRate}')
            
            self.superValCumSum = (self.superValCumSum + self.superContrib - self.superFeesTotal) * (1 + self.superReturnRate)
        elif phase == 2:
            self.superValCumSum = (self.superValCumSum - self.drawdownAmt - self.superFeesTotal) * (1 + self.superReturnRate)
        
        print(f'Super Value: ${self.superValCumSum:0.2f}')
        
        
    def superBalance(self):
        
        if self.superBalCumSum == 0:
            print('adding initial value to superBal')
            self.superBalCumSum += self.superContrib + self.superInitialBal
        else:
            self.superBalCumSum += self.superContrib - self.superFeesTotal
        
        print(f'Super Balance: ${self.superBalCumSum:0.2f}')
        
    def superContribution(self, phase, income):
        # Monthly income...
        self.superContrib = self.contribRate * income
        print(f'Super Contribution: ${self.superContrib:0.2f}')
        
        self.superFees(phase)
        self.superValue(phase)
        self.superBalance()
        
        
    def superDrawDown(self):
        # Drawdown once retirement starts and contributions cease
        retirementIncome = 25000
        self.drawdownAmt = retirementIncome / 12
        
        self.superContribution(2, 0)   # no income within phase 2

# %% [markdown]
# ><b>Tax:</b> The Tax class is used to calculate payable tax on taxable income in accordance with tax rates set by the Australian Tax Office (ATO).

# %%
class Tax():
    """
    Model for taxing income.
    Calculates tax on gross annual income.
    Note: Tax rates are current as of 2019-2020 and sourced from the ATO.
    """
    
    def __init__(self):
        self.tax_table_income = {1: [0, 18200],
                    2: [18201, 37000],
                    3: [37001, 90000],
                    4: [90001, 180000],
                    5: [180001, 1000000000]}   # ridiculous upper limit

        self.tax_table_paymt = {1: [0, 0],
                        2: [0.19, 0],
                        3: [0.325, 3572],
                        4: [0.37, 20797],
                        5: [0.45, 54097]}
    
    def getTaxAmount(self, income):
        
        income = income * 12 # input is per month...
        
        for key, value in self.tax_table_income.items():
            if value[0] <= income <= value[1]:
                tax_to_pay = self.tax_table_paymt[key][1] + self.tax_table_paymt[key][0] * \
                (income - self.tax_table_income[key][0])
                
        monthlyIncomeTax = tax_to_pay / 12
        
        return monthlyIncomeTax

# %% [markdown]
# ><b>Savings:</b> The Savings class is used for capturing user savings based on proportions saved which vary over time. Savings also work as a buffer for rare events that cannot be directly covered by income.

# %%
class Savings():
    """
    Model for savings.
    """
    
    def __init__(self, proportionSaved):
        self.proportionSaved = proportionSaved
        
        
        # data capture
        self.dataHistory = []
        self.savingHistory = []
        
    def getSavedAmount(self, remainingIncome):
        """
        Gets amount saved from remainingIncome
        """
        if remainingIncome > 0:
            return remainingIncome*self.proportionSaved
        else: 
            return 0
        
    # Data Capture Functions
    def getSavingHistory(self, date, savingInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.savingHistory.append(savingInfo)

# %% [markdown]
# ><b>Expenses:</b> The Expenses class is used to capture expenses relating to life in general. This is currently modelled as being stochastic within certain limits based on living costs.

# %%
class Expenses():
    """
    Model for general expenses.
    """
    
    def __init__(self, expenses):
        # Everything is on a monthly basis in the model...
        self.expenses = expenses
        
    def increaseExpenseRandomly(self, phase):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """

        expensesTemp = 0
        if (0.5 < np.random.uniform(0,1)):
            if phase == 2:
                increaseAmt = np.random.uniform(0.8, 1.2)*(self.expenses / 2)
            else:
                increaseAmt = np.random.uniform(0.8, 1.2)*(self.expenses)
            
            print(f'Expense balance: ${increaseAmt:0.2f}')
            return increaseAmt
        else:
            print(f'Expenses remain unchanged at: ${self.expenses:0.2f}', )
            if phase == 2:
                return self.expenses / 2
            else:
                return self.expenses

# %% [markdown]
# ><b>Income:</b> The Income class is used for generating cash flow for users. Income is determined by three means (as defined by various financial institutions): 1. earned, 2. passive, and 3. portfolio.

# %%
class Income():
    """
    Model for income (earned, passive, portfolio).
    """
    
    def __init__(self, income):
        # Everything is on a monthly basis in the model...
        self.income = income
        self.remainingIncome = self.income    # init
        self.dateHistory = []
        self.incomeHistory = []

        
    def incomeAfterCosts(self, loanPaymentSum):
        """
        Aggregated Monthly.
        """
        costs = loanPaymentSum
        self.remainingIncome = self.income - costs
        
    def getIncomeHistory(self, date, incomeInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.incomeHistory.append(incomeInfo)

# %% [markdown]
# ><b>Loan:</b> The Loan class captures loans and their attributes. Attributes include: 1. principal, 2. interest rate, 3. annual payments, 4. duration, and 5. startdate. Loans are an important factor in user simulation as they can be stackable (have more than one at a time).

# %%
class Loan():
    """
    Model for user profile loans.
    """
    
    def __init__(self, loanID, principal, interestRate, annualPayments, duration, startDate, loanPaymentExtra):
        self.principal = principal
        self.interestRate = interestRate
        self.annualPayments = annualPayments
        self.duration = duration
        self.startDate = datetime.datetime.strptime(startDate, '%d-%m-%Y').date()
        self.loanID = loanID
        self.period = 1
        self.endDate = (self.startDate + relativedelta(years=self.duration))
        self.beginBalance = self.principal
        self.endBalance = self.principal
        self.loanPaidOff = False
        self.loanPaidOffDate = 'Not paid off - Active'
        self.loanActive = False
        self.loanPaymentExtra = loanPaymentExtra
        self.loanPaymentMinimum = -round(np.pmt(self.interestRate/self.annualPayments, self.duration*self.annualPayments, self.principal), 2)
        
        # First loan payment amount
        # Note: loanPaymentExtra is a nominal payment that is added to the minimum loan service amount.
        self.loanPayment = self.loanPaymentExtra + self.loanPaymentMinimum
            
        # For data capture
        self.dateHistory = []
        self.loanHistory = []
    
    def initDesc(self):
        return f'''Loan {self.loanID} has principal of ${self.principal} over duration {self.duration} years with expected finish date of {self.endDate} - remaining balance: ${self.endBalance} - Minimum payment amount: ${self.loanPaymentMinimum}'''
    
    # Main Functions
    def makePayment(self):
        """
        Make a payment against the principal.
        """
        self.loanActive = True
        self.interest = round(((self.interestRate/self.annualPayments) * self.beginBalance), 2)
        self.loanPayment = min(self.loanPayment, self.beginBalance + self.interest)
        self.endBalance = self.beginBalance - (self.loanPayment - self.interest)
        self.period += 1
        self.beginBalance = self.endBalance
        
    def paymentSummary(self):
        try:
            print(f'Period: {self.period} BeginBalance: {self.beginBalance:0.2f} Principal: {self.principal:0.2f} Interest: {self.interest:0.2f} Payment: {self.loanPayment:0.2f}')
        except:
            print('Not enough information. Loan has likely not become active.')

    def loanFinished(self, date):
        """
        Used when a loan is finished.
        """
        #TODO: Add date for when loan finishes... as this may not be constant...
        self.loanPaidOff = True
        self.loanActive = False
        self.loanPaidOffDate = date
    
    # Misc Functions
    def increasePrincipal(self, increaseAmt):
        """
        Increase the amount of loan principal via month begin balance.
        """
        self.beginBalance += increaseAmt
        
    def increasePrincipalRandomly(self):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """
        if (0.99 < np.random.uniform(0,1)) and self.loanActive:
            if self.loanPaidOff == False:
                increaseAmt = np.random.randint(0,10)*1000
                self.beginBalance += increaseAmt
                print(f'Increased {self.loanID} balance by ${increaseAmt}')       
        
    # Data Capture Functions
    def getLoanHistory(self, date, loanInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.loanHistory.append(loanInfo)

# %% [markdown]
# ><b>Profile:</b> The Profile class is for generating user profiles. A user profile can have the previously defined classes attributed to it e.g. income, expenses, savings, tax, superannuations, and asset value. A user profile is simulated over a lifetime, the lifetime is split into two phases 1. working, and 2. retirement. In the first phase, working, the user typically would take out loans, have income, commit to superannuation, etc. In the second phase, retirement, the income streams change, superannuation starts to be drawn down, etc. Parameters of the user profile include 1. name, 2. age, 3. expected retirement age (will be an output rather than an input in the future), and 4. expected age of death (assumed from health statistics based on gender; could be extended based on other salient factors).

# %%
class Profile(Income, Expenses, Savings, Tax, Superannuation, AssetValue):
    """
    Profile for user. Contains their general information and meta data for financial modeling.
    """
    
    # Initializer / Instance Attributes
    def __init__(self, name, age, retireAge, deadAge, incomePA, expensesPM, proportionSaved):
        self.name = name
        self.age = age
        self.retireAge = retireAge
        self.deadAge = deadAge
        # Loans
        self.hasLoan = False
        self.loanDict = {}
        self.noLoans = 0
        self.loanPaymentSum = 0
        # Income
        self.hasIncome = False
        self.income = incomePA / 12
        self.hasIncome = True
        # Expenses
        self.expenses = expensesPM    # Expenses per month
        # Savings
        self.proportionSaved = proportionSaved

        
        # Inherit Loan init.. by inheriting this class, we can access it's attributes and methods...
        Income.__init__(self, self.income)  # pass attribute to class
        
        # Init Expenses
        Expenses.__init__(self, self.expenses)
        
        
        # Init Savings
        Savings.__init__(self, self.proportionSaved)
        
        # Init Tax
        Tax.__init__(self)
        
        # init super
        Superannuation.__init__(self, 0.095)
        
        # init asset value
        AssetValue.__init__(self, 0.06)
        
        
    # Profile
    def ageStep(self, year):
        """
        Used to age the users profile and step through time.
        """
        self.age += year
    
    def summary(self):
        print(f'{self.name} is {self.age} years old and has an income of ${self.income:0.2f} per month.\n')
    
    # Loan
    def getLoan(self, principal, interestRate, annualPayments, duration, startDate, loanPaymentExtra):
        """
        Allocates a loan to the profile.
        """
        
        self.hasLoan = True
        self.noLoans += 1
        print(f'Number of loans: {self.noLoans}')
        loanID = str(self.noLoans)
        self.loanDict[loanID] = Loan(loanID, principal, interestRate, annualPayments, duration, startDate, loanPaymentExtra)
        
    def removeLoan(self, loanID):
        """
        Removes a loan from the profile. TODO: update to remove once paid off.
        """
        try:
            del self.loanDict[loanID]
        except:
            print('Loan doesnt exist')
            
    def loanDesc(self):
        """
        Summary of active loans.
        """
        self.currentLoans = len(self.loanDict)
        try:
            return f'Current active loans for {self.name}: {self.currentLoans}'
        except:
            return f'{self.name} has no loan'
        
    def loanInfo(self):
        """
        Detailed description of loan dict. For debugging purposes.
        """
        for loanID, loanDetails in self.loanDict.items():
            print(f'{loanDetails.initDesc()}')

# %% [markdown]
# ## Running Basic User Simulation

# %% [markdown]
# ### Initialise user profile with basic information

# %%
def init_profile():
    """
    Profile initialisation.
    """
    # Initialise Profile class
    myProfile = Profile(name='tyler',age=26,retireAge=65,deadAge=80,incomePA=52000,expensesPM=1000,proportionSaved=0.25)

    # Initialise loans and attribute them to the user profile
    # Loan 1 - mortgage
    myProfile.getLoan(principal=300000,interestRate=0.04,annualPayments=12,duration=25,startDate='1-1-2021', loanPaymentExtra=0)
    # Loan 2 - car
    myProfile.getLoan(principal=50000,interestRate=0.12,annualPayments=12,duration=5,startDate='01-01-2025', loanPaymentExtra=50)
    # Loan 3 - car 2
    myProfile.getLoan(principal=7000,interestRate=0.08,annualPayments=12,duration=10,startDate='01-06-2027', loanPaymentExtra=250)
    
    # Output information pertaining to to user profile summary and loan descriptions/information
    myProfile.summary()
    myProfile.loanDesc()
    myProfile.loanInfo()
    
    return myProfile

# %% [raw]
# # Very good function...
# print(help(Profile))

# %%
# Initialise a profile with the information in the previous function...
myProfile = init_profile()
# Out:
# Number of loans: 1
# Number of loans: 2
# Number of loans: 3
# tyler is 26 years old and has an income of $4333.33 per month.
#
# Loan 1 has principal of $300000 over duration 25 years with expected finish date of 2046-01-01 - remaining balance: $300000 - Minimum payment amount: $1583.51
# Loan 2 has principal of $50000 over duration 5 years with expected finish date of 2030-01-01 - remaining balance: $50000 - Minimum payment amount: $1112.22
# Loan 3 has principal of $7000 over duration 10 years with expected finish date of 2037-06-01 - remaining balance: $7000 - Minimum payment amount: $84.93

# %% [markdown]
# ### Simulate User Profile - 1 Lifetime

# %% [markdown]
# #### Simulation Iterations
# Note: Simulation outputs on a monthly frequency.

# %%
def simulate():
    # Duration of simulation (phase 1)
    dateStart = datetime.date(2020,1,1)
    dateStartTemp = dateStart
    
    
    # Iterate over life with month level granularity
    # Phase One - Working life
    print('\n----- ENTERING PHASE ONE -----\n')
    logging.info('ENTERING PHASE ONE')
    
    while myProfile.age < myProfile.retireAge:
        # Current datetime of step
        print(f'\n {dateStartTemp}')
        logging.debug(f'Current DateTime: {dateStartTemp}')
        print(f'Monthly Income: ${myProfile.income:0.2f}')
        logging.debug(f'Monthly Income: ${myProfile.income:0.2f}')
        
        # Tax
        # Get taxable amount from income
        tax = myProfile.getTaxAmount(myProfile.income)
        print(f'Tax: ${tax:0.2f}')
        logging.debug(f'Tax: ${tax:0.2f}')

        # Super
        # Contribute to superannuation from income
        myProfile.superContribution(1, myProfile.income)

        tempLoanCost = 0

        # Pay debts
        # An aggregation of loan costs is computed here over all active loans
        for loanID, loanInfo in myProfile.loanDict.items():    # Iterate through loans associated to the profile

            # If the start date of the loan of interest is before the current time stamp, calculate loan payment or make loan inactive if it's finished.
            if myProfile.loanDict[loanID].startDate <= dateStartTemp:

                # TESTING: This step is currently simulating random increases to loan principal.
                # This is used to emulate when income goes below zero and loans need to be increased to make up the difference.
                # This only works if there are active loans, if no loan is active then another method for re-activating or creating a new loan need to be developed.
                # NEED TO CONFIRM THAT THIS ISNT ATTRIBUTING EXTRA PRINCIPAL TO ALL LOANS... ONE MAY BE ENOUGH.
                myProfile.loanDict[loanID].increasePrincipalRandomly()

                # If balance remains on loans - make payment
                if 0 < myProfile.loanDict[loanID].beginBalance:
                    # Raise payment against loan
                    myProfile.loanDict[loanID].makePayment()
                    # Print payment summary to console
                    myProfile.loanDict[loanID].paymentSummary()

                    # Capture loan history information for future analytics
                    myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, myProfile.loanDict[loanID].beginBalance)

                    # If the loan payment makes the balance zero, make the loan in-active as it's paid off
                    if myProfile.loanDict[loanID].beginBalance == 0:
                        print(f'LOAN {loanID} PAID OFF!')
                        logging.debug(f'LOAN {loanID} PAID OFF!')
                        # Set loanFinished to True
                        myProfile.loanDict[loanID].loanFinished(dateStartTemp)
                    
                    # Loan is not paid off but persists for the next period
                    else:
                        # Capture loanPayment for totalcost aggregation
                        print('ELSE SUMMARY!!!')
                        myProfile.loanDict[loanID].paymentSummary()
#                         print(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
#                         logging.debug(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
                        tempLoanCost += myProfile.loanDict[loanID].loanPayment
    
                # No principal - either loan hasnt begun or its finished
                else:
                    myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
            
            # Too early - no loans are active
            else:
                myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
                pass

        # Expenses
        # Currently randomly increasing expenses to emulate randomness
        # This has logic based on the phase of the user and some other salient information
        expenses =  myProfile.increaseExpenseRandomly(1)
        
        # Calculate income remaining after costs attributed to tax, expenses, etc.
        myProfile.incomeAfterCosts(tax + tempLoanCost + expenses)
        print(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
        logging.debug(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
        # Capture income history for future analysis
        myProfile.getIncomeHistory(dateStartTemp, myProfile.remainingIncome)

        # Savings
        # Calculate savings based on remaining income (can't save what you don't have)
        savedAmt = myProfile.getSavedAmount(myProfile.remainingIncome)
        print(f'Amount saved this month: ${savedAmt:0.2f}')
        logging.debug(f'Amount saved this month: ${savedAmt:0.2f}')

        # Note: if more draw downs occur on the remaining income, then the savings need to be subtracted explicitly aswell.
        # As this is not the case, it doesn't matter that the savings amount isn't removed from this parameter.
        

        # Asset value
        # Compute asset value based on compounding period and interest rates 
#         myProfile.getAssetValue(myProfile, compoundPeriod)

        # Create an ordered dictionary of information
        yield OrderedDict([('Date', dateStartTemp),
                          ('Income', myProfile.income),
                          ('Tax', myProfile.getTaxAmount(myProfile.income)),
                          ('SuperContrib', myProfile.superContrib),
                           ('SuperBalance', myProfile.superBalCumSum),
                           ('SuperValue', myProfile.superValCumSum),
                          ('LoanDebt', tempLoanCost),
                          ('Expenses', expenses),
                          ('RemainingIncome', myProfile.remainingIncome),
                          ('SavedAmt', savedAmt)])

        # Steps through time another month
        dateStartTemp += relativedelta(months=1)

        # if the current month of the year is January and we're not on the first year of the simulation
        # Add another year to the users profile, e.g. age them another year.
        if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
            #print(f'Year: {dateStartTemp.year - dateStart.year}')
            myProfile.ageStep(1)
            
    # Iterate over life with month level granularity
    # Phase Two - Retirement
    print('\n----- ENTERING PHASE TWO -----\n')
    print(logging.info('ENTERING PHASE TWO'))
    
    # While the users age is less than the age of death, run the simulation
    while myProfile.age < myProfile.deadAge:
        print(f'\n {dateStartTemp}')
        logging.debug(f'Current DateTime: {dateStartTemp}')
        
        # Super drawdown
        # Draw down super as this will act as a source of income
        # Need to review how this is used...
        myProfile.superDrawDown()
        
        # Expenses
        # Expenses in the retirement phase are treated differently to the 
        # working life phase
        expenses =  myProfile.increaseExpenseRandomly(2)
        
        # Create an ordered dictionary of information
        yield OrderedDict([('Date', dateStartTemp),
                          ('Income', 0),
                          ('Tax', 0),
                          ('SuperContrib', 0),
                          ('SuperBalance', myProfile.superBalCumSum),
                          ('SuperValue', myProfile.superValCumSum),
                          ('LoanDebt', 0),
                          ('Expenses', expenses),
                          ('RemainingIncome', 0),
                          ('SavedAmt', 0)])
        
        # Steps through time another month
        dateStartTemp += relativedelta(months=1)
        
        # if the current month of the year is January and we're not on the first year of the simulation
        # Add another year to the users profile, e.g. age them another year.
        if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
            print(f'Year: {dateStartTemp.year - dateStart.year}')
            myProfile.ageStep(1)

# %%
df = pd.DataFrame(simulate())
# Out:
# ----- ENTERING PHASE ONE -----
#
#
#  2020-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# adding initial value to superVal
# Super Value: $1411.67
# adding initial value to superBal
# Super Balance: $1411.67
# Expense balance: $962.18
# Income Remaining: $2667.26
# Amount saved this month: $666.82
#
#  2020-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $1621.62
# Super Balance: $1613.56
# Expense balance: $929.22
# Income Remaining: $2700.23
# Amount saved this month: $675.06
#
#  2020-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $1832.63
# Super Balance: $1815.44
# Expense balance: $1172.13
# Income Remaining: $2457.32
# Amount saved this month: $614.33
#
#  2020-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2044.69
# Super Balance: $2017.33
# Expense balance: $859.36
# Income Remaining: $2770.08
# Amount saved this month: $692.52
#
#  2020-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2257.81
# Super Balance: $2219.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $2629.44
# Amount saved this month: $657.36
#
#  2020-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2472.00
# Super Balance: $2421.11
# Expense balance: $1105.89
# Income Remaining: $2523.55
# Amount saved this month: $630.89
#
#  2020-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2687.26
# Super Balance: $2623.00
# Expenses remain unchanged at: $1000.00
# Income Remaining: $2629.44
# Amount saved this month: $657.36
#
#  2020-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $2903.59
# Super Balance: $2824.89
# Expenses remain unchanged at: $1000.00
# Income Remaining: $2629.44
# Amount saved this month: $657.36
#
#  2020-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3121.01
# Super Balance: $3026.78
# Expenses remain unchanged at: $1000.00
# Income Remaining: $2629.44
# Amount saved this month: $657.36
#
#  2020-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3339.51
# Super Balance: $3228.67
# Expense balance: $1123.10
# Income Remaining: $2506.35
# Amount saved this month: $626.59
#
#  2020-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3559.11
# Super Balance: $3430.56
# Expense balance: $967.02
# Income Remaining: $2662.43
# Amount saved this month: $665.61
#
#  2020-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $3779.80
# Super Balance: $3632.44
# Expense balance: $1059.26
# Income Remaining: $2570.18
# Amount saved this month: $642.55
#
#  2021-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4001.60
# Super Balance: $3834.33
# Period: 2 BeginBalance: 299416.49 Principal: 300000.00 Interest: 1000.00 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 2 BeginBalance: 299416.49 Principal: 300000.00 Interest: 1000.00 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2021-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4224.51
# Super Balance: $4036.22
# Period: 3 BeginBalance: 298831.03 Principal: 300000.00 Interest: 998.05 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 3 BeginBalance: 298831.03 Principal: 300000.00 Interest: 998.05 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2021-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4448.53
# Super Balance: $4238.11
# Period: 4 BeginBalance: 298243.62 Principal: 300000.00 Interest: 996.10 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 4 BeginBalance: 298243.62 Principal: 300000.00 Interest: 996.10 Payment: 1583.51
# Expense balance: $1116.02
# Income Remaining: $929.92
# Amount saved this month: $232.48
#
#  2021-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4673.67
# Super Balance: $4440.00
# Period: 5 BeginBalance: 297654.26 Principal: 300000.00 Interest: 994.15 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 5 BeginBalance: 297654.26 Principal: 300000.00 Interest: 994.15 Payment: 1583.51
# Expense balance: $932.72
# Income Remaining: $1113.21
# Amount saved this month: $278.30
#
#  2021-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $4899.94
# Super Balance: $4641.89
# Period: 6 BeginBalance: 297062.93 Principal: 300000.00 Interest: 992.18 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 6 BeginBalance: 297062.93 Principal: 300000.00 Interest: 992.18 Payment: 1583.51
# Expense balance: $1142.84
# Income Remaining: $903.09
# Amount saved this month: $225.77
#
#  2021-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5127.33
# Super Balance: $4843.78
# Period: 7 BeginBalance: 296469.63 Principal: 300000.00 Interest: 990.21 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 7 BeginBalance: 296469.63 Principal: 300000.00 Interest: 990.21 Payment: 1583.51
# Expense balance: $1198.79
# Income Remaining: $847.14
# Amount saved this month: $211.78
#
#  2021-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5355.87
# Super Balance: $5045.67
# Period: 8 BeginBalance: 295874.35 Principal: 300000.00 Interest: 988.23 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 8 BeginBalance: 295874.35 Principal: 300000.00 Interest: 988.23 Payment: 1583.51
# Expense balance: $1195.90
# Income Remaining: $850.03
# Amount saved this month: $212.51
#
#  2021-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5585.55
# Super Balance: $5247.56
# Period: 9 BeginBalance: 295277.09 Principal: 300000.00 Interest: 986.25 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 9 BeginBalance: 295277.09 Principal: 300000.00 Interest: 986.25 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2021-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $5816.37
# Super Balance: $5449.44
# Period: 10 BeginBalance: 294677.84 Principal: 300000.00 Interest: 984.26 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 10 BeginBalance: 294677.84 Principal: 300000.00 Interest: 984.26 Payment: 1583.51
# Expense balance: $921.04
# Income Remaining: $1124.89
# Amount saved this month: $281.22
#
#  2021-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6048.35
# Super Balance: $5651.33
# Period: 11 BeginBalance: 294076.59 Principal: 300000.00 Interest: 982.26 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 11 BeginBalance: 294076.59 Principal: 300000.00 Interest: 982.26 Payment: 1583.51
# Expense balance: $1143.43
# Income Remaining: $902.51
# Amount saved this month: $225.63
#
#  2021-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6281.49
# Super Balance: $5853.22
# Period: 12 BeginBalance: 293473.34 Principal: 300000.00 Interest: 980.26 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 12 BeginBalance: 293473.34 Principal: 300000.00 Interest: 980.26 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2021-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6515.80
# Super Balance: $6055.11
# Period: 13 BeginBalance: 292868.07 Principal: 300000.00 Interest: 978.24 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 13 BeginBalance: 292868.07 Principal: 300000.00 Interest: 978.24 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2022-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6751.28
# Super Balance: $6257.00
# Period: 14 BeginBalance: 292260.79 Principal: 300000.00 Interest: 976.23 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 14 BeginBalance: 292260.79 Principal: 300000.00 Interest: 976.23 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2022-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $6987.93
# Super Balance: $6458.89
# Period: 15 BeginBalance: 291651.48 Principal: 300000.00 Interest: 974.20 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 15 BeginBalance: 291651.48 Principal: 300000.00 Interest: 974.20 Payment: 1583.51
# Expense balance: $1168.77
# Income Remaining: $877.16
# Amount saved this month: $219.29
#
#  2022-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7225.77
# Super Balance: $6660.78
# Period: 16 BeginBalance: 291040.14 Principal: 300000.00 Interest: 972.17 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 16 BeginBalance: 291040.14 Principal: 300000.00 Interest: 972.17 Payment: 1583.51
# Expense balance: $922.08
# Income Remaining: $1123.85
# Amount saved this month: $280.96
#
#  2022-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7464.80
# Super Balance: $6862.67
# Period: 17 BeginBalance: 290426.76 Principal: 300000.00 Interest: 970.13 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 17 BeginBalance: 290426.76 Principal: 300000.00 Interest: 970.13 Payment: 1583.51
# Expense balance: $1002.41
# Income Remaining: $1043.52
# Amount saved this month: $260.88
#
#  2022-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7705.02
# Super Balance: $7064.56
# Period: 18 BeginBalance: 289811.34 Principal: 300000.00 Interest: 968.09 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 18 BeginBalance: 289811.34 Principal: 300000.00 Interest: 968.09 Payment: 1583.51
# Expense balance: $1199.19
# Income Remaining: $846.75
# Amount saved this month: $211.69
#
#  2022-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $7946.44
# Super Balance: $7266.44
# Period: 19 BeginBalance: 289193.87 Principal: 300000.00 Interest: 966.04 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 19 BeginBalance: 289193.87 Principal: 300000.00 Interest: 966.04 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2022-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8189.07
# Super Balance: $7468.33
# Period: 20 BeginBalance: 288574.34 Principal: 300000.00 Interest: 963.98 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 20 BeginBalance: 288574.34 Principal: 300000.00 Interest: 963.98 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2022-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8432.92
# Super Balance: $7670.22
# Period: 21 BeginBalance: 287952.74 Principal: 300000.00 Interest: 961.91 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 21 BeginBalance: 287952.74 Principal: 300000.00 Interest: 961.91 Payment: 1583.51
# Expense balance: $830.33
# Income Remaining: $1215.61
# Amount saved this month: $303.90
#
#  2022-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8677.98
# Super Balance: $7872.11
# Period: 22 BeginBalance: 287329.07 Principal: 300000.00 Interest: 959.84 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 22 BeginBalance: 287329.07 Principal: 300000.00 Interest: 959.84 Payment: 1583.51
# Expense balance: $1069.77
# Income Remaining: $976.17
# Amount saved this month: $244.04
#
#  2022-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $8924.27
# Super Balance: $8074.00
# Period: 23 BeginBalance: 286703.32 Principal: 300000.00 Interest: 957.76 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 23 BeginBalance: 286703.32 Principal: 300000.00 Interest: 957.76 Payment: 1583.51
# Expense balance: $1016.96
# Income Remaining: $1028.97
# Amount saved this month: $257.24
#
#  2022-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9171.79
# Super Balance: $8275.89
# Period: 24 BeginBalance: 286075.49 Principal: 300000.00 Interest: 955.68 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 24 BeginBalance: 286075.49 Principal: 300000.00 Interest: 955.68 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2022-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9420.54
# Super Balance: $8477.78
# Period: 25 BeginBalance: 285445.56 Principal: 300000.00 Interest: 953.58 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 25 BeginBalance: 285445.56 Principal: 300000.00 Interest: 953.58 Payment: 1583.51
# Expense balance: $858.31
# Income Remaining: $1187.63
# Amount saved this month: $296.91
#
#  2023-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9670.54
# Super Balance: $8679.67
# Period: 26 BeginBalance: 284813.54 Principal: 300000.00 Interest: 951.49 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 26 BeginBalance: 284813.54 Principal: 300000.00 Interest: 951.49 Payment: 1583.51
# Expense balance: $1165.61
# Income Remaining: $880.32
# Amount saved this month: $220.08
#
#  2023-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $9921.80
# Super Balance: $8881.56
# Period: 27 BeginBalance: 284179.41 Principal: 300000.00 Interest: 949.38 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 27 BeginBalance: 284179.41 Principal: 300000.00 Interest: 949.38 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2023-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10174.30
# Super Balance: $9083.44
# Period: 28 BeginBalance: 283543.16 Principal: 300000.00 Interest: 947.26 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 28 BeginBalance: 283543.16 Principal: 300000.00 Interest: 947.26 Payment: 1583.51
# Expense balance: $1124.28
# Income Remaining: $921.65
# Amount saved this month: $230.41
#
#  2023-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10428.07
# Super Balance: $9285.33
# Period: 29 BeginBalance: 282904.79 Principal: 300000.00 Interest: 945.14 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 29 BeginBalance: 282904.79 Principal: 300000.00 Interest: 945.14 Payment: 1583.51
# Expense balance: $1040.42
# Income Remaining: $1005.51
# Amount saved this month: $251.38
#
#  2023-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10683.11
# Super Balance: $9487.22
# Period: 30 BeginBalance: 282264.30 Principal: 300000.00 Interest: 943.02 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 30 BeginBalance: 282264.30 Principal: 300000.00 Interest: 943.02 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2023-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $10939.42
# Super Balance: $9689.11
# Period: 31 BeginBalance: 281621.67 Principal: 300000.00 Interest: 940.88 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 31 BeginBalance: 281621.67 Principal: 300000.00 Interest: 940.88 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2023-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11197.02
# Super Balance: $9891.00
# Period: 32 BeginBalance: 280976.90 Principal: 300000.00 Interest: 938.74 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 32 BeginBalance: 280976.90 Principal: 300000.00 Interest: 938.74 Payment: 1583.51
# Expense balance: $1070.54
# Income Remaining: $975.40
# Amount saved this month: $243.85
#
#  2023-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11455.90
# Super Balance: $10092.89
# Period: 33 BeginBalance: 280329.98 Principal: 300000.00 Interest: 936.59 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 33 BeginBalance: 280329.98 Principal: 300000.00 Interest: 936.59 Payment: 1583.51
# Expense balance: $874.22
# Income Remaining: $1171.71
# Amount saved this month: $292.93
#
#  2023-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11716.08
# Super Balance: $10294.78
# Period: 34 BeginBalance: 279680.90 Principal: 300000.00 Interest: 934.43 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 34 BeginBalance: 279680.90 Principal: 300000.00 Interest: 934.43 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2023-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $11977.56
# Super Balance: $10496.67
# Period: 35 BeginBalance: 279029.66 Principal: 300000.00 Interest: 932.27 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 35 BeginBalance: 279029.66 Principal: 300000.00 Interest: 932.27 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2023-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $12240.35
# Super Balance: $10698.56
# Period: 36 BeginBalance: 278376.25 Principal: 300000.00 Interest: 930.10 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 36 BeginBalance: 278376.25 Principal: 300000.00 Interest: 930.10 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2023-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $12504.45
# Super Balance: $10900.44
# Period: 37 BeginBalance: 277720.66 Principal: 300000.00 Interest: 927.92 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 37 BeginBalance: 277720.66 Principal: 300000.00 Interest: 927.92 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2024-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $12769.87
# Super Balance: $11102.33
# Period: 38 BeginBalance: 277062.89 Principal: 300000.00 Interest: 925.74 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 38 BeginBalance: 277062.89 Principal: 300000.00 Interest: 925.74 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2024-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13036.61
# Super Balance: $11304.22
# Period: 39 BeginBalance: 276402.92 Principal: 300000.00 Interest: 923.54 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 39 BeginBalance: 276402.92 Principal: 300000.00 Interest: 923.54 Payment: 1583.51
# Expense balance: $1160.47
# Income Remaining: $885.47
# Amount saved this month: $221.37
#
#  2024-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13304.70
# Super Balance: $11506.11
# Period: 40 BeginBalance: 275740.75 Principal: 300000.00 Interest: 921.34 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 40 BeginBalance: 275740.75 Principal: 300000.00 Interest: 921.34 Payment: 1583.51
# Expense balance: $998.88
# Income Remaining: $1047.06
# Amount saved this month: $261.76
#
#  2024-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13574.12
# Super Balance: $11708.00
# Period: 41 BeginBalance: 275076.38 Principal: 300000.00 Interest: 919.14 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 41 BeginBalance: 275076.38 Principal: 300000.00 Interest: 919.14 Payment: 1583.51
# Expense balance: $1131.60
# Income Remaining: $914.34
# Amount saved this month: $228.58
#
#  2024-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $13844.89
# Super Balance: $11909.89
# Period: 42 BeginBalance: 274409.79 Principal: 300000.00 Interest: 916.92 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 42 BeginBalance: 274409.79 Principal: 300000.00 Interest: 916.92 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2024-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14117.01
# Super Balance: $12111.78
# Period: 43 BeginBalance: 273740.98 Principal: 300000.00 Interest: 914.70 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 43 BeginBalance: 273740.98 Principal: 300000.00 Interest: 914.70 Payment: 1583.51
# Expense balance: $1109.27
# Income Remaining: $936.66
# Amount saved this month: $234.17
#
#  2024-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14390.49
# Super Balance: $12313.67
# Period: 44 BeginBalance: 273069.94 Principal: 300000.00 Interest: 912.47 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 44 BeginBalance: 273069.94 Principal: 300000.00 Interest: 912.47 Payment: 1583.51
# Expense balance: $944.20
# Income Remaining: $1101.74
# Amount saved this month: $275.43
#
#  2024-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14665.34
# Super Balance: $12515.56
# Period: 45 BeginBalance: 272396.66 Principal: 300000.00 Interest: 910.23 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 45 BeginBalance: 272396.66 Principal: 300000.00 Interest: 910.23 Payment: 1583.51
# Expense balance: $1187.07
# Income Remaining: $858.87
# Amount saved this month: $214.72
#
#  2024-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $14941.57
# Super Balance: $12717.44
# Period: 46 BeginBalance: 271721.14 Principal: 300000.00 Interest: 907.99 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 46 BeginBalance: 271721.14 Principal: 300000.00 Interest: 907.99 Payment: 1583.51
# Expense balance: $1009.64
# Income Remaining: $1036.29
# Amount saved this month: $259.07
#
#  2024-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $15219.18
# Super Balance: $12919.33
# Period: 47 BeginBalance: 271043.37 Principal: 300000.00 Interest: 905.74 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 47 BeginBalance: 271043.37 Principal: 300000.00 Interest: 905.74 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2024-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $15498.17
# Super Balance: $13121.22
# Period: 48 BeginBalance: 270363.34 Principal: 300000.00 Interest: 903.48 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 48 BeginBalance: 270363.34 Principal: 300000.00 Interest: 903.48 Payment: 1583.51
# Expense balance: $809.93
# Income Remaining: $1236.00
# Amount saved this month: $309.00
#
#  2024-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $15778.56
# Super Balance: $13323.11
# Period: 49 BeginBalance: 269681.04 Principal: 300000.00 Interest: 901.21 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 49 BeginBalance: 269681.04 Principal: 300000.00 Interest: 901.21 Payment: 1583.51
# Expenses remain unchanged at: $1000.00
# Income Remaining: $1045.93
# Amount saved this month: $261.48
#
#  2025-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16060.35
# Super Balance: $13525.00
# Period: 50 BeginBalance: 268996.47 Principal: 300000.00 Interest: 898.94 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 50 BeginBalance: 268996.47 Principal: 300000.00 Interest: 898.94 Payment: 1583.51
# Period: 2 BeginBalance: 49337.78 Principal: 50000.00 Interest: 500.00 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 2 BeginBalance: 49337.78 Principal: 50000.00 Interest: 500.00 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2025-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16343.55
# Super Balance: $13726.89
# Period: 51 BeginBalance: 268309.61 Principal: 300000.00 Interest: 896.65 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 51 BeginBalance: 268309.61 Principal: 300000.00 Interest: 896.65 Payment: 1583.51
# Period: 3 BeginBalance: 48668.94 Principal: 50000.00 Interest: 493.38 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 3 BeginBalance: 48668.94 Principal: 50000.00 Interest: 493.38 Payment: 1162.22
# Expense balance: $982.03
# Income Remaining: $-98.31
# Amount saved this month: $0.00
#
#  2025-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16628.17
# Super Balance: $13928.78
# Period: 52 BeginBalance: 267620.47 Principal: 300000.00 Interest: 894.37 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 52 BeginBalance: 267620.47 Principal: 300000.00 Interest: 894.37 Payment: 1583.51
# Period: 4 BeginBalance: 47993.41 Principal: 50000.00 Interest: 486.69 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 4 BeginBalance: 47993.41 Principal: 50000.00 Interest: 486.69 Payment: 1162.22
# Expense balance: $901.16
# Income Remaining: $-17.44
# Amount saved this month: $0.00
#
#  2025-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $16914.21
# Super Balance: $14130.67
# Period: 53 BeginBalance: 266929.03 Principal: 300000.00 Interest: 892.07 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 53 BeginBalance: 266929.03 Principal: 300000.00 Interest: 892.07 Payment: 1583.51
# Period: 5 BeginBalance: 47311.12 Principal: 50000.00 Interest: 479.93 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 5 BeginBalance: 47311.12 Principal: 50000.00 Interest: 479.93 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2025-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $17201.67
# Super Balance: $14332.56
# Period: 54 BeginBalance: 266235.28 Principal: 300000.00 Interest: 889.76 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 54 BeginBalance: 266235.28 Principal: 300000.00 Interest: 889.76 Payment: 1583.51
# Period: 6 BeginBalance: 46622.01 Principal: 50000.00 Interest: 473.11 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 6 BeginBalance: 46622.01 Principal: 50000.00 Interest: 473.11 Payment: 1162.22
# Expense balance: $998.39
# Income Remaining: $-114.68
# Amount saved this month: $0.00
#
#  2025-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $17490.58
# Super Balance: $14534.44
# Period: 55 BeginBalance: 265539.22 Principal: 300000.00 Interest: 887.45 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 55 BeginBalance: 265539.22 Principal: 300000.00 Interest: 887.45 Payment: 1583.51
# Period: 7 BeginBalance: 45926.01 Principal: 50000.00 Interest: 466.22 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 7 BeginBalance: 45926.01 Principal: 50000.00 Interest: 466.22 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2025-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $17780.93
# Super Balance: $14736.33
# Period: 56 BeginBalance: 264840.84 Principal: 300000.00 Interest: 885.13 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 56 BeginBalance: 264840.84 Principal: 300000.00 Interest: 885.13 Payment: 1583.51
# Period: 8 BeginBalance: 45223.05 Principal: 50000.00 Interest: 459.26 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 8 BeginBalance: 45223.05 Principal: 50000.00 Interest: 459.26 Payment: 1162.22
# Expense balance: $837.56
# Income Remaining: $46.15
# Amount saved this month: $11.54
#
#  2025-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18072.74
# Super Balance: $14938.22
# Period: 57 BeginBalance: 264140.13 Principal: 300000.00 Interest: 882.80 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 57 BeginBalance: 264140.13 Principal: 300000.00 Interest: 882.80 Payment: 1583.51
# Period: 9 BeginBalance: 44513.06 Principal: 50000.00 Interest: 452.23 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 9 BeginBalance: 44513.06 Principal: 50000.00 Interest: 452.23 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2025-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18366.00
# Super Balance: $15140.11
# Period: 58 BeginBalance: 263437.09 Principal: 300000.00 Interest: 880.47 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 58 BeginBalance: 263437.09 Principal: 300000.00 Interest: 880.47 Payment: 1583.51
# Period: 10 BeginBalance: 43795.97 Principal: 50000.00 Interest: 445.13 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 10 BeginBalance: 43795.97 Principal: 50000.00 Interest: 445.13 Payment: 1162.22
# Expense balance: $1196.70
# Income Remaining: $-312.99
# Amount saved this month: $0.00
#
#  2025-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18660.73
# Super Balance: $15342.00
# Period: 59 BeginBalance: 262731.70 Principal: 300000.00 Interest: 878.12 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 59 BeginBalance: 262731.70 Principal: 300000.00 Interest: 878.12 Payment: 1583.51
# Period: 11 BeginBalance: 43071.71 Principal: 50000.00 Interest: 437.96 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 11 BeginBalance: 43071.71 Principal: 50000.00 Interest: 437.96 Payment: 1162.22
# Expense balance: $802.65
# Income Remaining: $81.07
# Amount saved this month: $20.27
#
#  2025-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $18956.93
# Super Balance: $15543.89
# Period: 60 BeginBalance: 262023.96 Principal: 300000.00 Interest: 875.77 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 60 BeginBalance: 262023.96 Principal: 300000.00 Interest: 875.77 Payment: 1583.51
# Period: 12 BeginBalance: 42340.21 Principal: 50000.00 Interest: 430.72 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 12 BeginBalance: 42340.21 Principal: 50000.00 Interest: 430.72 Payment: 1162.22
# Expense balance: $1050.89
# Income Remaining: $-167.18
# Amount saved this month: $0.00
#
#  2025-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $19254.61
# Super Balance: $15745.78
# Period: 61 BeginBalance: 261313.86 Principal: 300000.00 Interest: 873.41 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 61 BeginBalance: 261313.86 Principal: 300000.00 Interest: 873.41 Payment: 1583.51
# Period: 13 BeginBalance: 41601.39 Principal: 50000.00 Interest: 423.40 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 13 BeginBalance: 41601.39 Principal: 50000.00 Interest: 423.40 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $19553.78
# Super Balance: $15947.67
# Period: 62 BeginBalance: 260601.40 Principal: 300000.00 Interest: 871.05 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 62 BeginBalance: 260601.40 Principal: 300000.00 Interest: 871.05 Payment: 1583.51
# Period: 14 BeginBalance: 40855.18 Principal: 50000.00 Interest: 416.01 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 14 BeginBalance: 40855.18 Principal: 50000.00 Interest: 416.01 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $19854.45
# Super Balance: $16149.56
# Period: 63 BeginBalance: 259886.56 Principal: 300000.00 Interest: 868.67 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 63 BeginBalance: 259886.56 Principal: 300000.00 Interest: 868.67 Payment: 1583.51
# Increased 2 balance by $9000
# Period: 15 BeginBalance: 49191.51 Principal: 50000.00 Interest: 498.55 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 15 BeginBalance: 49191.51 Principal: 50000.00 Interest: 498.55 Payment: 1162.22
# Expense balance: $864.00
# Income Remaining: $19.71
# Amount saved this month: $4.93
#
#  2026-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $20156.62
# Super Balance: $16351.44
# Period: 64 BeginBalance: 259169.34 Principal: 300000.00 Interest: 866.29 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 64 BeginBalance: 259169.34 Principal: 300000.00 Interest: 866.29 Payment: 1583.51
# Period: 16 BeginBalance: 48521.21 Principal: 50000.00 Interest: 491.92 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 16 BeginBalance: 48521.21 Principal: 50000.00 Interest: 491.92 Payment: 1162.22
# Expense balance: $808.09
# Income Remaining: $75.62
# Amount saved this month: $18.90
#
#  2026-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $20460.30
# Super Balance: $16553.33
# Period: 65 BeginBalance: 258449.73 Principal: 300000.00 Interest: 863.90 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 65 BeginBalance: 258449.73 Principal: 300000.00 Interest: 863.90 Payment: 1583.51
# Period: 17 BeginBalance: 47844.20 Principal: 50000.00 Interest: 485.21 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 17 BeginBalance: 47844.20 Principal: 50000.00 Interest: 485.21 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $20765.50
# Super Balance: $16755.22
# Period: 66 BeginBalance: 257727.72 Principal: 300000.00 Interest: 861.50 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 66 BeginBalance: 257727.72 Principal: 300000.00 Interest: 861.50 Payment: 1583.51
# Period: 18 BeginBalance: 47160.42 Principal: 50000.00 Interest: 478.44 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 18 BeginBalance: 47160.42 Principal: 50000.00 Interest: 478.44 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $21072.23
# Super Balance: $16957.11
# Period: 67 BeginBalance: 257003.30 Principal: 300000.00 Interest: 859.09 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 67 BeginBalance: 257003.30 Principal: 300000.00 Interest: 859.09 Payment: 1583.51
# Period: 19 BeginBalance: 46469.80 Principal: 50000.00 Interest: 471.60 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 19 BeginBalance: 46469.80 Principal: 50000.00 Interest: 471.60 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $21380.49
# Super Balance: $17159.00
# Period: 68 BeginBalance: 256276.47 Principal: 300000.00 Interest: 856.68 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 68 BeginBalance: 256276.47 Principal: 300000.00 Interest: 856.68 Payment: 1583.51
# Period: 20 BeginBalance: 45772.28 Principal: 50000.00 Interest: 464.70 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 20 BeginBalance: 45772.28 Principal: 50000.00 Interest: 464.70 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $21690.29
# Super Balance: $17360.89
# Period: 69 BeginBalance: 255547.21 Principal: 300000.00 Interest: 854.25 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 69 BeginBalance: 255547.21 Principal: 300000.00 Interest: 854.25 Payment: 1583.51
# Period: 21 BeginBalance: 45067.78 Principal: 50000.00 Interest: 457.72 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 21 BeginBalance: 45067.78 Principal: 50000.00 Interest: 457.72 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22001.64
# Super Balance: $17562.78
# Period: 70 BeginBalance: 254815.52 Principal: 300000.00 Interest: 851.82 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 70 BeginBalance: 254815.52 Principal: 300000.00 Interest: 851.82 Payment: 1583.51
# Period: 22 BeginBalance: 44356.24 Principal: 50000.00 Interest: 450.68 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 22 BeginBalance: 44356.24 Principal: 50000.00 Interest: 450.68 Payment: 1162.22
# Expense balance: $910.13
# Income Remaining: $-26.41
# Amount saved this month: $0.00
#
#  2026-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22314.54
# Super Balance: $17764.67
# Period: 71 BeginBalance: 254081.40 Principal: 300000.00 Interest: 849.39 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 71 BeginBalance: 254081.40 Principal: 300000.00 Interest: 849.39 Payment: 1583.51
# Period: 23 BeginBalance: 43637.58 Principal: 50000.00 Interest: 443.56 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 23 BeginBalance: 43637.58 Principal: 50000.00 Interest: 443.56 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2026-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22629.01
# Super Balance: $17966.56
# Period: 72 BeginBalance: 253344.83 Principal: 300000.00 Interest: 846.94 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 72 BeginBalance: 253344.83 Principal: 300000.00 Interest: 846.94 Payment: 1583.51
# Period: 24 BeginBalance: 42911.74 Principal: 50000.00 Interest: 436.38 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 24 BeginBalance: 42911.74 Principal: 50000.00 Interest: 436.38 Payment: 1162.22
# Expense balance: $963.80
# Income Remaining: $-80.09
# Amount saved this month: $0.00
#
#  2026-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $22945.06
# Super Balance: $18168.44
# Period: 73 BeginBalance: 252605.80 Principal: 300000.00 Interest: 844.48 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 73 BeginBalance: 252605.80 Principal: 300000.00 Interest: 844.48 Payment: 1583.51
# Period: 25 BeginBalance: 42178.64 Principal: 50000.00 Interest: 429.12 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 25 BeginBalance: 42178.64 Principal: 50000.00 Interest: 429.12 Payment: 1162.22
# Expense balance: $1140.12
# Income Remaining: $-256.41
# Amount saved this month: $0.00
#
#  2027-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $23262.68
# Super Balance: $18370.33
# Period: 74 BeginBalance: 251864.31 Principal: 300000.00 Interest: 842.02 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 74 BeginBalance: 251864.31 Principal: 300000.00 Interest: 842.02 Payment: 1583.51
# Period: 26 BeginBalance: 41438.21 Principal: 50000.00 Interest: 421.79 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 26 BeginBalance: 41438.21 Principal: 50000.00 Interest: 421.79 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2027-02-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $23581.89
# Super Balance: $18572.22
# Period: 75 BeginBalance: 251120.35 Principal: 300000.00 Interest: 839.55 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 75 BeginBalance: 251120.35 Principal: 300000.00 Interest: 839.55 Payment: 1583.51
# Period: 27 BeginBalance: 40690.37 Principal: 50000.00 Interest: 414.38 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 27 BeginBalance: 40690.37 Principal: 50000.00 Interest: 414.38 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2027-03-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $23902.70
# Super Balance: $18774.11
# Period: 76 BeginBalance: 250373.91 Principal: 300000.00 Interest: 837.07 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 76 BeginBalance: 250373.91 Principal: 300000.00 Interest: 837.07 Payment: 1583.51
# Period: 28 BeginBalance: 39935.05 Principal: 50000.00 Interest: 406.90 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 28 BeginBalance: 39935.05 Principal: 50000.00 Interest: 406.90 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2027-04-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $24225.11
# Super Balance: $18976.00
# Period: 77 BeginBalance: 249624.98 Principal: 300000.00 Interest: 834.58 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 77 BeginBalance: 249624.98 Principal: 300000.00 Interest: 834.58 Payment: 1583.51
# Period: 29 BeginBalance: 39172.18 Principal: 50000.00 Interest: 399.35 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 29 BeginBalance: 39172.18 Principal: 50000.00 Interest: 399.35 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2027-05-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $24549.14
# Super Balance: $19177.89
# Period: 78 BeginBalance: 248873.55 Principal: 300000.00 Interest: 832.08 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 78 BeginBalance: 248873.55 Principal: 300000.00 Interest: 832.08 Payment: 1583.51
# Period: 30 BeginBalance: 38401.68 Principal: 50000.00 Interest: 391.72 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 30 BeginBalance: 38401.68 Principal: 50000.00 Interest: 391.72 Payment: 1162.22
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-116.29
# Amount saved this month: $0.00
#
#  2027-06-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $24874.78
# Super Balance: $19379.78
# Period: 79 BeginBalance: 248119.62 Principal: 300000.00 Interest: 829.58 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 79 BeginBalance: 248119.62 Principal: 300000.00 Interest: 829.58 Payment: 1583.51
# Period: 31 BeginBalance: 37623.48 Principal: 50000.00 Interest: 384.02 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 31 BeginBalance: 37623.48 Principal: 50000.00 Interest: 384.02 Payment: 1162.22
# Period: 2 BeginBalance: 6711.74 Principal: 7000.00 Interest: 46.67 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 2 BeginBalance: 6711.74 Principal: 7000.00 Interest: 46.67 Payment: 334.93
# Expense balance: $1080.49
# Income Remaining: $-531.71
# Amount saved this month: $0.00
#
#  2027-07-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $25202.05
# Super Balance: $19581.67
# Period: 80 BeginBalance: 247363.18 Principal: 300000.00 Interest: 827.07 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 80 BeginBalance: 247363.18 Principal: 300000.00 Interest: 827.07 Payment: 1583.51
# Period: 32 BeginBalance: 36837.49 Principal: 50000.00 Interest: 376.23 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 32 BeginBalance: 36837.49 Principal: 50000.00 Interest: 376.23 Payment: 1162.22
# Period: 3 BeginBalance: 6421.55 Principal: 7000.00 Interest: 44.74 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 3 BeginBalance: 6421.55 Principal: 7000.00 Interest: 44.74 Payment: 334.93
# Expense balance: $950.20
# Income Remaining: $-401.42
# Amount saved this month: $0.00
#
#  2027-08-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $25530.96
# Super Balance: $19783.56
# Period: 81 BeginBalance: 246604.21 Principal: 300000.00 Interest: 824.54 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 81 BeginBalance: 246604.21 Principal: 300000.00 Interest: 824.54 Payment: 1583.51
# Period: 33 BeginBalance: 36043.64 Principal: 50000.00 Interest: 368.37 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 33 BeginBalance: 36043.64 Principal: 50000.00 Interest: 368.37 Payment: 1162.22
# Period: 4 BeginBalance: 6129.43 Principal: 7000.00 Interest: 42.81 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 4 BeginBalance: 6129.43 Principal: 7000.00 Interest: 42.81 Payment: 334.93
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-451.22
# Amount saved this month: $0.00
#
#  2027-09-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $25861.51
# Super Balance: $19985.44
# Period: 82 BeginBalance: 245842.71 Principal: 300000.00 Interest: 822.01 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 82 BeginBalance: 245842.71 Principal: 300000.00 Interest: 822.01 Payment: 1583.51
# Period: 34 BeginBalance: 35241.86 Principal: 50000.00 Interest: 360.44 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 34 BeginBalance: 35241.86 Principal: 50000.00 Interest: 360.44 Payment: 1162.22
# Period: 5 BeginBalance: 5835.36 Principal: 7000.00 Interest: 40.86 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 5 BeginBalance: 5835.36 Principal: 7000.00 Interest: 40.86 Payment: 334.93
# Expenses remain unchanged at: $1000.00
# Income Remaining: $-451.22
# Amount saved this month: $0.00
#
#  2027-10-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $26193.72
# Super Balance: $20187.33
# Period: 83 BeginBalance: 245078.68 Principal: 300000.00 Interest: 819.48 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 83 BeginBalance: 245078.68 Principal: 300000.00 Interest: 819.48 Payment: 1583.51
# Period: 35 BeginBalance: 34432.06 Principal: 50000.00 Interest: 352.42 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 35 BeginBalance: 34432.06 Principal: 50000.00 Interest: 352.42 Payment: 1162.22
# Period: 6 BeginBalance: 5539.33 Principal: 7000.00 Interest: 38.90 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 6 BeginBalance: 5539.33 Principal: 7000.00 Interest: 38.90 Payment: 334.93
# Expense balance: $1032.81
# Income Remaining: $-484.03
# Amount saved this month: $0.00
#
#  2027-11-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $26527.59
# Super Balance: $20389.22
# Period: 84 BeginBalance: 244312.10 Principal: 300000.00 Interest: 816.93 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 84 BeginBalance: 244312.10 Principal: 300000.00 Interest: 816.93 Payment: 1583.51
# Period: 36 BeginBalance: 33614.16 Principal: 50000.00 Interest: 344.32 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 36 BeginBalance: 33614.16 Principal: 50000.00 Interest: 344.32 Payment: 1162.22
# Period: 7 BeginBalance: 5241.33 Principal: 7000.00 Interest: 36.93 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 7 BeginBalance: 5241.33 Principal: 7000.00 Interest: 36.93 Payment: 334.93
# Expense balance: $982.57
# Income Remaining: $-433.79
# Amount saved this month: $0.00
#
#  2027-12-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $26863.12
# Super Balance: $20591.11
# Period: 85 BeginBalance: 243542.96 Principal: 300000.00 Interest: 814.37 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 85 BeginBalance: 243542.96 Principal: 300000.00 Interest: 814.37 Payment: 1583.51
# Period: 37 BeginBalance: 32788.08 Principal: 50000.00 Interest: 336.14 Payment: 1162.22
# ELSE SUMMARY!!!
# Period: 37 BeginBalance: 32788.08 Principal: 50000.00 Interest: 336.14 Payment: 1162.22
# Period: 8 BeginBalance: 4941.34 Principal: 7000.00 Interest: 34.94 Payment: 334.93
# ELSE SUMMARY!!!
# Period: 8 BeginBalance: 4941.34 Principal: 7000.00 Interest: 34.94 Payment: 334.93
# Expense balance: $1145.92
# Income Remaining: $-597.14
# Amount saved this month: $0.00
#
#  2028-01-01
# Monthly Income: $4333.33
# Tax: $703.89
# Super Contribution: $411.67
# Super Fees: $209.78
# Super Value: $27200.34
# Super Balance: $20793.00
# Period: 86 BeginBalance: 242771.26 Principal: 300000.00 Interest: 811.81 Payment: 1583.51
# ELSE SUMMARY!!!
# Period: 86 BeginBalance: 242771.26 Principal: 300000.00 Interest: 811.81 Payment: 1583.51
# Period: 38 BeginBalance: 31953.74 Principal: 50000.00 Interest: 327.88 Payment: 1162.22
# ELSE SUMMARY!!!
# ...
# Super Balance: $88993.78
# Expense balance: $425.50
#
#  2064-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $371191.48
# Super Balance: $88893.78
# Expense balance: $481.82
#
#  2064-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $370853.19
# Super Balance: $88793.78
# Expense balance: $591.20
#
#  2064-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $370513.21
# Super Balance: $88693.78
# Expense balance: $424.74
#
#  2064-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $370171.52
# Super Balance: $88593.78
# Expense balance: $496.74
#
#  2064-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $369828.13
# Super Balance: $88493.78
# Expenses remain unchanged at: $1000.00
# Year: 45
#
#  2065-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $369483.02
# Super Balance: $88393.78
# Expense balance: $501.15
#
#  2065-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $369136.19
# Super Balance: $88293.78
# Expense balance: $498.63
#
#  2065-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $368787.62
# Super Balance: $88193.78
# Expense balance: $416.98
#
#  2065-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $368437.31
# Super Balance: $88093.78
# Expenses remain unchanged at: $1000.00
#
#  2065-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $368085.24
# Super Balance: $87993.78
# Expenses remain unchanged at: $1000.00
#
#  2065-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $367731.42
# Super Balance: $87893.78
# Expense balance: $592.09
#
#  2065-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $367375.83
# Super Balance: $87793.78
# Expenses remain unchanged at: $1000.00
#
#  2065-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $367018.45
# Super Balance: $87693.78
# Expense balance: $494.29
#
#  2065-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $366659.30
# Super Balance: $87593.78
# Expense balance: $484.18
#
#  2065-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $366298.34
# Super Balance: $87493.78
# Expenses remain unchanged at: $1000.00
#
#  2065-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $365935.59
# Super Balance: $87393.78
# Expenses remain unchanged at: $1000.00
#
#  2065-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $365571.01
# Super Balance: $87293.78
# Expenses remain unchanged at: $1000.00
# Year: 46
#
#  2066-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $365204.62
# Super Balance: $87193.78
# Expenses remain unchanged at: $1000.00
#
#  2066-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $364836.39
# Super Balance: $87093.78
# Expense balance: $515.96
#
#  2066-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $364466.32
# Super Balance: $86993.78
# Expense balance: $550.43
#
#  2066-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $364094.40
# Super Balance: $86893.78
# Expenses remain unchanged at: $1000.00
#
#  2066-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $363720.63
# Super Balance: $86793.78
# Expenses remain unchanged at: $1000.00
#
#  2066-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $363344.98
# Super Balance: $86693.78
# Expense balance: $404.63
#
#  2066-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $362967.46
# Super Balance: $86593.78
# Expense balance: $505.91
#
#  2066-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $362588.04
# Super Balance: $86493.78
# Expenses remain unchanged at: $1000.00
#
#  2066-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $362206.73
# Super Balance: $86393.78
# Expenses remain unchanged at: $1000.00
#
#  2066-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $361823.52
# Super Balance: $86293.78
# Expenses remain unchanged at: $1000.00
#
#  2066-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $361438.38
# Super Balance: $86193.78
# Expenses remain unchanged at: $1000.00
#
#  2066-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $361051.33
# Super Balance: $86093.78
# Expense balance: $512.37
# Year: 47
#
#  2067-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $360662.33
# Super Balance: $85993.78
# Expenses remain unchanged at: $1000.00
#
#  2067-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $360271.39
# Super Balance: $85893.78
# Expense balance: $545.13
#
#  2067-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $359878.50
# Super Balance: $85793.78
# Expenses remain unchanged at: $1000.00
#
#  2067-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $359483.64
# Super Balance: $85693.78
# Expense balance: $401.61
#
#  2067-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $359086.81
# Super Balance: $85593.78
# Expense balance: $506.28
#
#  2067-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $358688.00
# Super Balance: $85493.78
# Expense balance: $551.32
#
#  2067-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $358287.19
# Super Balance: $85393.78
# Expenses remain unchanged at: $1000.00
#
#  2067-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $357884.37
# Super Balance: $85293.78
# Expense balance: $563.76
#
#  2067-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $357479.54
# Super Balance: $85193.78
# Expenses remain unchanged at: $1000.00
#
#  2067-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $357072.69
# Super Balance: $85093.78
# Expenses remain unchanged at: $1000.00
#
#  2067-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $356663.80
# Super Balance: $84993.78
# Expense balance: $496.63
#
#  2067-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $356252.87
# Super Balance: $84893.78
# Expense balance: $575.89
# Year: 48
#
#  2068-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $355839.89
# Super Balance: $84793.78
# Expense balance: $530.03
#
#  2068-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $355424.84
# Super Balance: $84693.78
# Expenses remain unchanged at: $1000.00
#
#  2068-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $355007.71
# Super Balance: $84593.78
# Expenses remain unchanged at: $1000.00
#
#  2068-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $354588.50
# Super Balance: $84493.78
# Expenses remain unchanged at: $1000.00
#
#  2068-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $354167.19
# Super Balance: $84393.78
# Expenses remain unchanged at: $1000.00
#
#  2068-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $353743.78
# Super Balance: $84293.78
# Expenses remain unchanged at: $1000.00
#
#  2068-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $353318.25
# Super Balance: $84193.78
# Expenses remain unchanged at: $1000.00
#
#  2068-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $352890.59
# Super Balance: $84093.78
# Expenses remain unchanged at: $1000.00
#
#  2068-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $352460.79
# Super Balance: $83993.78
# Expense balance: $412.15
#
#  2068-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $352028.85
# Super Balance: $83893.78
# Expense balance: $500.78
#
#  2068-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $351594.74
# Super Balance: $83793.78
# Expense balance: $550.85
#
#  2068-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $351158.46
# Super Balance: $83693.78
# Expenses remain unchanged at: $1000.00
# Year: 49
#
#  2069-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $350720.01
# Super Balance: $83593.78
# Expenses remain unchanged at: $1000.00
#
#  2069-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $350279.36
# Super Balance: $83493.78
# Expenses remain unchanged at: $1000.00
#
#  2069-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $349836.50
# Super Balance: $83393.78
# Expense balance: $514.89
#
#  2069-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $349391.44
# Super Balance: $83293.78
# Expenses remain unchanged at: $1000.00
#
#  2069-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $348944.14
# Super Balance: $83193.78
# Expenses remain unchanged at: $1000.00
#
#  2069-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $348494.61
# Super Balance: $83093.78
# Expense balance: $457.72
#
#  2069-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $348042.84
# Super Balance: $82993.78
# Expense balance: $497.74
#
#  2069-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $347588.80
# Super Balance: $82893.78
# Expenses remain unchanged at: $1000.00
#
#  2069-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $347132.49
# Super Balance: $82793.78
# Expenses remain unchanged at: $1000.00
#
#  2069-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $346673.91
# Super Balance: $82693.78
# Expense balance: $463.65
#
#  2069-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $346213.03
# Super Balance: $82593.78
# Expenses remain unchanged at: $1000.00
#
#  2069-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $345749.84
# Super Balance: $82493.78
# Expenses remain unchanged at: $1000.00
# Year: 50
#
#  2070-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $345284.34
# Super Balance: $82393.78
# Expenses remain unchanged at: $1000.00
#
#  2070-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $344816.51
# Super Balance: $82293.78
# Expenses remain unchanged at: $1000.00
#
#  2070-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $344346.35
# Super Balance: $82193.78
# Expense balance: $476.06
#
#  2070-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $343873.83
# Super Balance: $82093.78
# Expense balance: $483.97
#
#  2070-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $343398.95
# Super Balance: $81993.78
# Expense balance: $551.38
#
#  2070-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $342921.69
# Super Balance: $81893.78
# Expenses remain unchanged at: $1000.00
#
#  2070-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $342442.05
# Super Balance: $81793.78
# Expenses remain unchanged at: $1000.00
#
#  2070-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $341960.01
# Super Balance: $81693.78
# Expense balance: $403.38
#
#  2070-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $341475.56
# Super Balance: $81593.78
# Expense balance: $403.15
#
#  2070-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $340988.69
# Super Balance: $81493.78
# Expenses remain unchanged at: $1000.00
#
#  2070-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $340499.38
# Super Balance: $81393.78
# Expense balance: $466.93
#
#  2070-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $340007.63
# Super Balance: $81293.78
# Expenses remain unchanged at: $1000.00
# Year: 51
#
#  2071-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $339513.42
# Super Balance: $81193.78
# Expense balance: $481.99
#
#  2071-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $339016.73
# Super Balance: $81093.78
# Expenses remain unchanged at: $1000.00
#
#  2071-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $338517.57
# Super Balance: $80993.78
# Expenses remain unchanged at: $1000.00
#
#  2071-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $338015.90
# Super Balance: $80893.78
# Expense balance: $445.06
#
#  2071-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $337511.73
# Super Balance: $80793.78
# Expense balance: $545.19
#
#  2071-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $337005.04
# Super Balance: $80693.78
# Expenses remain unchanged at: $1000.00
#
#  2071-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $336495.82
# Super Balance: $80593.78
# Expense balance: $465.18
#
#  2071-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $335984.05
# Super Balance: $80493.78
# Expenses remain unchanged at: $1000.00
#
#  2071-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $335469.72
# Super Balance: $80393.78
# Expense balance: $554.18
#
#  2071-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $334952.82
# Super Balance: $80293.78
# Expense balance: $498.85
#
#  2071-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $334433.33
# Super Balance: $80193.78
# Expense balance: $555.55
#
#  2071-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $333911.25
# Super Balance: $80093.78
# Expense balance: $578.95
# Year: 52
#
#  2072-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $333386.55
# Super Balance: $79993.78
# Expense balance: $543.39
#
#  2072-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $332859.24
# Super Balance: $79893.78
# Expenses remain unchanged at: $1000.00
#
#  2072-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $332329.28
# Super Balance: $79793.78
# Expenses remain unchanged at: $1000.00
#
#  2072-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $331796.68
# Super Balance: $79693.78
# Expense balance: $417.81
#
#  2072-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $331261.41
# Super Balance: $79593.78
# Expenses remain unchanged at: $1000.00
#
#  2072-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $330723.47
# Super Balance: $79493.78
# Expense balance: $434.44
#
#  2072-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $330182.84
# Super Balance: $79393.78
# Expense balance: $480.85
#
#  2072-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $329639.50
# Super Balance: $79293.78
# Expenses remain unchanged at: $1000.00
#
#  2072-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $329093.45
# Super Balance: $79193.78
# Expense balance: $483.06
#
#  2072-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $328544.66
# Super Balance: $79093.78
# Expenses remain unchanged at: $1000.00
#
#  2072-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $327993.14
# Super Balance: $78993.78
# Expense balance: $565.35
#
#  2072-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $327438.85
# Super Balance: $78893.78
# Expenses remain unchanged at: $1000.00
# Year: 53
#
#  2073-01-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $326881.80
# Super Balance: $78793.78
# Expenses remain unchanged at: $1000.00
#
#  2073-02-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $326321.96
# Super Balance: $78693.78
# Expenses remain unchanged at: $1000.00
#
#  2073-03-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $325759.32
# Super Balance: $78593.78
# Expense balance: $458.72
#
#  2073-04-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $325193.86
# Super Balance: $78493.78
# Expenses remain unchanged at: $1000.00
#
#  2073-05-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $324625.58
# Super Balance: $78393.78
# Expenses remain unchanged at: $1000.00
#
#  2073-06-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $324054.46
# Super Balance: $78293.78
# Expense balance: $434.68
#
#  2073-07-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $323480.48
# Super Balance: $78193.78
# Expenses remain unchanged at: $1000.00
#
#  2073-08-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $322903.64
# Super Balance: $78093.78
# Expense balance: $459.44
#
#  2073-09-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $322323.90
# Super Balance: $77993.78
# Expenses remain unchanged at: $1000.00
#
#  2073-10-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $321741.27
# Super Balance: $77893.78
# Expense balance: $473.50
#
#  2073-11-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $321155.73
# Super Balance: $77793.78
# Expenses remain unchanged at: $1000.00
#
#  2073-12-01
# Super Contribution: $0.00
# Super Fees: $100.00
# Super Value: $320567.26
# Super Balance: $77693.78
# Expenses remain unchanged at: $1000.00
# Year: 54

# %%
df.head(100)
# Out:
#           Date       Income         Tax  SuperContrib  SuperBalance  \
# 0   2020-01-01  4333.333333  703.889583    411.666667   1411.666667
# 1   2020-02-01  4333.333333  703.889583    411.666667   1613.555556
# 2   2020-03-01  4333.333333  703.889583    411.666667   1815.444444
# 3   2020-04-01  4333.333333  703.889583    411.666667   2017.333333
# 4   2020-05-01  4333.333333  703.889583    411.666667   2219.222222
# ..         ...          ...         ...           ...           ...
# 95  2027-12-01  4333.333333  703.889583    411.666667  20591.111111
# 96  2028-01-01  4333.333333  703.889583    411.666667  20793.000000
# 97  2028-02-01  4333.333333  703.889583    411.666667  20994.888889
# 98  2028-03-01  4333.333333  703.889583    411.666667  21196.777778
# 99  2028-04-01  4333.333333  703.889583    411.666667  21398.666667
#
#       SuperValue  LoanDebt     Expenses  RemainingIncome    SavedAmt
# 0    1411.666667      0.00  1122.478020      2506.965730  626.741432
# 1    1621.623333      0.00  1000.000000      2629.443750  657.360937
# 2    1832.629783      0.00   844.672366      2784.771384  696.192846
# 3    2044.691266      0.00  1000.000000      2629.443750  657.360937
# 4    2257.813055      0.00  1181.347425      2448.096325  612.024081
# ..           ...       ...          ...              ...         ...
# 95  26863.123899   3080.66  1192.960504      -644.176754    0.000000
# 96  27200.337852   3080.66   996.937739      -448.153989    0.000000
# 97  27539.237874   3080.66   893.348968      -344.565218    0.000000
# 98  27879.832397   3080.66  1151.225181      -602.441431    0.000000
# 99  28222.129893   3080.66  1000.000000      -451.216250    0.000000
#
# [100 rows x 10 columns]

# %%
df.to_csv('qa.csv')

# %% [markdown]
# ## Lifetime Visualisations

# %%
plt.plot(df['Date'], df['SuperValue'])
plt.plot(df['Date'], df['SuperBalance'])
plt.show()

# %%
plt.plot(df['Date'], df['LoanDebt'])
plt.show()

# %%
plt.plot(df['Date'], df['Expenses'])
plt.show()

# %%
# Check current state of the user profile...
myProfile.summary()
# Out:
# tyler is 80 years old and has an income of $4333.33 per month.

# %%
myProfile.loanInfo()
# Out:
# Loan 1 has principal of $300000 over duration 25 years with expected finish date of 2046-01-01 - remaining balance: $0.0
# Loan 2 has principal of $50000 over duration 5 years with expected finish date of 2030-01-01 - remaining balance: $0.0
# Loan 3 has principal of $7000 over duration 10 years with expected finish date of 2037-06-01 - remaining balance: $0.0

# %%
for loanID, _ in myProfile.loanDict.items():
    
    plt.plot(myProfile.loanDict[loanID].dateHistory, myProfile.loanDict[loanID].loanHistory)

# %%
myProfile.loanDict['2'].loanPaidOff
# Out:
# True

# %%
print('Loan 1')
print('Start Date:', myProfile.loanDict['1'].startDate)
print('Expected End Date:', myProfile.loanDict['1'].endDate)
print('Finish Date:', myProfile.loanDict['1'].loanPaidOffDate)
# Out:
# Loan 1
# Start Date: 2021-01-01
# Expected End Date: 2046-01-01
# Finish Date: 2046-01-01

# %%
print('Loan 2')
print('Start Date:', myProfile.loanDict['2'].startDate)
print('Expected End Date:', myProfile.loanDict['2'].endDate)
print('Finish Date:', myProfile.loanDict['2'].loanPaidOffDate)
# Out:
# Loan 2
# Start Date: 2025-01-01
# Expected End Date: 2030-01-01
# Finish Date: 2030-12-01

# %%
print('Loan 3')
print('Start Date:', myProfile.loanDict['3'].startDate)
print('Expected End Date:', myProfile.loanDict['3'].endDate)
print('Finish Date:', myProfile.loanDict['3'].loanPaidOffDate)
# Out:
# Loan 3
# Start Date: 2027-06-01
# Expected End Date: 2037-06-01
# Finish Date: 2029-04-01

# %%
plt.plot(myProfile.dateHistory, myProfile.incomeHistory)
plt.title('Remaining Income')
plt.xlabel('Year')
plt.ylabel('$ Amount')
# Out:
# Text(0, 0.5, '$ Amount')
