# %% [markdown]
# # Stochastic Personal Finance Forecasting Simulator
# <b>Author:</b> Tyler Bikaun<br>
# <b>Last Modified:</b> 14.03.2020

# %% [markdown]
# ><b>Purpose:</b> Develop a user simulator based on object oriented design principles for use in stochastic personal financial forecasting.

# %% [markdown]
# <b>Modules Included</b>
# <ol>
#     <li>Asset Value</li>
#     <li>Superannuation</li>
#     <li>Tax</li>
#     <li>Savings</li>
#     <li>Expenses</li>
#     <li>Income</li>
#     <li>Loan</li>
#     <li>Profile</li>
#     <li>Simulation</li>
# </ol>

# %% [markdown]
# ><b>Inheritance:</b> 1:Asset Value to 7:Loan -> 8:Profile -> 9:Simulation

# %% [markdown]
# ### Notebook set-up and importation of libraries

# %%
import datetime
from dateutil.relativedelta import relativedelta
from collections import OrderedDict
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tqdm import tqdm

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### Initialisation of Logging

# %%
import logging
logging.basicConfig(filename=f'logs/simulation_{datetime.datetime.now().strftime("%d-%m-%y_%H-%M")}.log', level=logging.DEBUG)

# %% [markdown]
# ### Initialisation of Classes

# %% [markdown]
# ><b>Asset Value:</b> The AssetValue class is used for approximating user asset value and wealth. This is initially used for modeling real estate property value. This model currently assumes that the asset value only appreciates at a given rate (asset return rate).<br><br>
# Future model considerations:<ol><li>Integrate stochastic asset return rate... or damages to the market structure?</li></ol>

# %%
class AssetValue():
    """
    Model for approximating asset value and wealth.
    Initially used for property value
    """
    
    def __init__(self, assetReturnRate):
        self.assetReturnRate = assetReturnRate / 12
        
    def getAssetValue(self, assetPrincipal, compoundPeriod):
        # calculates asset value on a periodic compounding per month
        assetValue = assetPrincipal * (1 + self.assetReturnRate)**compoundPeriod
        return assetValue

# %% [markdown]
# ><b>Superannuation:</b> The Superunnuation class is used for capturing superannuation acquisition over time. Factors that are integrated into this class include: 1. super contributions (monthly freq), 2. initial balance, 3. rate of return, 4. employer contribution rate, 5. fees (administration and investment), 6. insurance premiums, and 7. indireect costs that aren't captured within these buckets.

# %%
class Superannuation():
    """
    Note: Assumes superannuation is run via an institution and is not self managed.
    
    """
    
    def __init__(self, contribRate):
        self.superContrib = 0
        self.superInitialBal = 1000   # initial super balance
        self.superReturnRate = 0.06 / 12
        
        self.contribRate = contribRate   # Employer contribution rate
        
        # Cumulative Sum of Super Balance and Value
        self.superBalCumSum = 0
        self.superValCumSum = 0
        
    def superFees(self, phase):
        if phase == 1:
            # phase 1 - before retirement
            self.contribFee = 1/12
        if phase == 2:
            # phase 2 - retirement
            self.contribFee = 0
        self.adminFee = 100
        self.investmentFee = 1/12
        self.insurancePrem = 1/12
        self.indirectCosts = 0.2/12
        self.superFeesTotal = 0
        
        self.superFeesTotal = self.adminFee + self.investmentFee * self.superContrib + \
                            self.contribFee * self.superContrib + self.insurancePrem * self.superContrib + \
                            self.indirectCosts * self.superContrib
#         print(f'Super Fees: ${self.superFeesTotal:0.2f}')
        
    def superValue(self, phase):
        
        if self.superBalCumSum == 0:
#             print('adding initial value to superVal')
            self.superValCumSum += self.superContrib + self.superInitialBal
        elif phase == 1:
#             print(f'{self.superValCumSum}-{self.superContrib}-{self.superFeesTotal}-{1 + self.superReturnRate}')
            self.superValCumSum = (self.superValCumSum + self.superContrib - self.superFeesTotal) * (1 + self.superReturnRate)
        elif phase == 2:
            self.superValCumSum = (self.superValCumSum - self.drawdownAmt - self.superFeesTotal) * (1 + self.superReturnRate)
        
#         print(f'Super Value: ${self.superValCumSum:0.2f}')
        
        
    def superBalance(self):
        
        if self.superBalCumSum == 0:
#             print('adding initial value to superBal')
            self.superBalCumSum += self.superContrib + self.superInitialBal
        else:
            self.superBalCumSum += self.superContrib - self.superFeesTotal
        
#         print(f'Super Balance: ${self.superBalCumSum:0.2f}')
        
    def superContribution(self, phase, income):
        # Monthly income...
        self.superContrib = self.contribRate * income
#         print(f'Super Contribution: ${self.superContrib:0.2f}')
        
        self.superFees(phase)
        self.superValue(phase)
        self.superBalance()
        
        
    def superDrawDown(self):
        # Drawdown once retirement starts and contributions cease
        retirementIncome = 25000
        self.drawdownAmt = retirementIncome / 12
        
        self.superContribution(2, 0)   # no income within phase 2

# %% [markdown]
# ><b>Tax:</b> The Tax class is used to calculate payable tax on taxable income in accordance with tax rates set by the Australian Tax Office (ATO).

# %%
class Tax():
    """
    Model for taxing income.
    Calculates tax on gross annual income.
    Note: Tax rates are current as of 2019-2020 and sourced from the ATO.
    """
    
    def __init__(self):
        self.tax_table_income = {1: [0, 18200],
                    2: [18201, 37000],
                    3: [37001, 90000],
                    4: [90001, 180000],
                    5: [180001, 1000000000]}   # ridiculous upper limit

        self.tax_table_paymt = {1: [0, 0],
                        2: [0.19, 0],
                        3: [0.325, 3572],
                        4: [0.37, 20797],
                        5: [0.45, 54097]}
    
    def getTaxAmount(self, income):
        
        income = income * 12 # input is per month...
        
        for key, value in self.tax_table_income.items():
            if value[0] <= income <= value[1]:
                tax_to_pay = self.tax_table_paymt[key][1] + self.tax_table_paymt[key][0] * \
                (income - self.tax_table_income[key][0])
                
        monthlyIncomeTax = tax_to_pay / 12
        
        return monthlyIncomeTax

# %% [markdown]
# ><b>Savings:</b> The Savings class is used for capturing user savings based on proportions saved which vary over time. Savings also work as a buffer for rare events that cannot be directly covered by income.

# %%
class Savings():
    """
    Model for savings.
    """
    
    def __init__(self, proportionSaved):
        """
        
        """
        self.proportionSaved = proportionSaved
        
        # data capture
        self.dataHistory = []
        self.savingHistory = []
        self.amtSaved = sum(self.savingHistory)
        
    def getSavedAmount(self, remainingIncome):
        """
        Gets amount saved from remainingIncome
        """
        if 0 < remainingIncome:
            return remainingIncome*self.proportionSaved
        elif remainingIncome < 0:
            # if negative income then take out of savings the amount required.
            # Need to be able to check the current balance of savings and compare that there is enough...
            return remainingIncome
        else:
            return 0
        
    # Data Capture Functions
    def getSavingHistory(self, date, savingInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.savingHistory.append(savingInfo)

# %% [markdown]
# ><b>Expenses:</b> The Expenses class is used to capture expenses relating to life in general. This is currently modelled as being stochastic within certain limits based on living costs.

# %%
class Expenses():
    """
    Model for general expenses.
    """
    
    def __init__(self, expenses):
        """
        
        """
        
        # Everything is on a monthly basis in the model...
        self.expenses = expenses
        
    def increaseExpenseRandomly(self, phase):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """

        expensesTemp = 0
        if (0.5 < np.random.uniform(0,1)):
            if phase == 2:
                increaseAmt = np.random.uniform(0.8, 1.2)*(self.expenses / 2)
            else:
                increaseAmt = np.random.uniform(0.8, 1.2)*(self.expenses)
            
#             print(f'Expense balance: ${increaseAmt:0.2f}')
            return increaseAmt
        else:
#             print(f'Expenses remain unchanged at: ${self.expenses:0.2f}', )
            if phase == 2:
                return self.expenses / 2
            else:
                return self.expenses

# %% [markdown]
# ><b>Income:</b> The Income class is used for generating cash flow for users. Income is determined by three means (as defined by various financial institutions): 1. earned, 2. passive, and 3. portfolio.

# %%
class Income():
    """
    Model for income (earned, passive, portfolio).
    """
    
    def __init__(self, income):
        """
        
        """
        
        # Everything is on a monthly basis in the model...
        self.income = income
        self.remainingIncome = self.income    # init
        self.dateHistory = []
        self.incomeHistory = []

        
    def incomeAfterCosts(self, loanPaymentSum):
        """
        Aggregated Monthly.
        """
        costs = loanPaymentSum
        self.remainingIncome = self.income - costs
        
    def getIncomeHistory(self, date, incomeInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.incomeHistory.append(incomeInfo)

# %% [markdown]
# ><b>Loan:</b> The Loan class captures loans and their attributes. Attributes include: 1. principal, 2. interest rate, 3. annual payments, 4. duration, and 5. startdate. Loans are an important factor in user simulation as they can be stackable (have more than one at a time).<br><br>
# <b>Note:</b> This model should be referenced against typical mortgage qualifiers such as requiring a certain deposit % before being allowed a mortgage. Wheras personal loans like cars can have anything given a certain asset value is there. If this isn't met then the loan is pushed into the future until this is reached.

# %%
class Loan():
    """
    Model for user profile loans.
    """
    
    def __init__(self, loanID, principal, interestRate, annualPayments, duration, startDate, loanPaymentExtra):
        self.principal = principal
        self.interestRate = interestRate
        self.annualPayments = annualPayments
        self.duration = duration
        self.startDate = datetime.datetime.strptime(startDate, '%d-%m-%Y').date()
        self.loanID = loanID
        self.period = 1
        self.endDate = (self.startDate + relativedelta(years=self.duration))
        self.beginBalance = self.principal
        self.endBalance = self.principal
        self.loanPaidOff = False
        self.loanPaidOffDate = 'Not paid off - Active'
        self.loanActive = False
        self.loanPaymentExtra = loanPaymentExtra
        self.loanPaymentMinimum = -round(np.pmt(self.interestRate/self.annualPayments, self.duration*self.annualPayments, self.principal), 2)
        
        # First loan payment amount
        # Note: loanPaymentExtra is a nominal payment that is added to the minimum loan service amount.
        self.loanPayment = self.loanPaymentExtra + self.loanPaymentMinimum
            
        # For data capture
        self.dateHistory = []
        self.loanHistory = []
    
    def initDesc(self):
        return f'''Loan {self.loanID} has principal of ${self.principal} over duration {self.duration} years with expected finish date of {self.endDate} - remaining balance: ${self.endBalance} - Minimum payment amount: ${self.loanPaymentMinimum}'''
    
    # Main Functions
    def makePayment(self):
        """
        Make a payment against the principal.
        """
        self.loanActive = True
        self.interest = round(((self.interestRate/self.annualPayments) * self.beginBalance), 2)
        self.loanPayment = min(self.loanPayment, self.beginBalance + self.interest)
        self.endBalance = self.beginBalance - (self.loanPayment - self.interest)
        self.period += 1
        self.beginBalance = self.endBalance
        
    def paymentSummary(self):
        try:
            print(f'Period: {self.period} BeginBalance: {self.beginBalance:0.2f} Principal: {self.principal:0.2f} Interest: {self.interest:0.2f} Payment: {self.loanPayment:0.2f}')
        except:
            print('Not enough information. Loan has likely not become active.')

    def loanFinished(self, date):
        """
        Used when a loan is finished.
        """
        #TODO: Add date for when loan finishes... as this may not be constant...
        self.loanPaidOff = True
        self.loanActive = False
        self.loanPaidOffDate = date
    
    # Misc Functions
    def increasePrincipal(self, increaseAmt):
        """
        Increase the amount of loan principal via month begin balance.
        """
        self.beginBalance += increaseAmt
        
    def increasePrincipalRandomly(self):
        """
        Increase principal by a random amount to simulate expense tranfers.
        This can only occur if the loan is still active. 
        TODO: integrate expenses and ability for profile to override 'active' status to ressurect their paid off loans...
        """
        if (0.99 < np.random.uniform(0,1)) and self.loanActive:
            if self.loanPaidOff == False:
                increaseAmt = np.random.randint(0,10)*1000
                self.beginBalance += increaseAmt
#                 print(f'Increased {self.loanID} balance by ${increaseAmt}')
        
    # Data Capture Functions
    def getLoanHistory(self, date, loanInfo):
        """
        Used to capture temporal data for plotting and analysis.
        """
        self.dateHistory.append(date)
        self.loanHistory.append(loanInfo)

# %% [markdown]
# ><b>Education:</b>

# %%
class Education():
    
    def __init__(self):
        """
        
        """
        
        self.eduLevel = 6   # 1 (year 11) -> 7 (postgraduate degree)
        
        pass
        
    def learn(self):
        """
        Proactively learn. This contributes to productivity etc. but also has consequences such as either costs and/or unemployment etc.
        """
        pass

# %% [markdown]
# ><b>Profile:</b> The Profile class is for generating user profiles. A user profile can have the previously defined classes attributed to it e.g. income, expenses, savings, tax, superannuations, and asset value. A user profile is simulated over a lifetime, the lifetime is split into two phases 1. working, and 2. retirement. In the first phase, working, the user typically would take out loans, have income, commit to superannuation, etc. In the second phase, retirement, the income streams change, superannuation starts to be drawn down, etc. Parameters of the user profile include 1. name, 2. age, 3. expected retirement age (will be an output rather than an input in the future), and 4. expected age of death (assumed from health statistics based on gender; could be extended based on other salient factors).

# %%
class Profile(Income, Expenses, Savings, Tax, Superannuation, AssetValue, Education):
    """
    Profile for user. Contains their general information and meta data for financial modeling.
    """
    
    # Initializer / Instance Attributes
    def __init__(self, name, age, retireAge, deadAge, incomePA, expensesPM, proportionSaved):
        self.name = name
        self.age = age
        self.retireAge = retireAge
        self.deadAge = deadAge
        
        # Education
        # Currently does not take user input and is hard coded in the Education Class initialisation...
        
        # Loans
        self.hasLoan = False
        self.loanDict = {}
        self.noLoans = 0
        self.loanPaymentSum = 0
        
        # Income
        self.hasIncome = False
        self.incomePA = incomePA
        self.income = self.incomePA / 12
        self.hasIncome = True
        
        # Expenses
        self.expenses = expensesPM    # Expenses per month
        
        # Savings
        self.proportionSaved = proportionSaved

        
        # Inherit Loan init.. by inheriting this class, we can access it's attributes and methods...
        Income.__init__(self, self.income)  # pass attribute to class
        
        # Init Expenses
        Expenses.__init__(self, self.expenses)
        
        
        # Init Savings
        Savings.__init__(self, self.proportionSaved)
        
        # Init Tax
        Tax.__init__(self)
        
        # Init super
        Superannuation.__init__(self, 0.095)
        
        # Init asset value
        AssetValue.__init__(self, 0.06)
        
        # Init Education 
        Education.__init__(self)
        
    # Profile
    def ageStep(self, year):
        """
        Used to age the users profile and step through time.
        """
        self.age += year
    
    def summary(self):
        print(f'{self.name} is {self.age} years old and has an income of ${self.income:0.2f} per month.\n')
    
    # Loan
    def getLoan(self, principal, interestRate, annualPayments, duration, startDate, loanPaymentExtra):
        """
        Allocates a loan to the profile.
        """
        
        self.hasLoan = True
        self.noLoans += 1
#         print(f'Number of loans: {self.noLoans}')
        loanID = str(self.noLoans)
        self.loanDict[loanID] = Loan(loanID, principal, interestRate, annualPayments, duration, startDate, loanPaymentExtra)
        
    def removeLoan(self, loanID):
        """
        Removes a loan from the profile. TODO: update to remove once paid off.
        """
        try:
            del self.loanDict[loanID]
        except:
            print('Loan doesnt exist')
            
    def loanDesc(self):
        """
        Summary of active loans.
        """
        self.currentLoans = len(self.loanDict)
        try:
            return f'Current active loans for {self.name}: {self.currentLoans}'
        except:
            return f'{self.name} has no loan'
        
    def loanInfo(self):
        """
        Detailed description of loan dict. For debugging purposes.
        """
        for loanID, loanDetails in self.loanDict.items():
            print(f'{loanDetails.initDesc()}')

# %% [markdown]
# ><b>Simulation:</b> The simulation class is used for simulating user lifetimes for stochastic modeling and analysis.

# %%
class Simulation(Profile):
    """
    Simulation class. Used for simulation functions and data capture.
    """
        
    def init_user_profile(self):
        """
        Initialises a user profile for simulation.
        """
        
        # Initialise Profile class
        self.userProfile = Profile(self.name, self.age, self.retireAge, self.deadAge, self.incomePA, self.expenses, self.proportionSaved)

        # Initialise loans and attribute them to the user profile
        for loan in self.data_dict['loanDetails']:
            self.userProfile.getLoan(self.data_dict['loanDetails'][loan]['principal'],
                                     self.data_dict['loanDetails'][loan]['interestRate'],
                                     self.data_dict['loanDetails'][loan]['annualPayments'],
                                     self.data_dict['loanDetails'][loan]['duration'],
                                     self.data_dict['loanDetails'][loan]['startDate'],
                                     self.data_dict['loanDetails'][loan]['loanPaymentExtra'])
    
    def __init__(self, data_dict):
        """
        Intialisation of the simulation model
        """
        
        self.data_dict = data_dict   # holds simulation and profile information.
        
        # Init Profile
        Profile.__init__(self, self.data_dict['profileDetails']['name'], self.data_dict['profileDetails']['age'], \
                         self.data_dict['profileDetails']['retireAge'], self.data_dict['profileDetails']['deadAge'], \
                         self.data_dict['profileDetails']['incomePA'], self.data_dict['profileDetails']['expensesPM'], \
                         self.data_dict['profileDetails']['proportionSaved'])
        # Initialise profile for simulation
        self.init_user_profile()
    
    
    def simulate_one_step(self):
        """
        Simulates the financial situation of a user for one month.
        """
        # Duration of simulation (phase 1)
        dateStart = datetime.date(2020,1,1)
        dateStartTemp = dateStart

        # Iterate over life with month level granularity
        # Phase One - Working life
        logging.info('ENTERING PHASE ONE')

        while self.userProfile.age < self.userProfile.retireAge:
            # Current datetime of step
            logging.debug(f'Current DateTime: {dateStartTemp}')
            logging.debug(f'Monthly Income: ${self.userProfile.income:0.2f}')

            # Tax
            # Get taxable amount from income
            tax = self.userProfile.getTaxAmount(self.userProfile.income)
            logging.debug(f'Tax: ${tax:0.2f}')

            # Super
            # Contribute to superannuation from income
            self.userProfile.superContribution(1, self.userProfile.income)

            tempLoanCost = 0

            # Pay debts
            # An aggregation of loan costs is computed here over all active loans
            for loanID, loanInfo in self.userProfile.loanDict.items():    # Iterate through loans associated to the profile

                # If the start date of the loan of interest is before the current time stamp, calculate loan payment or make loan inactive if it's finished.
                if self.userProfile.loanDict[loanID].startDate <= dateStartTemp:

                    # TESTING: This step is currently simulating random increases to loan principal.
                    # This is used to emulate when income goes below zero and loans need to be increased to make up the difference.
                    # This only works if there are active loans, if no loan is active then another method for re-activating or creating a new loan need to be developed.
                    # NEED TO CONFIRM THAT THIS ISNT ATTRIBUTING EXTRA PRINCIPAL TO ALL LOANS... ONE MAY BE ENOUGH.
                    self.userProfile.loanDict[loanID].increasePrincipalRandomly()

                    # If balance remains on loans - make payment
                    if 0 < self.userProfile.loanDict[loanID].beginBalance:
                        # Raise payment against loan
                        self.userProfile.loanDict[loanID].makePayment()
                        # Print payment summary to console
#                         self.userProfile.loanDict[loanID].paymentSummary()    # shows summary of loan to console

                        # Capture loan history information for future analytics
                        self.userProfile.loanDict[loanID].getLoanHistory(dateStartTemp, self.userProfile.loanDict[loanID].beginBalance)

                        # If the loan payment makes the balance zero, make the loan in-active as it's paid off
                        if self.userProfile.loanDict[loanID].beginBalance == 0:
                            logging.debug(f'LOAN {loanID} PAID OFF!')
                            # Set loanFinished to True
                            self.userProfile.loanDict[loanID].loanFinished(dateStartTemp)

                        # Loan is not paid off but persists for the next period
                        else:
                            # Capture loanPayment for totalcost aggregation
#                             self.userProfile.loanDict[loanID].paymentSummary()    # shows summary of loan to console
                            
    #                         print(f'Loan {loanID} - Begin Balance: ${self.userProfile.loanDict[loanID].beginBalance:0.2f} Payment: {self.userProfile.loanDict[loanID].loanPayment:0.2f}')
    #                         logging.debug(f'Loan {loanID} - Begin Balance: ${self.userProfile.loanDict[loanID].beginBalance:0.2f} Payment: {self.userProfile.loanDict[loanID].loanPayment:0.2f}')
                            tempLoanCost += self.userProfile.loanDict[loanID].loanPayment

                    # No principal - either loan hasnt begun or its finished
                    else:
                        self.userProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)

                # Too early - no loans are active
                else:
                    self.userProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
                    pass

            # Expenses
            # Currently randomly increasing expenses to emulate randomness
            # This has logic based on the phase of the user and some other salient information
            expenses =  self.userProfile.increaseExpenseRandomly(1)
            

            # Calculate income remaining after costs attributed to tax, expenses, etc.
            self.userProfile.incomeAfterCosts(tax + tempLoanCost + expenses)
            logging.debug(f'Income Remaining: ${self.userProfile.remainingIncome:0.2f}')
            # Capture income history for future analysis
            self.userProfile.getIncomeHistory(dateStartTemp, self.userProfile.remainingIncome)
            
            
            # If the amount of disposable income cannot service the loans and expenses, then 1. don't save any money.
            # If there is still not enough money, draw it out of savings...
            # NOTE: obviously there are lots of ways this deficiency can be tackled...
            if (self.userProfile.income - tax) < (tempLoanCost + expenses):
                savedAmt = self.userProfile.getSavedAmount(self.userProfile.remainingIncome)
                
                # capture savings history
                self.userProfile.getSavingHistory(dateStartTemp, savedAmt)
                
            else:
                # Savings
                # Calculate savings based on remaining income (can't save what you don't have)
                savedAmt = self.userProfile.getSavedAmount(self.userProfile.remainingIncome)
                logging.debug(f'Amount saved this month: ${savedAmt:0.2f}')
                
                # capture savings history
                self.userProfile.getSavingHistory(dateStartTemp, savedAmt)

            # Note: if more draw downs occur on the remaining income, then the savings need to be subtracted explicitly aswell.
            # As this is not the case, it doesn't matter that the savings amount isn't removed from this parameter.


            # Asset value
            # Compute asset value based on compounding period and interest rates 
    #         self.userProfile.getAssetValue(self.userProfile, compoundPeriod)

            # Create an ordered dictionary of information
            yield OrderedDict([('Date', dateStartTemp),
                              ('Income', self.userProfile.income),
                              ('Tax', self.userProfile.getTaxAmount(self.userProfile.income)),
                              ('SuperContrib', self.userProfile.superContrib),
                               ('SuperBalance', self.userProfile.superBalCumSum),
                               ('SuperValue', self.userProfile.superValCumSum),
                              ('LoanDebt', tempLoanCost),
                              ('Expenses', expenses),
                              ('RemainingIncome', self.userProfile.remainingIncome),
                              ('SavedAmt', savedAmt)])

            # Steps through time another month
            dateStartTemp += relativedelta(months=1)

            # if the current month of the year is January and we're not on the first year of the simulation
            # Add another year to the users profile, e.g. age them another year.
            if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
                self.userProfile.ageStep(1)

        # Iterate over life with month level granularity
        # Phase Two - Retirement
        logging.info('ENTERING PHASE TWO')

        # While the users age is less than the age of death, run the simulation
        while self.userProfile.age < self.userProfile.deadAge:
            logging.debug(f'Current DateTime: {dateStartTemp}')

            # Super drawdown
            # Draw down super as this will act as a source of income
            # Need to review how this is used...
            self.userProfile.superDrawDown()

            # Expenses
            # Expenses in the retirement phase are treated differently to the 
            # working life phase
            expenses =  self.userProfile.increaseExpenseRandomly(2)

            # Create an ordered dictionary of information
            yield OrderedDict([('Date', dateStartTemp),
                              ('Income', 0),
                              ('Tax', 0),
                              ('SuperContrib', 0),
                              ('SuperBalance', self.userProfile.superBalCumSum),
                              ('SuperValue', self.userProfile.superValCumSum),
                              ('LoanDebt', 0),
                              ('Expenses', expenses),
                              ('RemainingIncome', 0),
                              ('SavedAmt', 0)])

            # Steps through time another month
            dateStartTemp += relativedelta(months=1)

            # if the current month of the year is January and we're not on the first year of the simulation
            # Add another year to the users profile, e.g. age them another year.
            if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
                self.userProfile.ageStep(1)
                
                
    def simulate(self):
        """
        Simulates a users finance over their lifetime.
        """
        return pd.DataFrame(self.simulate_one_step())
        
                
    def monte_carlo_model(self, iterations):
        """
        Runs n iterations of the user life simulation and captures results for analysis.
        """
        
        self.simulationHistory = list()
        
        # Output information pertaining to to user profile summary and loan descriptions/information
        self.userProfile.summary()
        self.userProfile.loanDesc()
        self.userProfile.loanInfo()
        
        for iteration in tqdm(range(1, iterations+1, 1)):
#             print(f'\nIteration Number: {iteration}')
            self.simulationHistory.append(self.simulate())
            
            # Need to reinitialise user profile as the profile model believes the user is dead....
            self.init_user_profile()
    

    def statistical_analysis(self):
        """
        Performs a basic statistical analysis (mean, Q25, Q50, Q75) of the Monte Carlo simulation results. 
        """
        
        # Initialise empty dataframe instance - 'master dataframe'
        self.df_analytics = pd.DataFrame()
        
        for col_name in self.simulationHistory[0].drop('Date', axis=1).columns:    # iterate over columns except Date
            print(f'Processing: {col_name}')

            # column counter used for iteration columns for each type of column
            sim_column_count = 1

            df_temp_analytics = pd.DataFrame()    # used to create a temporary dataframe for each column type which then can have statistical analysis done. This is then concatenated to the master dataframe.
            for df in self.simulationHistory:

                # Expenses
                df_temp_analytics[f'{col_name}_{sim_column_count}'] = df[col_name]

                sim_column_count += 1

            self.df_analytics[f'{col_name}_Mean'] = df_temp_analytics.apply(lambda x: x.mean(), axis=1)
            self.df_analytics[f'{col_name}_Q25'] = df_temp_analytics.apply(lambda x: x.quantile(0.25), axis=1)
            self.df_analytics[f'{col_name}_Q50'] = df_temp_analytics.apply(lambda x: x.quantile(0.50), axis=1)
            self.df_analytics[f'{col_name}_Q75'] = df_temp_analytics.apply(lambda x: x.quantile(0.75), axis=1)

# %% [markdown]
# > <b>Earnings</b>: Employment for users is not constant but rather dependent on various latent factors such as 1. 2. 3. 4. 5. etc. This dictates the amount of income of the user.<br> Note: Earnings dictate monthly income

# %%
class Earnings():

    def __init__(self, eduLevel, age, retireAge):
        """
        Something...
        """
    
        self.renumerationType = 'salary'
        self.employmentType = 'FT'    # FT (sal), PT (sal), CAS (wage), TEMP (wage)
        self.employmentStatus = 'Working'    # Working, temp. laid off, unemployed, retired, disabled, housewife, student, other (only first 3 are included in the paper 'Modeling Earning Dynamics')
        self.employed = True    # will be inhierited by profile class...
        self.tenure = 0  # months
        self.tenureBeforeJobLoss = 0    # Months
        self.maxTenure = (retireAge-age)*12   # months
        self.currentIncomePA = 50000
        self.maximumIncomePA = 200000
        
        self.jobTransitions = 0
        
        
        eduRisk = {1:0.05, 2:0.04, 3: 0.03, 4: 0.02, 5: 0.01, 6: 0.0075, 7: 0.005}   # eduLevel : bernoulli risk probability correction...
        self.eduRiskLevel = eduRisk[eduLevel]
            
        
    def captureTenure(self):
        """
        Amount of tenure accumulated over time. This is proportional to experience...
        """
        
        if self.employed:
            self.tenure += 1
            
    def countJobTransitions(self):
        self.jobTransitions += 1
    
    def employmentTransition(self):
        """
        Employment transitions, including whether profile becomes unemployed or not. Furthermore, this may also be related to getting better roles.
        Job searching, labor supply...
        Job offer...
        Job in similar domain -> offer based on similar earnings
        Job type/industry -> change... 
        Unemployment and Job shocks...
        Job specific hour shocks...
        Job shopping...
        Job tenure...
        
        Discrete events... job changes, employment loss, interactions between job changes and wages
        Temporary / Permanent layoffs
        
        Account for persons who come out of retirement and include observations following a retirement spell if the individual is working, temporarily laid off, or unemployed.
        
        Assumes that tenure dictates likelihood of unemployment (doesn't take job specific roles into account). For example: If a job is lost and regained, the risk level doesn't reset but rather starts lowering again from a new tenure.
        """
    
        # the risk of job loss reduces with increasing tenure... using an inverse relationship... this could probably be changed to a natural log or similar in the future.
        if self.employed:
            
            # Capture tenure for being employed.
            self.captureTenure()
            
            # Compute unemployment risk based on education level and tenure...
            self.eduRiskLevel = self.eduRiskLevel * (1 - ((self.tenure/self.maxTenure)/100))
            
            # First logic is the chance of becoming unemployed.
            if np.random.binomial(n = 1, p = self.eduRiskLevel):
                print('Job lost')
                self.jobTransitions += 1   # not working...
                self.employed = False
                self.tenureBeforeJobLoss = self.tenure   # Used to weight the reemployment calculation
                print(self.tenureBeforeJobLoss)
                self.tenure = 0   # reset tenure...
            
        # If not employed...
        # Need to try and get job back and restart tenure...
        if not self.employed:
            print('Not employed')
            
            
            # Current probability is random, however, this should be weighted on education level and tenure...This isn't the best logic but it's something.
            if np.random.binomial(n = 1, p = 0.25):
                print('Got a job...')
                self.employed = True
    
    
    def dynamicEarnings(self):
        """
        Model for changes in earnings based on latent factors such as education, experience, productivity, etc.
        """
        
        self.currentIncomePA = (self.maximumIncomePA - self.currentIncomePA)*(self.tenure/self.maxTenure)+self.currentIncomePA

# %% [markdown]
# > <b>What is the typical number of job 'hops' for a career?</b><br> "The best data the Bureau of Labor Statistics has on how many jobs people hold in a lifetime is a longterm study that has followed baby boomers through most of their careers up until now. On average, people in that study held 11.7 jobs between age 18 and 48. About 27 percent of them were particularly prone to hop, holding 15 jobs or more, while 10 percent held zero to four jobs."<br>"Their study found that millennials will change jobs an average of four times in their first decade out of college, compared to about two job changes by Gen Xers their first ten years out of college"<br>
# ref: https://www.edsurge.com/news/2017-07-20-how-many-times-will-people-change-jobs-the-myth-of-the-endlessly-job-hopping-millennial

# %% [markdown]
# ## Testing - Earning Dynamics Model

# %%
dateStart = datetime.date(2020,1,1)
dateStartTemp = dateStart

userAge = 26
retireAge = 65

# Initialise education
# edu = Education()

# Initialise an 'earnings' class for someone with education level 2, who is 26 years old and wants to retire at 27...
earning = Earnings(eduLevel=2, age=userAge, retireAge=retireAge)

while userAge <= retireAge:
    
    
    # Earnings model
    earning.employmentTransition()    # Make a transition...


    # Debug Output
    print(f'{dateStartTemp} - Employement Status {earning.employed} - Months of tenure {earning.tenure} - Current Unemployment Risk {earning.eduRiskLevel*100:0.2f}% - Current Earning (PA) ${earning.currentIncomePA:0.2f}')
    
    
    # Steps through time another month
    dateStartTemp += relativedelta(months=1)

    
    # if the current month of the year is January and we're not on the first year of the simulation
    # Add another year to the users profile, e.g. age them another year.
    if dateStartTemp.month == 1 and 0 < (dateStartTemp.year - dateStart.year):
        userAge += 1
        earning.dynamicEarnings()   # compute new earnings at end of year...
# Out:
# 2020-01-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-02-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-03-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-04-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-05-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-06-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-07-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-08-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-09-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-10-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 4.00% - Current Earning (PA) $50000.00
# 2020-11-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.99% - Current Earning (PA) $50000.00
# 2020-12-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.99% - Current Earning (PA) $50000.00
# 2021-01-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.99% - Current Earning (PA) $53846.15
# 2021-02-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.99% - Current Earning (PA) $53846.15
# 2021-03-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.99% - Current Earning (PA) $53846.15
# 2021-04-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.99% - Current Earning (PA) $53846.15
# 2021-05-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.99% - Current Earning (PA) $53846.15
# 2021-06-01 - Employement Status True - Months of tenure 18 - Current Unemployment Risk 3.99% - Current Earning (PA) $53846.15
# 2021-07-01 - Employement Status True - Months of tenure 19 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2021-08-01 - Employement Status True - Months of tenure 20 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2021-09-01 - Employement Status True - Months of tenure 21 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2021-10-01 - Employement Status True - Months of tenure 22 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Job lost
# 23
# Not employed
# 2021-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2021-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2022-01-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2022-02-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2022-03-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2022-04-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2022-05-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# 2022-06-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# Not employed
# Got a job...
# 2022-07-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2022-08-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2022-09-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2022-10-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2022-11-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2022-12-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.98% - Current Earning (PA) $53846.15
# 2023-01-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-02-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-03-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-04-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-05-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-06-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-07-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-08-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-09-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-10-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.97% - Current Earning (PA) $55407.63
# 2023-11-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.96% - Current Earning (PA) $55407.63
# 2023-12-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.96% - Current Earning (PA) $55407.63
# 2024-01-01 - Employement Status True - Months of tenure 18 - Current Unemployment Risk 3.96% - Current Earning (PA) $60659.91
# 2024-02-01 - Employement Status True - Months of tenure 19 - Current Unemployment Risk 3.96% - Current Earning (PA) $60659.91
# 2024-03-01 - Employement Status True - Months of tenure 20 - Current Unemployment Risk 3.96% - Current Earning (PA) $60659.91
# 2024-04-01 - Employement Status True - Months of tenure 21 - Current Unemployment Risk 3.96% - Current Earning (PA) $60659.91
# 2024-05-01 - Employement Status True - Months of tenure 22 - Current Unemployment Risk 3.96% - Current Earning (PA) $60659.91
# 2024-06-01 - Employement Status True - Months of tenure 23 - Current Unemployment Risk 3.95% - Current Earning (PA) $60659.91
# 2024-07-01 - Employement Status True - Months of tenure 24 - Current Unemployment Risk 3.95% - Current Earning (PA) $60659.91
# 2024-08-01 - Employement Status True - Months of tenure 25 - Current Unemployment Risk 3.95% - Current Earning (PA) $60659.91
# 2024-09-01 - Employement Status True - Months of tenure 26 - Current Unemployment Risk 3.95% - Current Earning (PA) $60659.91
# 2024-10-01 - Employement Status True - Months of tenure 27 - Current Unemployment Risk 3.94% - Current Earning (PA) $60659.91
# 2024-11-01 - Employement Status True - Months of tenure 28 - Current Unemployment Risk 3.94% - Current Earning (PA) $60659.91
# 2024-12-01 - Employement Status True - Months of tenure 29 - Current Unemployment Risk 3.94% - Current Earning (PA) $60659.91
# 2025-01-01 - Employement Status True - Months of tenure 30 - Current Unemployment Risk 3.94% - Current Earning (PA) $69294.24
# 2025-02-01 - Employement Status True - Months of tenure 31 - Current Unemployment Risk 3.93% - Current Earning (PA) $69294.24
# 2025-03-01 - Employement Status True - Months of tenure 32 - Current Unemployment Risk 3.93% - Current Earning (PA) $69294.24
# 2025-04-01 - Employement Status True - Months of tenure 33 - Current Unemployment Risk 3.93% - Current Earning (PA) $69294.24
# 2025-05-01 - Employement Status True - Months of tenure 34 - Current Unemployment Risk 3.93% - Current Earning (PA) $69294.24
# 2025-06-01 - Employement Status True - Months of tenure 35 - Current Unemployment Risk 3.92% - Current Earning (PA) $69294.24
# 2025-07-01 - Employement Status True - Months of tenure 36 - Current Unemployment Risk 3.92% - Current Earning (PA) $69294.24
# 2025-08-01 - Employement Status True - Months of tenure 37 - Current Unemployment Risk 3.92% - Current Earning (PA) $69294.24
# 2025-09-01 - Employement Status True - Months of tenure 38 - Current Unemployment Risk 3.91% - Current Earning (PA) $69294.24
# 2025-10-01 - Employement Status True - Months of tenure 39 - Current Unemployment Risk 3.91% - Current Earning (PA) $69294.24
# 2025-11-01 - Employement Status True - Months of tenure 40 - Current Unemployment Risk 3.91% - Current Earning (PA) $69294.24
# 2025-12-01 - Employement Status True - Months of tenure 41 - Current Unemployment Risk 3.90% - Current Earning (PA) $69294.24
# 2026-01-01 - Employement Status True - Months of tenure 42 - Current Unemployment Risk 3.90% - Current Earning (PA) $80744.95
# 2026-02-01 - Employement Status True - Months of tenure 43 - Current Unemployment Risk 3.90% - Current Earning (PA) $80744.95
# 2026-03-01 - Employement Status True - Months of tenure 44 - Current Unemployment Risk 3.89% - Current Earning (PA) $80744.95
# 2026-04-01 - Employement Status True - Months of tenure 45 - Current Unemployment Risk 3.89% - Current Earning (PA) $80744.95
# 2026-05-01 - Employement Status True - Months of tenure 46 - Current Unemployment Risk 3.89% - Current Earning (PA) $80744.95
# 2026-06-01 - Employement Status True - Months of tenure 47 - Current Unemployment Risk 3.88% - Current Earning (PA) $80744.95
# 2026-07-01 - Employement Status True - Months of tenure 48 - Current Unemployment Risk 3.88% - Current Earning (PA) $80744.95
# 2026-08-01 - Employement Status True - Months of tenure 49 - Current Unemployment Risk 3.87% - Current Earning (PA) $80744.95
# 2026-09-01 - Employement Status True - Months of tenure 50 - Current Unemployment Risk 3.87% - Current Earning (PA) $80744.95
# 2026-10-01 - Employement Status True - Months of tenure 51 - Current Unemployment Risk 3.87% - Current Earning (PA) $80744.95
# 2026-11-01 - Employement Status True - Months of tenure 52 - Current Unemployment Risk 3.86% - Current Earning (PA) $80744.95
# 2026-12-01 - Employement Status True - Months of tenure 53 - Current Unemployment Risk 3.86% - Current Earning (PA) $80744.95
# 2027-01-01 - Employement Status True - Months of tenure 54 - Current Unemployment Risk 3.85% - Current Earning (PA) $94250.33
# 2027-02-01 - Employement Status True - Months of tenure 55 - Current Unemployment Risk 3.85% - Current Earning (PA) $94250.33
# 2027-03-01 - Employement Status True - Months of tenure 56 - Current Unemployment Risk 3.84% - Current Earning (PA) $94250.33
# 2027-04-01 - Employement Status True - Months of tenure 57 - Current Unemployment Risk 3.84% - Current Earning (PA) $94250.33
# 2027-05-01 - Employement Status True - Months of tenure 58 - Current Unemployment Risk 3.83% - Current Earning (PA) $94250.33
# 2027-06-01 - Employement Status True - Months of tenure 59 - Current Unemployment Risk 3.83% - Current Earning (PA) $94250.33
# 2027-07-01 - Employement Status True - Months of tenure 60 - Current Unemployment Risk 3.82% - Current Earning (PA) $94250.33
# 2027-08-01 - Employement Status True - Months of tenure 61 - Current Unemployment Risk 3.82% - Current Earning (PA) $94250.33
# 2027-09-01 - Employement Status True - Months of tenure 62 - Current Unemployment Risk 3.81% - Current Earning (PA) $94250.33
# 2027-10-01 - Employement Status True - Months of tenure 63 - Current Unemployment Risk 3.81% - Current Earning (PA) $94250.33
# 2027-11-01 - Employement Status True - Months of tenure 64 - Current Unemployment Risk 3.80% - Current Earning (PA) $94250.33
# 2027-12-01 - Employement Status True - Months of tenure 65 - Current Unemployment Risk 3.80% - Current Earning (PA) $94250.33
# 2028-01-01 - Employement Status True - Months of tenure 66 - Current Unemployment Risk 3.79% - Current Earning (PA) $108937.79
# 2028-02-01 - Employement Status True - Months of tenure 67 - Current Unemployment Risk 3.79% - Current Earning (PA) $108937.79
# 2028-03-01 - Employement Status True - Months of tenure 68 - Current Unemployment Risk 3.78% - Current Earning (PA) $108937.79
# 2028-04-01 - Employement Status True - Months of tenure 69 - Current Unemployment Risk 3.78% - Current Earning (PA) $108937.79
# 2028-05-01 - Employement Status True - Months of tenure 70 - Current Unemployment Risk 3.77% - Current Earning (PA) $108937.79
# 2028-06-01 - Employement Status True - Months of tenure 71 - Current Unemployment Risk 3.77% - Current Earning (PA) $108937.79
# 2028-07-01 - Employement Status True - Months of tenure 72 - Current Unemployment Risk 3.76% - Current Earning (PA) $108937.79
# 2028-08-01 - Employement Status True - Months of tenure 73 - Current Unemployment Risk 3.75% - Current Earning (PA) $108937.79
# 2028-09-01 - Employement Status True - Months of tenure 74 - Current Unemployment Risk 3.75% - Current Earning (PA) $108937.79
# 2028-10-01 - Employement Status True - Months of tenure 75 - Current Unemployment Risk 3.74% - Current Earning (PA) $108937.79
# 2028-11-01 - Employement Status True - Months of tenure 76 - Current Unemployment Risk 3.74% - Current Earning (PA) $108937.79
# 2028-12-01 - Employement Status True - Months of tenure 77 - Current Unemployment Risk 3.73% - Current Earning (PA) $108937.79
# 2029-01-01 - Employement Status True - Months of tenure 78 - Current Unemployment Risk 3.72% - Current Earning (PA) $123920.24
# 2029-02-01 - Employement Status True - Months of tenure 79 - Current Unemployment Risk 3.72% - Current Earning (PA) $123920.24
# 2029-03-01 - Employement Status True - Months of tenure 80 - Current Unemployment Risk 3.71% - Current Earning (PA) $123920.24
# 2029-04-01 - Employement Status True - Months of tenure 81 - Current Unemployment Risk 3.70% - Current Earning (PA) $123920.24
# 2029-05-01 - Employement Status True - Months of tenure 82 - Current Unemployment Risk 3.70% - Current Earning (PA) $123920.24
# 2029-06-01 - Employement Status True - Months of tenure 83 - Current Unemployment Risk 3.69% - Current Earning (PA) $123920.24
# 2029-07-01 - Employement Status True - Months of tenure 84 - Current Unemployment Risk 3.68% - Current Earning (PA) $123920.24
# 2029-08-01 - Employement Status True - Months of tenure 85 - Current Unemployment Risk 3.68% - Current Earning (PA) $123920.24
# 2029-09-01 - Employement Status True - Months of tenure 86 - Current Unemployment Risk 3.67% - Current Earning (PA) $123920.24
# 2029-10-01 - Employement Status True - Months of tenure 87 - Current Unemployment Risk 3.66% - Current Earning (PA) $123920.24
# 2029-11-01 - Employement Status True - Months of tenure 88 - Current Unemployment Risk 3.66% - Current Earning (PA) $123920.24
# 2029-12-01 - Employement Status True - Months of tenure 89 - Current Unemployment Risk 3.65% - Current Earning (PA) $123920.24
# 2030-01-01 - Employement Status True - Months of tenure 90 - Current Unemployment Risk 3.64% - Current Earning (PA) $138388.40
# 2030-02-01 - Employement Status True - Months of tenure 91 - Current Unemployment Risk 3.64% - Current Earning (PA) $138388.40
# 2030-03-01 - Employement Status True - Months of tenure 92 - Current Unemployment Risk 3.63% - Current Earning (PA) $138388.40
# 2030-04-01 - Employement Status True - Months of tenure 93 - Current Unemployment Risk 3.62% - Current Earning (PA) $138388.40
# 2030-05-01 - Employement Status True - Months of tenure 94 - Current Unemployment Risk 3.61% - Current Earning (PA) $138388.40
# 2030-06-01 - Employement Status True - Months of tenure 95 - Current Unemployment Risk 3.61% - Current Earning (PA) $138388.40
# 2030-07-01 - Employement Status True - Months of tenure 96 - Current Unemployment Risk 3.60% - Current Earning (PA) $138388.40
# 2030-08-01 - Employement Status True - Months of tenure 97 - Current Unemployment Risk 3.59% - Current Earning (PA) $138388.40
# 2030-09-01 - Employement Status True - Months of tenure 98 - Current Unemployment Risk 3.58% - Current Earning (PA) $138388.40
# 2030-10-01 - Employement Status True - Months of tenure 99 - Current Unemployment Risk 3.58% - Current Earning (PA) $138388.40
# 2030-11-01 - Employement Status True - Months of tenure 100 - Current Unemployment Risk 3.57% - Current Earning (PA) $138388.40
# 2030-12-01 - Employement Status True - Months of tenure 101 - Current Unemployment Risk 3.56% - Current Earning (PA) $138388.40
# Job lost
# 102
# Not employed
# Got a job...
# 2031-01-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-02-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-03-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-04-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-05-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-06-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-07-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-08-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-09-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-10-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-11-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2031-12-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.55% - Current Earning (PA) $151684.92
# 2032-01-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# 2032-02-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# Job lost
# 14
# Not employed
# 2032-03-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# Not employed
# Got a job...
# 2032-04-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# 2032-05-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# 2032-06-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# 2032-07-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# 2032-08-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.55% - Current Earning (PA) $152820.53
# 2032-09-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.54% - Current Earning (PA) $152820.53
# 2032-10-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.54% - Current Earning (PA) $152820.53
# 2032-11-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.54% - Current Earning (PA) $152820.53
# 2032-12-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.54% - Current Earning (PA) $152820.53
# 2033-01-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-02-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-03-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-04-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-05-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-06-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# Job lost
# 15
# Not employed
# 2033-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# Not employed
# Got a job...
# 2033-08-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-09-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-10-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-11-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2033-12-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.54% - Current Earning (PA) $153627.02
# 2034-01-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Job lost
# 6
# Not employed
# 2034-02-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-03-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-04-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-05-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-06-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-08-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-09-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-10-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# 2034-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# Not employed
# Got a job...
# 2035-01-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# 2035-02-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# 2035-03-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.54% - Current Earning (PA) $154023.37
# 2035-04-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-05-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-06-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-07-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-08-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-09-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-10-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-11-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# 2035-12-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.53% - Current Earning (PA) $154023.37
# Job lost
# 12
# Not employed
# Got a job...
# 2036-01-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-02-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-03-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-04-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-05-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-06-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-07-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-08-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-09-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-10-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-11-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.53% - Current Earning (PA) $155104.02
# 2036-12-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.52% - Current Earning (PA) $155104.02
# 2037-01-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2037-02-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2037-03-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2037-04-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2037-05-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Job lost
# 17
# Not employed
# 2037-06-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# 2037-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# Got a job...
# 2037-08-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Job lost
# 1
# Not employed
# 2037-09-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# 2037-10-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# 2037-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# 2037-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# 2038-01-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# 2038-02-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# Not employed
# Got a job...
# 2038-03-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-04-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-05-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-06-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-07-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-08-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-09-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-10-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-11-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.52% - Current Earning (PA) $156159.27
# 2038-12-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.51% - Current Earning (PA) $156159.27
# 2039-01-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-02-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-03-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-04-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-05-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-06-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-07-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-08-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-09-01 - Employement Status True - Months of tenure 18 - Current Unemployment Risk 3.51% - Current Earning (PA) $157002.36
# 2039-10-01 - Employement Status True - Months of tenure 19 - Current Unemployment Risk 3.50% - Current Earning (PA) $157002.36
# 2039-11-01 - Employement Status True - Months of tenure 20 - Current Unemployment Risk 3.50% - Current Earning (PA) $157002.36
# 2039-12-01 - Employement Status True - Months of tenure 21 - Current Unemployment Risk 3.50% - Current Earning (PA) $157002.36
# 2040-01-01 - Employement Status True - Months of tenure 22 - Current Unemployment Risk 3.50% - Current Earning (PA) $158931.74
# 2040-02-01 - Employement Status True - Months of tenure 23 - Current Unemployment Risk 3.50% - Current Earning (PA) $158931.74
# 2040-03-01 - Employement Status True - Months of tenure 24 - Current Unemployment Risk 3.50% - Current Earning (PA) $158931.74
# 2040-04-01 - Employement Status True - Months of tenure 25 - Current Unemployment Risk 3.49% - Current Earning (PA) $158931.74
# 2040-05-01 - Employement Status True - Months of tenure 26 - Current Unemployment Risk 3.49% - Current Earning (PA) $158931.74
# 2040-06-01 - Employement Status True - Months of tenure 27 - Current Unemployment Risk 3.49% - Current Earning (PA) $158931.74
# 2040-07-01 - Employement Status True - Months of tenure 28 - Current Unemployment Risk 3.49% - Current Earning (PA) $158931.74
# 2040-08-01 - Employement Status True - Months of tenure 29 - Current Unemployment Risk 3.49% - Current Earning (PA) $158931.74
# 2040-09-01 - Employement Status True - Months of tenure 30 - Current Unemployment Risk 3.48% - Current Earning (PA) $158931.74
# 2040-10-01 - Employement Status True - Months of tenure 31 - Current Unemployment Risk 3.48% - Current Earning (PA) $158931.74
# 2040-11-01 - Employement Status True - Months of tenure 32 - Current Unemployment Risk 3.48% - Current Earning (PA) $158931.74
# 2040-12-01 - Employement Status True - Months of tenure 33 - Current Unemployment Risk 3.48% - Current Earning (PA) $158931.74
# 2041-01-01 - Employement Status True - Months of tenure 34 - Current Unemployment Risk 3.47% - Current Earning (PA) $161827.58
# 2041-02-01 - Employement Status True - Months of tenure 35 - Current Unemployment Risk 3.47% - Current Earning (PA) $161827.58
# 2041-03-01 - Employement Status True - Months of tenure 36 - Current Unemployment Risk 3.47% - Current Earning (PA) $161827.58
# 2041-04-01 - Employement Status True - Months of tenure 37 - Current Unemployment Risk 3.47% - Current Earning (PA) $161827.58
# 2041-05-01 - Employement Status True - Months of tenure 38 - Current Unemployment Risk 3.46% - Current Earning (PA) $161827.58
# 2041-06-01 - Employement Status True - Months of tenure 39 - Current Unemployment Risk 3.46% - Current Earning (PA) $161827.58
# 2041-07-01 - Employement Status True - Months of tenure 40 - Current Unemployment Risk 3.46% - Current Earning (PA) $161827.58
# 2041-08-01 - Employement Status True - Months of tenure 41 - Current Unemployment Risk 3.45% - Current Earning (PA) $161827.58
# 2041-09-01 - Employement Status True - Months of tenure 42 - Current Unemployment Risk 3.45% - Current Earning (PA) $161827.58
# 2041-10-01 - Employement Status True - Months of tenure 43 - Current Unemployment Risk 3.45% - Current Earning (PA) $161827.58
# 2041-11-01 - Employement Status True - Months of tenure 44 - Current Unemployment Risk 3.44% - Current Earning (PA) $161827.58
# 2041-12-01 - Employement Status True - Months of tenure 45 - Current Unemployment Risk 3.44% - Current Earning (PA) $161827.58
# 2042-01-01 - Employement Status True - Months of tenure 46 - Current Unemployment Risk 3.44% - Current Earning (PA) $165498.00
# 2042-02-01 - Employement Status True - Months of tenure 47 - Current Unemployment Risk 3.43% - Current Earning (PA) $165498.00
# 2042-03-01 - Employement Status True - Months of tenure 48 - Current Unemployment Risk 3.43% - Current Earning (PA) $165498.00
# 2042-04-01 - Employement Status True - Months of tenure 49 - Current Unemployment Risk 3.43% - Current Earning (PA) $165498.00
# 2042-05-01 - Employement Status True - Months of tenure 50 - Current Unemployment Risk 3.42% - Current Earning (PA) $165498.00
# 2042-06-01 - Employement Status True - Months of tenure 51 - Current Unemployment Risk 3.42% - Current Earning (PA) $165498.00
# 2042-07-01 - Employement Status True - Months of tenure 52 - Current Unemployment Risk 3.42% - Current Earning (PA) $165498.00
# 2042-08-01 - Employement Status True - Months of tenure 53 - Current Unemployment Risk 3.41% - Current Earning (PA) $165498.00
# 2042-09-01 - Employement Status True - Months of tenure 54 - Current Unemployment Risk 3.41% - Current Earning (PA) $165498.00
# 2042-10-01 - Employement Status True - Months of tenure 55 - Current Unemployment Risk 3.40% - Current Earning (PA) $165498.00
# 2042-11-01 - Employement Status True - Months of tenure 56 - Current Unemployment Risk 3.40% - Current Earning (PA) $165498.00
# 2042-12-01 - Employement Status True - Months of tenure 57 - Current Unemployment Risk 3.40% - Current Earning (PA) $165498.00
# 2043-01-01 - Employement Status True - Months of tenure 58 - Current Unemployment Risk 3.39% - Current Earning (PA) $169700.17
# 2043-02-01 - Employement Status True - Months of tenure 59 - Current Unemployment Risk 3.39% - Current Earning (PA) $169700.17
# 2043-03-01 - Employement Status True - Months of tenure 60 - Current Unemployment Risk 3.38% - Current Earning (PA) $169700.17
# 2043-04-01 - Employement Status True - Months of tenure 61 - Current Unemployment Risk 3.38% - Current Earning (PA) $169700.17
# 2043-05-01 - Employement Status True - Months of tenure 62 - Current Unemployment Risk 3.37% - Current Earning (PA) $169700.17
# 2043-06-01 - Employement Status True - Months of tenure 63 - Current Unemployment Risk 3.37% - Current Earning (PA) $169700.17
# Job lost
# 64
# Not employed
# 2043-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2043-08-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2043-09-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2043-10-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2043-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2043-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2044-01-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2044-02-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# Got a job...
# 2044-03-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2044-04-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2044-05-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2044-06-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2044-07-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2044-08-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2044-09-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Job lost
# 7
# Not employed
# 2044-10-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2044-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# 2044-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# Not employed
# Got a job...
# 2045-01-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-02-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-03-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-04-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-05-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-06-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-07-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-08-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-09-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-10-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-11-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2045-12-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.36% - Current Earning (PA) $169700.17
# 2046-01-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.36% - Current Earning (PA) $170412.34
# 2046-02-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.36% - Current Earning (PA) $170412.34
# 2046-03-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.36% - Current Earning (PA) $170412.34
# 2046-04-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-05-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-06-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-07-01 - Employement Status True - Months of tenure 18 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-08-01 - Employement Status True - Months of tenure 19 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-09-01 - Employement Status True - Months of tenure 20 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-10-01 - Employement Status True - Months of tenure 21 - Current Unemployment Risk 3.35% - Current Earning (PA) $170412.34
# 2046-11-01 - Employement Status True - Months of tenure 22 - Current Unemployment Risk 3.34% - Current Earning (PA) $170412.34
# 2046-12-01 - Employement Status True - Months of tenure 23 - Current Unemployment Risk 3.34% - Current Earning (PA) $170412.34
# 2047-01-01 - Employement Status True - Months of tenure 24 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-02-01 - Employement Status True - Months of tenure 25 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# Job lost
# 26
# Not employed
# Got a job...
# 2047-03-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-04-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-05-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-06-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-07-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-08-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-09-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-10-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-11-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.34% - Current Earning (PA) $171866.44
# 2047-12-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.33% - Current Earning (PA) $171866.44
# 2048-01-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-02-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-03-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-04-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-05-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-06-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-07-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2048-08-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# Job lost
# 18
# Not employed
# 2048-09-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# Not employed
# 2048-10-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# Not employed
# 2048-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# Not employed
# 2048-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# Not employed
# Got a job...
# 2049-01-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2049-02-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2049-03-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2049-04-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.33% - Current Earning (PA) $172407.47
# 2049-05-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-06-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-07-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-08-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-09-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-10-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-11-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2049-12-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.32% - Current Earning (PA) $172407.47
# 2050-01-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.32% - Current Earning (PA) $173056.01
# 2050-02-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.32% - Current Earning (PA) $173056.01
# 2050-03-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.32% - Current Earning (PA) $173056.01
# 2050-04-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.32% - Current Earning (PA) $173056.01
# 2050-05-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.32% - Current Earning (PA) $173056.01
# 2050-06-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2050-07-01 - Employement Status True - Months of tenure 18 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2050-08-01 - Employement Status True - Months of tenure 19 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2050-09-01 - Employement Status True - Months of tenure 20 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2050-10-01 - Employement Status True - Months of tenure 21 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2050-11-01 - Employement Status True - Months of tenure 22 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2050-12-01 - Employement Status True - Months of tenure 23 - Current Unemployment Risk 3.31% - Current Earning (PA) $173056.01
# 2051-01-01 - Employement Status True - Months of tenure 24 - Current Unemployment Risk 3.30% - Current Earning (PA) $174380.18
# 2051-02-01 - Employement Status True - Months of tenure 25 - Current Unemployment Risk 3.30% - Current Earning (PA) $174380.18
# 2051-03-01 - Employement Status True - Months of tenure 26 - Current Unemployment Risk 3.30% - Current Earning (PA) $174380.18
# 2051-04-01 - Employement Status True - Months of tenure 27 - Current Unemployment Risk 3.30% - Current Earning (PA) $174380.18
# 2051-05-01 - Employement Status True - Months of tenure 28 - Current Unemployment Risk 3.30% - Current Earning (PA) $174380.18
# 2051-06-01 - Employement Status True - Months of tenure 29 - Current Unemployment Risk 3.29% - Current Earning (PA) $174380.18
# 2051-07-01 - Employement Status True - Months of tenure 30 - Current Unemployment Risk 3.29% - Current Earning (PA) $174380.18
# 2051-08-01 - Employement Status True - Months of tenure 31 - Current Unemployment Risk 3.29% - Current Earning (PA) $174380.18
# 2051-09-01 - Employement Status True - Months of tenure 32 - Current Unemployment Risk 3.29% - Current Earning (PA) $174380.18
# 2051-10-01 - Employement Status True - Months of tenure 33 - Current Unemployment Risk 3.29% - Current Earning (PA) $174380.18
# 2051-11-01 - Employement Status True - Months of tenure 34 - Current Unemployment Risk 3.28% - Current Earning (PA) $174380.18
# 2051-12-01 - Employement Status True - Months of tenure 35 - Current Unemployment Risk 3.28% - Current Earning (PA) $174380.18
# 2052-01-01 - Employement Status True - Months of tenure 36 - Current Unemployment Risk 3.28% - Current Earning (PA) $176296.19
# 2052-02-01 - Employement Status True - Months of tenure 37 - Current Unemployment Risk 3.28% - Current Earning (PA) $176296.19
# 2052-03-01 - Employement Status True - Months of tenure 38 - Current Unemployment Risk 3.27% - Current Earning (PA) $176296.19
# 2052-04-01 - Employement Status True - Months of tenure 39 - Current Unemployment Risk 3.27% - Current Earning (PA) $176296.19
# 2052-05-01 - Employement Status True - Months of tenure 40 - Current Unemployment Risk 3.27% - Current Earning (PA) $176296.19
# 2052-06-01 - Employement Status True - Months of tenure 41 - Current Unemployment Risk 3.26% - Current Earning (PA) $176296.19
# 2052-07-01 - Employement Status True - Months of tenure 42 - Current Unemployment Risk 3.26% - Current Earning (PA) $176296.19
# 2052-08-01 - Employement Status True - Months of tenure 43 - Current Unemployment Risk 3.26% - Current Earning (PA) $176296.19
# 2052-09-01 - Employement Status True - Months of tenure 44 - Current Unemployment Risk 3.26% - Current Earning (PA) $176296.19
# 2052-10-01 - Employement Status True - Months of tenure 45 - Current Unemployment Risk 3.25% - Current Earning (PA) $176296.19
# 2052-11-01 - Employement Status True - Months of tenure 46 - Current Unemployment Risk 3.25% - Current Earning (PA) $176296.19
# 2052-12-01 - Employement Status True - Months of tenure 47 - Current Unemployment Risk 3.25% - Current Earning (PA) $176296.19
# 2053-01-01 - Employement Status True - Months of tenure 48 - Current Unemployment Risk 3.24% - Current Earning (PA) $178676.70
# 2053-02-01 - Employement Status True - Months of tenure 49 - Current Unemployment Risk 3.24% - Current Earning (PA) $178676.70
# 2053-03-01 - Employement Status True - Months of tenure 50 - Current Unemployment Risk 3.24% - Current Earning (PA) $178676.70
# 2053-04-01 - Employement Status True - Months of tenure 51 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# 2053-05-01 - Employement Status True - Months of tenure 52 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# Job lost
# 53
# Not employed
# 2053-06-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# Not employed
# 2053-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# Not employed
# Got a job...
# 2053-08-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# 2053-09-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# 2053-10-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.23% - Current Earning (PA) $178676.70
# 2053-11-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.22% - Current Earning (PA) $178676.70
# 2053-12-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.22% - Current Earning (PA) $178676.70
# 2054-01-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# 2054-02-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# Job lost
# 7
# Not employed
# 2054-03-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# Not employed
# 2054-04-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# Not employed
# 2054-05-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# Not employed
# 2054-06-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# Not employed
# 2054-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# Not employed
# Got a job...
# 2054-08-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# 2054-09-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# 2054-10-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# 2054-11-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# 2054-12-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.22% - Current Earning (PA) $178858.95
# 2055-01-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2055-02-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2055-03-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2055-04-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2055-05-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2055-06-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Job lost
# 11
# Not employed
# 2055-07-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2055-08-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2055-09-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2055-10-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2055-11-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2055-12-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2056-01-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2056-02-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# 2056-03-01 - Employement Status False - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# Not employed
# Got a job...
# 2056-04-01 - Employement Status True - Months of tenure 0 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-05-01 - Employement Status True - Months of tenure 1 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-06-01 - Employement Status True - Months of tenure 2 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-07-01 - Employement Status True - Months of tenure 3 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-08-01 - Employement Status True - Months of tenure 4 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-09-01 - Employement Status True - Months of tenure 5 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-10-01 - Employement Status True - Months of tenure 6 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-11-01 - Employement Status True - Months of tenure 7 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2056-12-01 - Employement Status True - Months of tenure 8 - Current Unemployment Risk 3.22% - Current Earning (PA) $179039.65
# 2057-01-01 - Employement Status True - Months of tenure 9 - Current Unemployment Risk 3.22% - Current Earning (PA) $179397.94
# 2057-02-01 - Employement Status True - Months of tenure 10 - Current Unemployment Risk 3.22% - Current Earning (PA) $179397.94
# 2057-03-01 - Employement Status True - Months of tenure 11 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-04-01 - Employement Status True - Months of tenure 12 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-05-01 - Employement Status True - Months of tenure 13 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-06-01 - Employement Status True - Months of tenure 14 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-07-01 - Employement Status True - Months of tenure 15 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-08-01 - Employement Status True - Months of tenure 16 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-09-01 - Employement Status True - Months of tenure 17 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-10-01 - Employement Status True - Months of tenure 18 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-11-01 - Employement Status True - Months of tenure 19 - Current Unemployment Risk 3.21% - Current Earning (PA) $179397.94
# 2057-12-01 - Employement Status True - Months of tenure 20 - Current Unemployment Risk 3.20% - Current Earning (PA) $179397.94
# 2058-01-01 - Employement Status True - Months of tenure 21 - Current Unemployment Risk 3.20% - Current Earning (PA) $180278.37
# 2058-02-01 - Employement Status True - Months of tenure 22 - Current Unemployment Risk 3.20% - Current Earning (PA) $180278.37
# 2058-03-01 - Employement Status True - Months of tenure 23 - Current Unemployment Risk 3.20% - Current Earning (PA) $180278.37
# 2058-04-01 - Employement Status True - Months of tenure 24 - Current Unemployment Risk 3.20% - Current Earning (PA) $180278.37
# 2058-05-01 - Employement Status True - Months of tenure 25 - Current Unemployment Risk 3.20% - Current Earning (PA) $180278.37
# 2058-06-01 - Employement Status True - Months of tenure 26 - Current Unemployment Risk 3.19% - Current Earning (PA) $180278.37
# 2058-07-01 - Employement Status True - Months of tenure 27 - Current Unemployment Risk 3.19% - Current Earning (PA) $180278.37
# 2058-08-01 - Employement Status True - Months of tenure 28 - Current Unemployment Risk 3.19% - Current Earning (PA) $180278.37
# 2058-09-01 - Employement Status True - Months of tenure 29 - Current Unemployment Risk 3.19% - Current Earning (PA) $180278.37
# 2058-10-01 - Employement Status True - Months of tenure 30 - Current Unemployment Risk 3.19% - Current Earning (PA) $180278.37
# 2058-11-01 - Employement Status True - Months of tenure 31 - Current Unemployment Risk 3.18% - Current Earning (PA) $180278.37
# 2058-12-01 - Employement Status True - Months of tenure 32 - Current Unemployment Risk 3.18% - Current Earning (PA) $180278.37
# 2059-01-01 - Employement Status True - Months of tenure 33 - Current Unemployment Risk 3.18% - Current Earning (PA) $181626.86
# 2059-02-01 - Employement Status True - Months of tenure 34 - Current Unemployment Risk 3.18% - Current Earning (PA) $181626.86
# 2059-03-01 - Employement Status True - Months of tenure 35 - Current Unemployment Risk 3.18% - Current Earning (PA) $181626.86
# 2059-04-01 - Employement Status True - Months of tenure 36 - Current Unemployment Risk 3.17% - Current Earning (PA) $181626.86
# 2059-05-01 - Employement Status True - Months of tenure 37 - Current Unemployment Risk 3.17% - Current Earning (PA) $181626.86
# 2059-06-01 - Employement Status True - Months of tenure 38 - Current Unemployment Risk 3.17% - Current Earning (PA) $181626.86
# 2059-07-01 - Employement Status True - Months of tenure 39 - Current Unemployment Risk 3.17% - Current Earning (PA) $181626.86
# 2059-08-01 - Employement Status True - Months of tenure 40 - Current Unemployment Risk 3.16% - Current Earning (PA) $181626.86
# 2059-09-01 - Employement Status True - Months of tenure 41 - Current Unemployment Risk 3.16% - Current Earning (PA) $181626.86
# 2059-10-01 - Employement Status True - Months of tenure 42 - Current Unemployment Risk 3.16% - Current Earning (PA) $181626.86
# 2059-11-01 - Employement Status True - Months of tenure 43 - Current Unemployment Risk 3.15% - Current Earning (PA) $181626.86
# 2059-12-01 - Employement Status True - Months of tenure 44 - Current Unemployment Risk 3.15% - Current Earning (PA) $181626.86

# %%
earning.jobTransitions
# Out:
# 15

# %%
earning.currentIncomePA
# Out:
# 183354.24980977277

# %% [markdown]
# <img src="https://springboardai.com/wp-content/uploads/2017/11/header-use-case-finance.jpg">

# %% [markdown]
# # Running User Simulation model

# %%
# Simulation and user profile information
sim_details = {'profileDetails': {'name': 'Tyler',
                                  'age': 26,
                                  'retireAge': 65,
                                  'deadAge': 80,
                                  'incomePA': 52000,
                                  'expensesPM': 1000,
                                  'proportionSaved': 0.25
                                 },
                  'loanDetails': {
                      'loan_1': {'type': 'Home',
                                 'description': 'Home loan...',
                                 'principal':300000,
                                'interestRate': 0.04,
                                'annualPayments': 12,
                                'duration': 25,
                                'startDate': '01-01-2021',
                                'loanPaymentExtra': 0},
                      'loan_2': {'type': 'Car',
                                 'description': 'Car loan 1',
                                 'principal':50000,
                                'interestRate': 0.12,
                                'annualPayments': 12,
                                'duration': 10,
                                'startDate': '01-01-2025',
                                'loanPaymentExtra': 50},
                      'loan_3': {'type': 'Car',
                                 'description': 'Car loan 2',
                                 'principal':7000,
                                'interestRate': 0.08,
                                'annualPayments': 12,
                                'duration': 5,
                                'startDate': '01-06-2027',
                                'loanPaymentExtra': 250}
                  }}

# %%
# Initialse simulation class
sim = Simulation(data_dict=sim_details)

# %%
# Review user profile has the correct attributes
sim.userProfile.eduLevel
# Out:
# 6

# %%
# Run monte carlo model for two simulation iterations
df_store = sim.monte_carlo_model(10)
# Out:
# Tyler is 26 years old and has an income of $4333.33 per month.
#
# Loan 1 has principal of $300000 over duration 25 years with expected finish date of 2046-01-01 - remaining balance: $300000 - Minimum payment amount: $1583.51
# Loan 2 has principal of $50000 over duration 10 years with expected finish date of 2035-01-01 - remaining balance: $50000 - Minimum payment amount: $717.35
# Loan 3 has principal of $7000 over duration 5 years with expected finish date of 2032-06-01 - remaining balance: $7000 - Minimum payment amount: $141.93
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  5.27it/s]

# %%
# Execute statistical analysis
sim.statistical_analysis()
# Out:
# Processing: Income
# Processing: Tax
# Processing: SuperContrib
# Processing: SuperBalance
# Processing: SuperValue
# Processing: LoanDebt

# %%
# Review analysis results
sim.df_analytics.head()

# %%
# Review analysis results
sim.df_analytics.loc[90,:].T

# %%
sim.df_analytics[['RemainingIncome_Q25', 'RemainingIncome_Q50', 'RemainingIncome_Q75']].plot()
plt.show()

# %%
sim.df_analytics[['SavedAmt_Q25', 'SavedAmt_Q50', 'SavedAmt_Q75']].plot()
plt.show()

# %%
sim.df_analytics[['LoanDebt_Q25', 'LoanDebt_Q50', 'LoanDebt_Q75']].plot()
plt.show()

# %%
sim.df_analytics[['Income_Q25', 'Income_Q50', 'Income_Q75']].plot()
plt.show()

# %% [markdown]
# # Analytics on models...

# %% [raw]
# # Initialise empty dataframe instance
# df_analytics = pd.DataFrame()
# # column counter used for iteration columns for each type of column
#
#
# for col_name in sim.simulationHistory[0].drop('Date', axis=1).columns:    # iterate over columns except Date
#     print(f'Processing: {col_name}')
#
#     sim_column_count = 1
#
#     df_temp_analytics = pd.DataFrame()    # used to create a temporary dataframe for each column type which then can have statistical analysis done. This is then concatenated to the master dataframe.
#     for df in sim.simulationHistory:
#
#         # Expenses
#         df_temp_analytics[f'{col_name}_{sim_column_count}'] = df[col_name]
#
#         sim_column_count += 1
#
#     df_temp_analytics[f'{col_name}_Mean'] = df_temp_analytics.apply(lambda x: x.mean(), axis=1)
#     df_temp_analytics[f'{col_name}_Q25'] = df_temp_analytics.apply(lambda x: x.quantile(0.25), axis=1)
#     df_temp_analytics[f'{col_name}_Q50'] = df_temp_analytics.apply(lambda x: x.quantile(0.50), axis=1)
#     df_temp_analytics[f'{col_name}_Q75'] = df_temp_analytics.apply(lambda x: x.quantile(0.75), axis=1)
#
#     # concatenate to master dataframe
#     df_analytics = pd.concat([df_analytics, df_temp_analytics], axis=1, sort=False)

# %% [raw]
# df_analytics

# %% [raw]
# df_analytics.tail()

# %% [raw]
# df_analytics[['RemainingIncome_Q25', 'RemainingIncome_Q50', 'RemainingIncome_Q75']].plot()
# plt.show()

# %% [markdown]
# # ---- SIMULATION DEVELOPMENT ----

# %% [markdown]
# ## Running Basic User Simulation

# %% [markdown]
# ### Initialise user profile with basic information

# %% [raw]
# def init_profile():
#     """
#     Profile initialisation.
#     """
#     # Initialise Profile class
#     myProfile = Profile(name='tyler',age=26,retireAge=65,deadAge=80,incomePA=52000,expensesPM=1000,proportionSaved=0.25)
#
#     # Initialise loans and attribute them to the user profile
#     # Loan 1 - mortgage
#     myProfile.getLoan(principal=300000,interestRate=0.04,annualPayments=12,duration=25,startDate='1-1-2021', loanPaymentExtra=0)
#     # Loan 2 - car
#     myProfile.getLoan(principal=50000,interestRate=0.12,annualPayments=12,duration=5,startDate='01-01-2025', loanPaymentExtra=50)
#     # Loan 3 - car 2
#     myProfile.getLoan(principal=7000,interestRate=0.08,annualPayments=12,duration=10,startDate='01-06-2027', loanPaymentExtra=250)
#
#     # Output information pertaining to to user profile summary and loan descriptions/information
#     myProfile.summary()
#     myProfile.loanDesc()
#     myProfile.loanInfo()
#
#     return myProfile

# %% [raw]
# # Very good function...
# print(help(Profile))

# %% [raw]
# # Initialise a profile with the information in the previous function...
# myProfile = init_profile()

# %% [markdown]
# ### Simulate User Profile - 1 Lifetime

# %% [markdown]
# #### Simulation Iterations
# Note: Simulation outputs on a monthly frequency.

# %% [raw]
# def simulate():
#     # Duration of simulation (phase 1)
#     dateStart = datetime.date(2020,1,1)
#     dateStartTemp = dateStart
#
#
#     # Iterate over life with month level granularity
#     # Phase One - Working life
#     print('\n----- ENTERING PHASE ONE -----\n')
#     logging.info('ENTERING PHASE ONE')
#
#     while myProfile.age < myProfile.retireAge:
#         # Current datetime of step
#         print(f'\n {dateStartTemp}')
#         logging.debug(f'Current DateTime: {dateStartTemp}')
#         print(f'Monthly Income: ${myProfile.income:0.2f}')
#         logging.debug(f'Monthly Income: ${myProfile.income:0.2f}')
#
#         # Tax
#         # Get taxable amount from income
#         tax = myProfile.getTaxAmount(myProfile.income)
#         print(f'Tax: ${tax:0.2f}')
#         logging.debug(f'Tax: ${tax:0.2f}')
#
#         # Super
#         # Contribute to superannuation from income
#         myProfile.superContribution(1, myProfile.income)
#
#         tempLoanCost = 0
#
#         # Pay debts
#         # An aggregation of loan costs is computed here over all active loans
#         for loanID, loanInfo in myProfile.loanDict.items():    # Iterate through loans associated to the profile
#
#             # If the start date of the loan of interest is before the current time stamp, calculate loan payment or make loan inactive if it's finished.
#             if myProfile.loanDict[loanID].startDate <= dateStartTemp:
#
#                 # TESTING: This step is currently simulating random increases to loan principal.
#                 # This is used to emulate when income goes below zero and loans need to be increased to make up the difference.
#                 # This only works if there are active loans, if no loan is active then another method for re-activating or creating a new loan need to be developed.
#                 # NEED TO CONFIRM THAT THIS ISNT ATTRIBUTING EXTRA PRINCIPAL TO ALL LOANS... ONE MAY BE ENOUGH.
#                 myProfile.loanDict[loanID].increasePrincipalRandomly()
#
#                 # If balance remains on loans - make payment
#                 if 0 < myProfile.loanDict[loanID].beginBalance:
#                     # Raise payment against loan
#                     myProfile.loanDict[loanID].makePayment()
#                     # Print payment summary to console
#                     myProfile.loanDict[loanID].paymentSummary()
#
#                     # Capture loan history information for future analytics
#                     myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, myProfile.loanDict[loanID].beginBalance)
#
#                     # If the loan payment makes the balance zero, make the loan in-active as it's paid off
#                     if myProfile.loanDict[loanID].beginBalance == 0:
#                         print(f'LOAN {loanID} PAID OFF!')
#                         logging.debug(f'LOAN {loanID} PAID OFF!')
#                         # Set loanFinished to True
#                         myProfile.loanDict[loanID].loanFinished(dateStartTemp)
#
#                     # Loan is not paid off but persists for the next period
#                     else:
#                         # Capture loanPayment for totalcost aggregation
#                         print('ELSE SUMMARY!!!')
#                         myProfile.loanDict[loanID].paymentSummary()
# #                         print(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
# #                         logging.debug(f'Loan {loanID} - Begin Balance: ${myProfile.loanDict[loanID].beginBalance:0.2f} Payment: {myProfile.loanDict[loanID].loanPayment:0.2f}')
#                         tempLoanCost += myProfile.loanDict[loanID].loanPayment
#
#                 # No principal - either loan hasnt begun or its finished
#                 else:
#                     myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
#
#             # Too early - no loans are active
#             else:
#                 myProfile.loanDict[loanID].getLoanHistory(dateStartTemp, 0)
#                 pass
#
#         # Expenses
#         # Currently randomly increasing expenses to emulate randomness
#         # This has logic based on the phase of the user and some other salient information
#         expenses =  myProfile.increaseExpenseRandomly(1)
#
#         # Calculate income remaining after costs attributed to tax, expenses, etc.
#         myProfile.incomeAfterCosts(tax + tempLoanCost + expenses)
#         print(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
#         logging.debug(f'Income Remaining: ${myProfile.remainingIncome:0.2f}')
#         # Capture income history for future analysis
#         myProfile.getIncomeHistory(dateStartTemp, myProfile.remainingIncome)
#
#         # Savings
#         # Calculate savings based on remaining income (can't save what you don't have)
#         savedAmt = myProfile.getSavedAmount(myProfile.remainingIncome)
#         print(f'Amount saved this month: ${savedAmt:0.2f}')
#         logging.debug(f'Amount saved this month: ${savedAmt:0.2f}')
#
#         # Note: if more draw downs occur on the remaining income, then the savings need to be subtracted explicitly aswell.
#         # As this is not the case, it doesn't matter that the savings amount isn't removed from this parameter.
#
#
#         # Asset value
#         # Compute asset value based on compounding period and interest rates
# #         myProfile.getAssetValue(myProfile, compoundPeriod)
#
#         # Create an ordered dictionary of information
#         yield OrderedDict([('Date', dateStartTemp),
#                           ('Income', myProfile.income),
#                           ('Tax', myProfile.getTaxAmount(myProfile.income)),
#                           ('SuperContrib', myProfile.superContrib),
#                            ('SuperBalance', myProfile.superBalCumSum),
#                            ('SuperValue', myProfile.superValCumSum),
#                           ('LoanDebt', tempLoanCost),
#                           ('Expenses', expenses),
#                           ('RemainingIncome', myProfile.remainingIncome),
#                           ('SavedAmt', savedAmt)])
#
#         # Steps through time another month
#         dateStartTemp += relativedelta(months=1)
#
#         # if the current month of the year is January and we're not on the first year of the simulation
#         # Add another year to the users profile, e.g. age them another year.
#         if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
#             #print(f'Year: {dateStartTemp.year - dateStart.year}')
#             myProfile.ageStep(1)
#
#     # Iterate over life with month level granularity
#     # Phase Two - Retirement
#     print('\n----- ENTERING PHASE TWO -----\n')
#     print(logging.info('ENTERING PHASE TWO'))
#
#     # While the users age is less than the age of death, run the simulation
#     while myProfile.age < myProfile.deadAge:
#         print(f'\n {dateStartTemp}')
#         logging.debug(f'Current DateTime: {dateStartTemp}')
#
#         # Super drawdown
#         # Draw down super as this will act as a source of income
#         # Need to review how this is used...
#         myProfile.superDrawDown()
#
#         # Expenses
#         # Expenses in the retirement phase are treated differently to the
#         # working life phase
#         expenses =  myProfile.increaseExpenseRandomly(2)
#
#         # Create an ordered dictionary of information
#         yield OrderedDict([('Date', dateStartTemp),
#                           ('Income', 0),
#                           ('Tax', 0),
#                           ('SuperContrib', 0),
#                           ('SuperBalance', myProfile.superBalCumSum),
#                           ('SuperValue', myProfile.superValCumSum),
#                           ('LoanDebt', 0),
#                           ('Expenses', expenses),
#                           ('RemainingIncome', 0),
#                           ('SavedAmt', 0)])
#
#         # Steps through time another month
#         dateStartTemp += relativedelta(months=1)
#
#         # if the current month of the year is January and we're not on the first year of the simulation
#         # Add another year to the users profile, e.g. age them another year.
#         if dateStartTemp.month == 1 and (dateStartTemp.year - dateStart.year) > 0:
#             print(f'Year: {dateStartTemp.year - dateStart.year}')
#             myProfile.ageStep(1)

# %% [raw]
# df = pd.DataFrame(simulate())

# %% [raw]
# df.head(100)

# %% [markdown]
# ## Lifetime Visualisations

# %% [raw]
# plt.plot(df['Date'], df['SuperValue'])
# plt.plot(df['Date'], df['SuperBalance'])
# plt.show()

# %% [raw]
# plt.plot(df['Date'], df['LoanDebt'])
# plt.show()

# %% [raw]
# plt.plot(df['Date'], df['Expenses'])
# plt.show()

# %% [raw]
# # Check current state of the user profile...
# myProfile.summary()

# %% [raw]
# myProfile.loanInfo()

# %% [raw]
# for loanID, _ in myProfile.loanDict.items():
#
#     plt.plot(myProfile.loanDict[loanID].dateHistory, myProfile.loanDict[loanID].loanHistory)

# %% [raw]
# myProfile.loanDict['2'].loanPaidOff

# %% [raw]
# print('Loan 1')
# print('Start Date:', myProfile.loanDict['1'].startDate)
# print('Expected End Date:', myProfile.loanDict['1'].endDate)
# print('Finish Date:', myProfile.loanDict['1'].loanPaidOffDate)

# %% [raw]
# print('Loan 2')
# print('Start Date:', myProfile.loanDict['2'].startDate)
# print('Expected End Date:', myProfile.loanDict['2'].endDate)
# print('Finish Date:', myProfile.loanDict['2'].loanPaidOffDate)

# %% [raw]
# print('Loan 3')
# print('Start Date:', myProfile.loanDict['3'].startDate)
# print('Expected End Date:', myProfile.loanDict['3'].endDate)
# print('Finish Date:', myProfile.loanDict['3'].loanPaidOffDate)

# %% [raw]
# plt.plot(myProfile.dateHistory, myProfile.incomeHistory)
# plt.title('Remaining Income')
# plt.xlabel('Year')
# plt.ylabel('$ Amount')
